# %%
# from qiskit.opflow import I, Z, X, Y, SparsePauliOp
import numpy as np
# from juices import Juices
# 假设有 3 台机器和 3 个操作
m = 3 # 机器数量
n = 2 # 操作数量
l = 1  # 用于表示 C_max 的二进制位数

# 处理时间矩阵 (例如)
p = np.array([[1, 2, 3],[3, 1, 2]])

# 常数
K1 = 20
P = 10

# 量子比特数量
num_qubits = n * m + l

# %%
# #
# def pauli_z_term(index, num_qubits):
#     """初始化一个 Pauli-I 门的列表,指定索引 index 替换为 Pauli-Z 门"""
#     __paulis = ['I'] * num_qubits
#     paulis[index] = 'Z'
#     return ''.join(paulis)  # 将列表转化为字符串
#
# def pauli_x_term(index, num_qubits):
#     paulis = ['I'] * num_qubits
#     paulis[index] = 'X'
#     return ''.join(paulis)
# def pauli_y_term(index, num_qubits):
#     paulis = ['I'] * num_qubits
#     paulis[index] = 'Y'
#     return ''.join(paulis)

# %%
def append__zz_term( qc, qubit1, qubit2, gamma):
    qc.cx(qubit1, qubit2)
    qc.rz(gamma, qubit2)
    qc.cx(qubit1, qubit2)

def append__z_term(qc, qubit, gamma):
    qc.rz(gamma, qubit)
def append__mixer_term(qc, qubit, beta):
    qc.rx(2 * beta, qubit)

# %%
def get_cost_circuit1(gamma, n, m, l, K1, P, p, qc):
    # beta, gamma = params[:len(params)//2], params[len(params)//2:]
    for h in range(l):
        # print(m * n + h)
        coef = - 2**h
        append__z_term(qc, m * n + h, coef * gamma)
    return qc

# %%
def get_cost_circuit2(gamma, n, m, l, K1, P, p, qc):
    # beta, gamma = params[:len(params)//2], params[len(params)//2:]
    for i in range(n):
        for j in range(m):
            append__z_term(qc, i * m + j, (2 - m) * K1*gamma)
    # for i in range(n):
        for j1 in range(m):
            for j2 in range(m):
                if j1 != j2:
                    append__zz_term(qc, i * m + j1, i * m + j2, K1*gamma)
    return qc

# %%
def get_cost_circuit3(gamma, n, m, l, K1, P, p, qc):
    # beta, gamma = params[:len(params)//2], params[len(params)//2:]
    for j in range(m):
        for i in range(n):
            coef = -1/2 * (np.sum(p[:, j]) - ( 2 ** l-1)) * P
            append__z_term(qc, i * m + j, 2 * coef * p[i,j] * gamma)
        for h in range(l):
            coef = -1/2 * (np.sum(p[:, j]) - ( 2 ** l-1)) * P
            append__z_term(qc, m * n + h, -2 * (2 ** h) * coef * gamma)
        for i1 in range(n):
            for i2 in range(n):
                if i1 != i2:
                    coef = p[i1, j] * p[i2, j] * P
                    append__zz_term(qc, i1 * m + j, i2 * m + j, coef * gamma)
        for i in range(n):
            for h in range(l):
                coef = -1 * p[i,j] * 2 ** h * P
                append__zz_term(qc, i * m + j, m * n + h, coef * gamma)
        for h1 in range(l):
            for h2 in range(l):
                if h1 != h2:
                    coef = 2 ** h1 * 2 ** h2 * P
                    append__zz_term(qc, m * n + h1, m * n + h2, coef * gamma)
    return qc

# %%
def get_mixer_circuit(beta, n, m, l, K1, P, p, qc):
    # beta, gamma = params[:len(params)//2], params[len(params)//2:]
    for i in range(num_qubits):
        append__mixer_term(qc, i, beta)
        # qc.barrier()
    return qc

# %%
def get_mixer_circuit_xy(beta, n, m, l, K1, P, p, qc):
    for i in range(n):
        for j1 in range(m):
            for j2 in range(m):
                if j1<j2:
                    qc.rxx(2 * beta, i * m + j1, i * m + j2)
                    qc.ryy(2 * beta, i * m + j1, i * m + j2)

# %%
def invert_counts(s):
    return s[::-1]

# %%
from qiskit.circuit.library import PauliEvolutionGate
from qiskit import Aer, transpile, assemble, QuantumCircuit, execute


# 定义成本函数
def cost_function(params, n, m, l, K1, P, p):
    beta, gamma = params[:len(params)//2], params[len(params)//2:]
    num_qubits = n * m + l
    qc = QuantumCircuit(num_qubits, num_qubits)  # 添加经典寄存器

    # 初始化量子态到 |+> 态
    qc.h(range(n * m + l))
    # print(qc)

    # for g, b in zip(gamma, beta):
    #     # 应用问题哈密顿量
    #     qc.append(PauliEvolutionGate(cost_hamiltonian, g), list(range(num_qubits)))
    #     # 应用混合哈密顿量
    #     qc.append(PauliEvolutionGate(mixer_hamiltonian, b), list(range(num_qubits)))
    length  = len(params)
    for i in range(int(length/2)):

        # get_cost_circuit1(gamma[i], n, m, l, K1, P, p, qc)
        get_cost_circuit2(gamma[i], n, m, l, K1, P, p, qc)
        # get_cost_circuit3(gamma[i], n, m, l, K1, P, p, qc)
        get_mixer_circuit(beta[i], n, m, l, K1, P, p, qc)

    # print(qc)
    # 模拟电路
    # 添加测量指令
    qc.measure(range(num_qubits), range(num_qubits))
    backend = Aer.get_backend('qasm_simulator')
    result = execute(qc, backend, seed_simulator=10, shots=10000).result()
    counts = result.get_counts(qc)
    # 计算期望值
    expectation = 0
    for bitstring, count in counts.items():
        bitstring = invert_counts(bitstring)
        prob = count / 10000
        z_h = np.array([int(bit) for bit in bitstring[(n*m):]])
        x_ij = np.array([int(bit) for bit in bitstring[:(n*m)]]).reshape(n, m)

        E1 = np.sum([2 ** h * z for h, z in enumerate(z_h)])
        E2 = K1 * np.sum([(np.sum(x_ij[i]) - 1) ** 2 for i in range(n)])
        # alpha_s = np.max([0, np.sum(x_ij * p) - np.sum([2 ** h * z for h, z in enumerate(z_h)])])
        E3 = 0
        for j in range(m):

            sum_xp = np.sum([x_ij[i][j] * p[i][j] for i in range(n)])

            sum_zh = np.sum([2**h * z_h[h] for h in range(l)])

            max_value = max(0, sum_xp - sum_zh)

            E3 += P * (max_value)**2
        E =  E2
        # E = np.sum([2 ** h * z for h, z in enumerate(z_h)]) + K1 * np.sum([(np.sum(x_ij[i]) - 1) ** 2 for i in range(n)]) + P * alpha_s ** 2
        expectation += E * prob

    return expectation, counts

# %%
from qiskit_algorithms.optimizers import COBYLA


# 优化 QAOA 参数
def optimize_qaoa(n, m, l, K1, P, p, params):
    def objective(params):
        expectation, _ = cost_function(params, n, m, l, K1, P, p)

        return expectation

    optimizer = COBYLA(rhobeg = 1.5, tol = 1e-7)
    # params = np.random.rand(2 * p_max) * 2 * np.pi
    result = optimizer.minimize(fun=objective, x0=params)

    return result

# %%
import time

# 运行优化
# p_max = 6  # 最大层数

startTime = time.time()
ansatz_final = object()
init_point = np.array([])
counts = {}
min_energy = 0
final_result = object()
for p1 in range(1, 4):
    min_energy = 10000
    for k in range(100):
        print('第：', p1, '层', ' ', '第', k, '个参数')
        init_point_temp = init_point
        beta_p = np.random.uniform(0, np.pi)
        gamma_p = np.random.uniform(0,  2 * np.pi)
        if k >0:
            init_point_temp = np.delete(init_point_temp, 2 * p1 - 1)
            init_point_temp = np.delete(init_point_temp, p1 - 1)
        init_point_temp = np.insert(init_point_temp, p1 - 1, beta_p)
        init_point_temp = np.insert(init_point_temp, 2 * p1 - 1, gamma_p)
        # 创建参数向量
        # print("init_point_temp"+ init_point_temp)
        result = optimize_qaoa(n, m, l, K1, P, p, init_point_temp)

        # print(result.x)
        optimal_params = result.x

        # 计算最终的能量
        energy, counts_temp = cost_function(result.x, n, m, l, K1, P, p)
        # 寻找这20对点中最优的参数
        if min_energy > energy:
            min_energy = energy
            init_point = optimal_params
            counts = counts_temp
            final_result = result
endTime = time.time()
# params = np.random.rand(2 * p_max,2*np.pi)
# result = optimize_qaoa(n, m, l, K1, P, p, params)
# Out:
# 第： 1 层   第 0 个参数
# 第： 1 层   第 1 个参数
# 第： 1 层   第 2 个参数
# 第： 1 层   第 3 个参数
# 第： 1 层   第 4 个参数
# 第： 1 层   第 5 个参数
# 第： 1 层   第 6 个参数
# 第： 1 层   第 7 个参数
# 第： 1 层   第 8 个参数
# 第： 1 层   第 9 个参数
# 第： 1 层   第 10 个参数
# 第： 1 层   第 11 个参数
# 第： 1 层   第 12 个参数
# 第： 1 层   第 13 个参数
# 第： 1 层   第 14 个参数
# 第： 1 层   第 15 个参数
# 第： 1 层   第 16 个参数
# 第： 1 层   第 17 个参数
# 第： 1 层   第 18 个参数
# 第： 1 层   第 19 个参数
# 第： 1 层   第 20 个参数
# 第： 1 层   第 21 个参数
# 第： 1 层   第 22 个参数
# 第： 1 层   第 23 个参数
# 第： 1 层   第 24 个参数
# 第： 1 层   第 25 个参数
# 第： 1 层   第 26 个参数
# 第： 1 层   第 27 个参数
# 第： 1 层   第 28 个参数
# 第： 1 层   第 29 个参数
# 第： 1 层   第 30 个参数
# 第： 1 层   第 31 个参数
# 第： 1 层   第 32 个参数
# 第： 1 层   第 33 个参数
# 第： 1 层   第 34 个参数
# 第： 1 层   第 35 个参数
# 第： 1 层   第 36 个参数
# 第： 1 层   第 37 个参数
# 第： 1 层   第 38 个参数
# 第： 1 层   第 39 个参数
# 第： 1 层   第 40 个参数
# 第： 1 层   第 41 个参数
# 第： 1 层   第 42 个参数
# 第： 1 层   第 43 个参数
# 第： 1 层   第 44 个参数
# 第： 1 层   第 45 个参数
# 第： 1 层   第 46 个参数
# 第： 1 层   第 47 个参数
# 第： 1 层   第 48 个参数
# 第： 1 层   第 49 个参数
# 第： 1 层   第 50 个参数
# 第： 1 层   第 51 个参数
# 第： 1 层   第 52 个参数
# 第： 1 层   第 53 个参数
# 第： 1 层   第 54 个参数
# 第： 1 层   第 55 个参数
# 第： 1 层   第 56 个参数
# 第： 1 层   第 57 个参数
# 第： 1 层   第 58 个参数
# 第： 1 层   第 59 个参数
# 第： 1 层   第 60 个参数
# 第： 1 层   第 61 个参数
# 第： 1 层   第 62 个参数
# 第： 1 层   第 63 个参数
# 第： 1 层   第 64 个参数
# 第： 1 层   第 65 个参数
# 第： 1 层   第 66 个参数
# 第： 1 层   第 67 个参数
# 第： 1 层   第 68 个参数
# 第： 1 层   第 69 个参数
# 第： 1 层   第 70 个参数
# 第： 1 层   第 71 个参数
# 第： 1 层   第 72 个参数
# 第： 1 层   第 73 个参数
# 第： 1 层   第 74 个参数
# 第： 1 层   第 75 个参数
# 第： 1 层   第 76 个参数
# 第： 1 层   第 77 个参数
# 第： 1 层   第 78 个参数
# 第： 1 层   第 79 个参数
# 第： 1 层   第 80 个参数
# 第： 1 层   第 81 个参数
# 第： 1 层   第 82 个参数
# 第： 1 层   第 83 个参数
# 第： 1 层   第 84 个参数
# 第： 1 层   第 85 个参数
# 第： 1 层   第 86 个参数
# 第： 1 层   第 87 个参数
# 第： 1 层   第 88 个参数
# 第： 1 层   第 89 个参数
# 第： 1 层   第 90 个参数
# 第： 1 层   第 91 个参数
# 第： 1 层   第 92 个参数
# 第： 1 层   第 93 个参数
# 第： 1 层   第 94 个参数
# 第： 1 层   第 95 个参数
# 第： 1 层   第 96 个参数
# 第： 1 层   第 97 个参数
# 第： 1 层   第 98 个参数
# 第： 1 层   第 99 个参数
# 第： 2 层   第 0 个参数
# 第： 2 层   第 1 个参数
# 第： 2 层   第 2 个参数
# 第： 2 层   第 3 个参数
# 第： 2 层   第 4 个参数
# 第： 2 层   第 5 个参数
# 第： 2 层   第 6 个参数
# 第： 2 层   第 7 个参数
# 第： 2 层   第 8 个参数
# 第： 2 层   第 9 个参数
# 第： 2 层   第 10 个参数
# 第： 2 层   第 11 个参数
# 第： 2 层   第 12 个参数
# 第： 2 层   第 13 个参数
# 第： 2 层   第 14 个参数
# 第： 2 层   第 15 个参数
# 第： 2 层   第 16 个参数
# 第： 2 层   第 17 个参数
# 第： 2 层   第 18 个参数
# 第： 2 层   第 19 个参数
# 第： 2 层   第 20 个参数
# 第： 2 层   第 21 个参数
# 第： 2 层   第 22 个参数
# 第： 2 层   第 23 个参数
# 第： 2 层   第 24 个参数
# 第： 2 层   第 25 个参数
# 第： 2 层   第 26 个参数
# 第： 2 层   第 27 个参数
# 第： 2 层   第 28 个参数
# 第： 2 层   第 29 个参数
# 第： 2 层   第 30 个参数
# 第： 2 层   第 31 个参数
# 第： 2 层   第 32 个参数
# 第： 2 层   第 33 个参数
# 第： 2 层   第 34 个参数
# 第： 2 层   第 35 个参数
# 第： 2 层   第 36 个参数
# 第： 2 层   第 37 个参数
# 第： 2 层   第 38 个参数
# 第： 2 层   第 39 个参数
# 第： 2 层   第 40 个参数
# 第： 2 层   第 41 个参数
# 第： 2 层   第 42 个参数
# 第： 2 层   第 43 个参数
# 第： 2 层   第 44 个参数
# 第： 2 层   第 45 个参数
# 第： 2 层   第 46 个参数
# 第： 2 层   第 47 个参数
# 第： 2 层   第 48 个参数
# 第： 2 层   第 49 个参数
# 第： 2 层   第 50 个参数
# 第： 2 层   第 51 个参数
# 第： 2 层   第 52 个参数
# 第： 2 层   第 53 个参数
# 第： 2 层   第 54 个参数
# 第： 2 层   第 55 个参数
# 第： 2 层   第 56 个参数
# 第： 2 层   第 57 个参数
# 第： 2 层   第 58 个参数
# 第： 2 层   第 59 个参数
# 第： 2 层   第 60 个参数
# 第： 2 层   第 61 个参数
# 第： 2 层   第 62 个参数
# 第： 2 层   第 63 个参数
# 第： 2 层   第 64 个参数
# 第： 2 层   第 65 个参数
# 第： 2 层   第 66 个参数
# 第： 2 层   第 67 个参数
# 第： 2 层   第 68 个参数
# 第： 2 层   第 69 个参数
# 第： 2 层   第 70 个参数
# 第： 2 层   第 71 个参数
# 第： 2 层   第 72 个参数
# 第： 2 层   第 73 个参数
# 第： 2 层   第 74 个参数
# 第： 2 层   第 75 个参数
# 第： 2 层   第 76 个参数
# 第： 2 层   第 77 个参数
# 第： 2 层   第 78 个参数
# 第： 2 层   第 79 个参数
# 第： 2 层   第 80 个参数
# 第： 2 层   第 81 个参数
# 第： 2 层   第 82 个参数
# 第： 2 层   第 83 个参数
# 第： 2 层   第 84 个参数
# 第： 2 层   第 85 个参数
# 第： 2 层   第 86 个参数
# 第： 2 层   第 87 个参数
# 第： 2 层   第 88 个参数
# 第： 2 层   第 89 个参数
# 第： 2 层   第 90 个参数
# 第： 2 层   第 91 个参数
# 第： 2 层   第 92 个参数
# 第： 2 层   第 93 个参数
# 第： 2 层   第 94 个参数
# 第： 2 层   第 95 个参数
# 第： 2 层   第 96 个参数
# 第： 2 层   第 97 个参数
# 第： 2 层   第 98 个参数
# 第： 2 层   第 99 个参数
# 第： 3 层   第 0 个参数
# 第： 3 层   第 1 个参数
# 第： 3 层   第 2 个参数
# 第： 3 层   第 3 个参数
# 第： 3 层   第 4 个参数
# 第： 3 层   第 5 个参数
# 第： 3 层   第 6 个参数
# 第： 3 层   第 7 个参数
# 第： 3 层   第 8 个参数
# 第： 3 层   第 9 个参数
# 第： 3 层   第 10 个参数
# 第： 3 层   第 11 个参数
# 第： 3 层   第 12 个参数
# 第： 3 层   第 13 个参数
# 第： 3 层   第 14 个参数
# 第： 3 层   第 15 个参数
# 第： 3 层   第 16 个参数
# 第： 3 层   第 17 个参数
# 第： 3 层   第 18 个参数
# 第： 3 层   第 19 个参数
# 第： 3 层   第 20 个参数
# 第： 3 层   第 21 个参数
# 第： 3 层   第 22 个参数
# 第： 3 层   第 23 个参数
# 第： 3 层   第 24 个参数
# 第： 3 层   第 25 个参数
# 第： 3 层   第 26 个参数
# 第： 3 层   第 27 个参数
# 第： 3 层   第 28 个参数
# 第： 3 层   第 29 个参数
# 第： 3 层   第 30 个参数
# 第： 3 层   第 31 个参数
# 第： 3 层   第 32 个参数
# 第： 3 层   第 33 个参数
# 第： 3 层   第 34 个参数
# 第： 3 层   第 35 个参数
# 第： 3 层   第 36 个参数
# 第： 3 层   第 37 个参数
# 第： 3 层   第 38 个参数
# 第： 3 层   第 39 个参数
# 第： 3 层   第 40 个参数
# 第： 3 层   第 41 个参数
# 第： 3 层   第 42 个参数
# 第： 3 层   第 43 个参数
# 第： 3 层   第 44 个参数
# 第： 3 层   第 45 个参数
# 第： 3 层   第 46 个参数
# 第： 3 层   第 47 个参数
# 第： 3 层   第 48 个参数
# 第： 3 层   第 49 个参数
# 第： 3 层   第 50 个参数
# 第： 3 层   第 51 个参数
# 第： 3 层   第 52 个参数
# 第： 3 层   第 53 个参数
# 第： 3 层   第 54 个参数
# 第： 3 层   第 55 个参数
# 第： 3 层   第 56 个参数
# 第： 3 层   第 57 个参数
# 第： 3 层   第 58 个参数
# 第： 3 层   第 59 个参数
# 第： 3 层   第 60 个参数
# 第： 3 层   第 61 个参数
# 第： 3 层   第 62 个参数
# 第： 3 层   第 63 个参数
# 第： 3 层   第 64 个参数
# 第： 3 层   第 65 个参数
# 第： 3 层   第 66 个参数
# 第： 3 层   第 67 个参数
# 第： 3 层   第 68 个参数
# 第： 3 层   第 69 个参数
# 第： 3 层   第 70 个参数
# 第： 3 层   第 71 个参数
# 第： 3 层   第 72 个参数
# 第： 3 层   第 73 个参数
# 第： 3 层   第 74 个参数
# 第： 3 层   第 75 个参数
# 第： 3 层   第 76 个参数
# 第： 3 层   第 77 个参数
# 第： 3 层   第 78 个参数
# 第： 3 层   第 79 个参数
# 第： 3 层   第 80 个参数
# 第： 3 层   第 81 个参数
# 第： 3 层   第 82 个参数
# 第： 3 层   第 83 个参数
# 第： 3 层   第 84 个参数
# 第： 3 层   第 85 个参数
# 第： 3 层   第 86 个参数
# 第： 3 层   第 87 个参数
# 第： 3 层   第 88 个参数
# 第： 3 层   第 89 个参数
# 第： 3 层   第 90 个参数
# 第： 3 层   第 91 个参数
# 第： 3 层   第 92 个参数
# 第： 3 层   第 93 个参数
# 第： 3 层   第 94 个参数
# 第： 3 层   第 95 个参数
# 第： 3 层   第 96 个参数
# 第： 3 层   第 97 个参数
# 第： 3 层   第 98 个参数
# 第： 3 层   第 99 个参数

# %%
# 输出结果
print("优化时间：", endTime - startTime)
print("Optimal parameters:", final_result.x)
print("Optimal value:", final_result.fun)
# 使用最优参数运行量子电路并输出测量结果
final_expectation, final_counts = cost_function(final_result.x, n, m, l, K1, P, p)
# sorted_dict = dict(sorted(final_counts.items(), key=lambda item: item[1], reverse=True))
sorted_dict = {item[0][::-1]: item[1] for item in sorted(final_counts.items(), key=lambda item: item[1], reverse=True)}
print("Final expectation value:", final_expectation)
print("Final measurement counts:", sorted_dict)
# Out:
# 优化时间： 995.3084762096405
# Optimal parameters: [14.63584836  5.43437843  4.5086223   7.50302717  1.83829659  0.05435459]
# Optimal value: 0.38600000000000023
# Final expectation value: 0.38600000000000023
# Final measurement counts: {'1001001': 588, '1000101': 582, '0100011': 578, '0010011': 575, '0010010': 570, '1000011': 561, '0101000': 558, '0100101': 555, '0100100': 550, '1000010': 543, '1001000': 541, '0101001': 533, '0010100': 529, '0010101': 528, '0100010': 518, '1000100': 517, '0011001': 514, '0011000': 512, '0110100': 7, '0111000': 6, '1010010': 5, '1000111': 5, '0111001': 5, '1100010': 5, '0010110': 5, '0110010': 5, '1000110': 5, '0101011': 4, '0000101': 4, '0011010': 4, '0110101': 4, '1001010': 4, '1010011': 4, '1001011': 4, '0010111': 3, '0010000': 3, '0101111': 3, '0011011': 3, '1000000': 3, '0101010': 3, '1100011': 3, '1100101': 3, '0110011': 3, '1101000': 2, '0100111': 2, '1010100': 2, '0000010': 2, '1001110': 2, '0001001': 2, '1100100': 2, '1010101': 2, '1110100': 2, '0000100': 2, '0011101': 2, '1110011': 2, '0011111': 2, '0101100': 2, '1001100': 2, '1111000': 2, '1011001': 1, '1110010': 1, '0011110': 1, '0100001': 1, '1001101': 1, '0100000': 1, '0010001': 1, '0000011': 1, '0101101': 1, '0100110': 1, '1000001': 1, '1011000': 1, '0001000': 1}

# %% [markdown]
# 测试只代入最优参数，不优化，结果怎么样，h2

# %%
# op_params = [11.84548248 , 2.37812652  , 1.93942811,  4.67546307,  1.58498361,  6.35763475]
# beta, gamma = op_params[:len(op_params)//2], op_params[len(op_params)//2:]
# qc2 = QuantumCircuit(num_qubits, num_qubits)
# length = len(op_params)
# qc2.h(range(n * m + l))
# for i in range(int(length/2)):
#
#         # get_cost_circuit1(gamma[i], n, m, l, K1, P, p, qc2)
#         get_cost_circuit2(gamma[i], n, m, l, K1, P, p, qc2)
#         # get_cost_circuit3(gamma[i], n, m, l, K1, P, p, qc2)
#         get_mixer_circuit(beta[i], n, m, l, K1, P, p, qc2)
#
# qc2.measure(range(num_qubits), range(num_qubits))
# backend = Aer.get_backend('qasm_simulator')
# result = execute(qc2, backend, seed_simulator=10, shots=10000).result()
# counts = result.get_counts(qc2)
# sorted_dict = {item[0][::-1]: item[1] for item in sorted(counts.items(), key=lambda item: item[1], reverse=True)}
# # print("Final expectation value:", final_expectation)
# print("Final measurement counts:", sorted_dict)

# %%
from qiskit.visualization import plot_histogram

# 定义成本函数
def cost_function_xy(params, n, m, l, K1, P, p, optimal_params):
    beta, gamma = params[:len(params)//2], params[len(params)//2:]
    opt_beta, opt_gamma = optimal_params[:len(optimal_params)//2], optimal_params[len(optimal_params)//2:]
    num_qubits = n * m + l
    qc = QuantumCircuit(num_qubits, num_qubits)  # 添加经典寄存器

    # 初始化量子态到 |+> 态
    qc.h(range(n * m + l))
    opt_length  = len(optimal_params)
    for i in range(int(opt_length/2)):

        # get_cost_circuit1(gamma[i], n, m, l, K1, P, p, qc)
        get_cost_circuit2(opt_gamma[i], n, m, l, K1, P, p, qc)
        # get_cost_circuit3(gamma[i], n, m, l, K1, P, p, qc)
        get_mixer_circuit(opt_beta[i], n, m, l, K1, P, p, qc)
    length = len(params)
    for i in range(int(length/2)):

        get_cost_circuit1(gamma[i], n, m, l, K1, P, p, qc)
        # get_cost_circuit2(gamma[i], n, m, l, K1, P, p, qc)
        get_cost_circuit3(gamma[i], n, m, l, K1, P, p, qc)
        get_mixer_circuit_xy(beta[i], n, m, l, K1, P, p, qc)
    # print(qc)

    # 模拟电路
    # 添加测量指令
    qc.measure(range(num_qubits), range(num_qubits))
    backend = Aer.get_backend('qasm_simulator')
    # qc = transpile(qc, backend)
    # qobj = assemble(qc, shots=10000)
    # result = backend.run(qobj).result()
    result = execute(qc, backend, seed_simulator=10, shots=10000).result()
    counts = result.get_counts(qc)
    # qc.draw(output = 'mpl', style='iqp')
    # plot_histogram(counts)
    # 计算期望值
    expectation = 0
    # x=0
    for bitstring, count in counts.items():
        bitstring = invert_counts(bitstring)
        prob = count / 10000
        z_h = np.array([int(bit) for bit in bitstring[(n*m):]])
        x_ij = np.array([int(bit) for bit in bitstring[:(n*m)]]).reshape(n, m)

        E1 = np.sum([2 ** h * z for h, z in enumerate(z_h)])
        E2 = K1 * np.sum([(np.sum(x_ij[i]) - 1) ** 2 for i in range(n)])
        # alpha_s = np.max([0, np.sum(x_ij * p) - np.sum([2 ** h * z for h, z in enumerate(z_h)])])
        E3 = 0
        for j in range(m):

            sum_xp = np.sum([x_ij[i][j] * p[i][j] for i in range(n)])

            sum_zh = np.sum([2**h * z_h[h] for h in range(l)])

            max_value = max(0, sum_xp - sum_zh)

            E3 += P * (max_value)**2
        E = E1 + E3
        # x+=1
        # print(E)
        expectation += E * prob
    # print("x:",x)
    return expectation, counts

# %%
# 优化 QAOA 参数
def optimize_qaoa_xy(n, m, l, K1, P, p, params, opt_params):
    def objective(params):
        expectation, _ = cost_function_xy(params, n, m, l, K1, P, p, opt_params)

        return expectation

    optimizer = COBYLA(rhobeg=1.5, tol=1e-7)
    # params = np.random.rand(2 * p_max) * 2 * np.pi
    result = optimizer.minimize(fun=objective, x0=params)

    return result

# %%
import time

# 运行优化
# p_max = 6  # 最大层数

startTime = time.time()
# ansatz_final = object()
init_point_xy = np.array([])
counts_xy = {}
min_energy_xy = 0
final_result_xy = object()
optimal_params = final_result.x
for p1 in range(1, 6):
    min_energy_xy = 10000
    for k in range(300):
        print('第：', p1, '层', ' ', '第', k, '个参数')
        init_point_temp = init_point_xy
        beta_p = np.random.uniform(0, np.pi)
        gamma_p = np.random.uniform(0,  2 * np.pi)
        if k >0:
            init_point_temp = np.delete(init_point_temp, 2 * p1 - 1)
            init_point_temp = np.delete(init_point_temp, p1 - 1)
        init_point_temp = np.insert(init_point_temp, p1 - 1, beta_p)
        init_point_temp = np.insert(init_point_temp, 2 * p1 - 1, gamma_p)
        # 创建参数向量
        # print("init_point_temp"+ init_point_temp)
        result = optimize_qaoa_xy(n, m, l, K1, P, p, init_point_temp, optimal_params)

        # print(result.x)
        optimal_params_xy = result.x

        # 计算最终的能量
        energy, counts_temp = cost_function_xy(result.x, n, m, l, K1, P, p,optimal_params)
        # 寻找这20对点中最优的参数
        if min_energy_xy > energy:
            min_energy_xy = energy
            init_point_xy = optimal_params_xy
            counts_xy = counts_temp
            final_result_xy = result
endTime = time.time()
# Out:
# 第： 1 层   第 0 个参数
# 第： 1 层   第 1 个参数
# 第： 1 层   第 2 个参数
# 第： 1 层   第 3 个参数
# 第： 1 层   第 4 个参数
# 第： 1 层   第 5 个参数
# 第： 1 层   第 6 个参数
# 第： 1 层   第 7 个参数
# 第： 1 层   第 8 个参数
# 第： 1 层   第 9 个参数
# 第： 1 层   第 10 个参数
# 第： 1 层   第 11 个参数
# 第： 1 层   第 12 个参数
# 第： 1 层   第 13 个参数
# 第： 1 层   第 14 个参数
# 第： 1 层   第 15 个参数
# 第： 1 层   第 16 个参数
# 第： 1 层   第 17 个参数
# 第： 1 层   第 18 个参数
# 第： 1 层   第 19 个参数
# 第： 1 层   第 20 个参数
# 第： 1 层   第 21 个参数
# 第： 1 层   第 22 个参数
# 第： 1 层   第 23 个参数
# 第： 1 层   第 24 个参数
# 第： 1 层   第 25 个参数
# 第： 1 层   第 26 个参数
# 第： 1 层   第 27 个参数
# 第： 1 层   第 28 个参数
# 第： 1 层   第 29 个参数
# 第： 1 层   第 30 个参数
# 第： 1 层   第 31 个参数
# 第： 1 层   第 32 个参数
# 第： 1 层   第 33 个参数
# 第： 1 层   第 34 个参数
# 第： 1 层   第 35 个参数
# 第： 1 层   第 36 个参数
# 第： 1 层   第 37 个参数
# 第： 1 层   第 38 个参数
# 第： 1 层   第 39 个参数
# 第： 1 层   第 40 个参数
# 第： 1 层   第 41 个参数
# 第： 1 层   第 42 个参数
# 第： 1 层   第 43 个参数
# 第： 1 层   第 44 个参数
# 第： 1 层   第 45 个参数
# 第： 1 层   第 46 个参数
# 第： 1 层   第 47 个参数
# 第： 1 层   第 48 个参数
# 第： 1 层   第 49 个参数
# 第： 1 层   第 50 个参数
# 第： 1 层   第 51 个参数
# 第： 1 层   第 52 个参数
# 第： 1 层   第 53 个参数
# 第： 1 层   第 54 个参数
# 第： 1 层   第 55 个参数
# 第： 1 层   第 56 个参数
# 第： 1 层   第 57 个参数
# 第： 1 层   第 58 个参数
# 第： 1 层   第 59 个参数
# 第： 1 层   第 60 个参数
# 第： 1 层   第 61 个参数
# 第： 1 层   第 62 个参数
# 第： 1 层   第 63 个参数
# 第： 1 层   第 64 个参数
# 第： 1 层   第 65 个参数
# 第： 1 层   第 66 个参数
# 第： 1 层   第 67 个参数
# 第： 1 层   第 68 个参数
# 第： 1 层   第 69 个参数
# 第： 1 层   第 70 个参数
# 第： 1 层   第 71 个参数
# 第： 1 层   第 72 个参数
# 第： 1 层   第 73 个参数
# 第： 1 层   第 74 个参数
# 第： 1 层   第 75 个参数
# 第： 1 层   第 76 个参数
# 第： 1 层   第 77 个参数
# 第： 1 层   第 78 个参数
# 第： 1 层   第 79 个参数
# 第： 1 层   第 80 个参数
# 第： 1 层   第 81 个参数
# 第： 1 层   第 82 个参数
# 第： 1 层   第 83 个参数
# 第： 1 层   第 84 个参数
# 第： 1 层   第 85 个参数
# 第： 1 层   第 86 个参数
# 第： 1 层   第 87 个参数
# 第： 1 层   第 88 个参数
# 第： 1 层   第 89 个参数
# 第： 1 层   第 90 个参数
# 第： 1 层   第 91 个参数
# 第： 1 层   第 92 个参数
# 第： 1 层   第 93 个参数
# 第： 1 层   第 94 个参数
# 第： 1 层   第 95 个参数
# 第： 1 层   第 96 个参数
# 第： 1 层   第 97 个参数
# 第： 1 层   第 98 个参数
# 第： 1 层   第 99 个参数
# 第： 1 层   第 100 个参数
# 第： 1 层   第 101 个参数
# 第： 1 层   第 102 个参数
# 第： 1 层   第 103 个参数
# 第： 1 层   第 104 个参数
# 第： 1 层   第 105 个参数
# 第： 1 层   第 106 个参数
# 第： 1 层   第 107 个参数
# 第： 1 层   第 108 个参数
# 第： 1 层   第 109 个参数
# 第： 1 层   第 110 个参数
# 第： 1 层   第 111 个参数
# 第： 1 层   第 112 个参数
# 第： 1 层   第 113 个参数
# 第： 1 层   第 114 个参数
# 第： 1 层   第 115 个参数
# 第： 1 层   第 116 个参数
# 第： 1 层   第 117 个参数
# 第： 1 层   第 118 个参数
# 第： 1 层   第 119 个参数
# 第： 1 层   第 120 个参数
# 第： 1 层   第 121 个参数
# 第： 1 层   第 122 个参数
# 第： 1 层   第 123 个参数
# 第： 1 层   第 124 个参数
# 第： 1 层   第 125 个参数
# 第： 1 层   第 126 个参数
# 第： 1 层   第 127 个参数
# 第： 1 层   第 128 个参数
# 第： 1 层   第 129 个参数
# 第： 1 层   第 130 个参数
# 第： 1 层   第 131 个参数
# 第： 1 层   第 132 个参数
# 第： 1 层   第 133 个参数
# 第： 1 层   第 134 个参数
# 第： 1 层   第 135 个参数
# 第： 1 层   第 136 个参数
# 第： 1 层   第 137 个参数
# 第： 1 层   第 138 个参数
# 第： 1 层   第 139 个参数
# 第： 1 层   第 140 个参数
# 第： 1 层   第 141 个参数
# 第： 1 层   第 142 个参数
# 第： 1 层   第 143 个参数
# 第： 1 层   第 144 个参数
# 第： 1 层   第 145 个参数
# 第： 1 层   第 146 个参数
# 第： 1 层   第 147 个参数
# 第： 1 层   第 148 个参数
# 第： 1 层   第 149 个参数
# 第： 1 层   第 150 个参数
# 第： 1 层   第 151 个参数
# 第： 1 层   第 152 个参数
# 第： 1 层   第 153 个参数
# 第： 1 层   第 154 个参数
# 第： 1 层   第 155 个参数
# 第： 1 层   第 156 个参数
# 第： 1 层   第 157 个参数
# 第： 1 层   第 158 个参数
# 第： 1 层   第 159 个参数
# 第： 1 层   第 160 个参数
# 第： 1 层   第 161 个参数
# 第： 1 层   第 162 个参数
# 第： 1 层   第 163 个参数
# 第： 1 层   第 164 个参数
# 第： 1 层   第 165 个参数
# 第： 1 层   第 166 个参数
# 第： 1 层   第 167 个参数
# 第： 1 层   第 168 个参数
# 第： 1 层   第 169 个参数
# 第： 1 层   第 170 个参数
# 第： 1 层   第 171 个参数
# 第： 1 层   第 172 个参数
# 第： 1 层   第 173 个参数
# 第： 1 层   第 174 个参数
# 第： 1 层   第 175 个参数
# 第： 1 层   第 176 个参数
# 第： 1 层   第 177 个参数
# 第： 1 层   第 178 个参数
# 第： 1 层   第 179 个参数
# 第： 1 层   第 180 个参数
# 第： 1 层   第 181 个参数
# 第： 1 层   第 182 个参数
# 第： 1 层   第 183 个参数
# 第： 1 层   第 184 个参数
# 第： 1 层   第 185 个参数
# 第： 1 层   第 186 个参数
# 第： 1 层   第 187 个参数
# 第： 1 层   第 188 个参数
# 第： 1 层   第 189 个参数
# 第： 1 层   第 190 个参数
# 第： 1 层   第 191 个参数
# 第： 1 层   第 192 个参数
# 第： 1 层   第 193 个参数
# 第： 1 层   第 194 个参数
# 第： 1 层   第 195 个参数
# 第： 1 层   第 196 个参数
# 第： 1 层   第 197 个参数
# 第： 1 层   第 198 个参数
# 第： 1 层   第 199 个参数
# 第： 1 层   第 200 个参数
# 第： 1 层   第 201 个参数
# 第： 1 层   第 202 个参数
# 第： 1 层   第 203 个参数
# 第： 1 层   第 204 个参数
# 第： 1 层   第 205 个参数
# 第： 1 层   第 206 个参数
# 第： 1 层   第 207 个参数
# 第： 1 层   第 208 个参数
# 第： 1 层   第 209 个参数
# 第： 1 层   第 210 个参数
# 第： 1 层   第 211 个参数
# 第： 1 层   第 212 个参数
# 第： 1 层   第 213 个参数
# 第： 1 层   第 214 个参数
# 第： 1 层   第 215 个参数
# 第： 1 层   第 216 个参数
# 第： 1 层   第 217 个参数
# 第： 1 层   第 218 个参数
# 第： 1 层   第 219 个参数
# 第： 1 层   第 220 个参数
# 第： 1 层   第 221 个参数
# 第： 1 层   第 222 个参数
# 第： 1 层   第 223 个参数
# 第： 1 层   第 224 个参数
# 第： 1 层   第 225 个参数
# 第： 1 层   第 226 个参数
# 第： 1 层   第 227 个参数
# 第： 1 层   第 228 个参数
# 第： 1 层   第 229 个参数
# 第： 1 层   第 230 个参数
# 第： 1 层   第 231 个参数
# 第： 1 层   第 232 个参数
# 第： 1 层   第 233 个参数
# 第： 1 层   第 234 个参数
# 第： 1 层   第 235 个参数
# 第： 1 层   第 236 个参数
# 第： 1 层   第 237 个参数
# 第： 1 层   第 238 个参数
# 第： 1 层   第 239 个参数
# 第： 1 层   第 240 个参数
# 第： 1 层   第 241 个参数
# 第： 1 层   第 242 个参数
# 第： 1 层   第 243 个参数
# 第： 1 层   第 244 个参数
# 第： 1 层   第 245 个参数
# 第： 1 层   第 246 个参数
# 第： 1 层   第 247 个参数
# 第： 1 层   第 248 个参数
# 第： 1 层   第 249 个参数
# 第： 1 层   第 250 个参数
# 第： 1 层   第 251 个参数
# 第： 1 层   第 252 个参数
# 第： 1 层   第 253 个参数
# 第： 1 层   第 254 个参数
# 第： 1 层   第 255 个参数
# 第： 1 层   第 256 个参数
# 第： 1 层   第 257 个参数
# 第： 1 层   第 258 个参数
# 第： 1 层   第 259 个参数
# 第： 1 层   第 260 个参数
# 第： 1 层   第 261 个参数
# 第： 1 层   第 262 个参数
# 第： 1 层   第 263 个参数
# 第： 1 层   第 264 个参数
# 第： 1 层   第 265 个参数
# 第： 1 层   第 266 个参数
# 第： 1 层   第 267 个参数
# 第： 1 层   第 268 个参数
# 第： 1 层   第 269 个参数
# 第： 1 层   第 270 个参数
# 第： 1 层   第 271 个参数
# 第： 1 层   第 272 个参数
# 第： 1 层   第 273 个参数
# 第： 1 层   第 274 个参数
# 第： 1 层   第 275 个参数
# 第： 1 层   第 276 个参数
# 第： 1 层   第 277 个参数
# 第： 1 层   第 278 个参数
# 第： 1 层   第 279 个参数
# 第： 1 层   第 280 个参数
# 第： 1 层   第 281 个参数
# 第： 1 层   第 282 个参数
# 第： 1 层   第 283 个参数
# 第： 1 层   第 284 个参数
# 第： 1 层   第 285 个参数
# 第： 1 层   第 286 个参数
# 第： 1 层   第 287 个参数
# 第： 1 层   第 288 个参数
# 第： 1 层   第 289 个参数
# 第： 1 层   第 290 个参数
# 第： 1 层   第 291 个参数
# 第： 1 层   第 292 个参数
# 第： 1 层   第 293 个参数
# 第： 1 层   第 294 个参数
# 第： 1 层   第 295 个参数
# 第： 1 层   第 296 个参数
# 第： 1 层   第 297 个参数
# 第： 1 层   第 298 个参数
# 第： 1 层   第 299 个参数
# 第： 2 层   第 0 个参数
# 第： 2 层   第 1 个参数
# 第： 2 层   第 2 个参数
# 第： 2 层   第 3 个参数
# 第： 2 层   第 4 个参数
# 第： 2 层   第 5 个参数
# 第： 2 层   第 6 个参数
# 第： 2 层   第 7 个参数
# 第： 2 层   第 8 个参数
# 第： 2 层   第 9 个参数
# 第： 2 层   第 10 个参数
# 第： 2 层   第 11 个参数
# 第： 2 层   第 12 个参数
# 第： 2 层   第 13 个参数
# 第： 2 层   第 14 个参数
# 第： 2 层   第 15 个参数
# 第： 2 层   第 16 个参数
# 第： 2 层   第 17 个参数
# 第： 2 层   第 18 个参数
# 第： 2 层   第 19 个参数
# 第： 2 层   第 20 个参数
# 第： 2 层   第 21 个参数
# 第： 2 层   第 22 个参数
# 第： 2 层   第 23 个参数
# 第： 2 层   第 24 个参数
# 第： 2 层   第 25 个参数
# 第： 2 层   第 26 个参数
# 第： 2 层   第 27 个参数
# 第： 2 层   第 28 个参数
# 第： 2 层   第 29 个参数
# 第： 2 层   第 30 个参数
# 第： 2 层   第 31 个参数
# 第： 2 层   第 32 个参数
# 第： 2 层   第 33 个参数
# 第： 2 层   第 34 个参数
# 第： 2 层   第 35 个参数
# 第： 2 层   第 36 个参数
# 第： 2 层   第 37 个参数
# 第： 2 层   第 38 个参数
# 第： 2 层   第 39 个参数
# 第： 2 层   第 40 个参数
# 第： 2 层   第 41 个参数
# 第： 2 层   第 42 个参数
# 第： 2 层   第 43 个参数
# 第： 2 层   第 44 个参数
# 第： 2 层   第 45 个参数
# 第： 2 层   第 46 个参数
# 第： 2 层   第 47 个参数
# 第： 2 层   第 48 个参数
# 第： 2 层   第 49 个参数
# 第： 2 层   第 50 个参数
# 第： 2 层   第 51 个参数
# 第： 2 层   第 52 个参数
# 第： 2 层   第 53 个参数
# 第： 2 层   第 54 个参数
# 第： 2 层   第 55 个参数
# 第： 2 层   第 56 个参数
# 第： 2 层   第 57 个参数
# 第： 2 层   第 58 个参数
# 第： 2 层   第 59 个参数
# 第： 2 层   第 60 个参数
# 第： 2 层   第 61 个参数
# 第： 2 层   第 62 个参数
# 第： 2 层   第 63 个参数
# 第： 2 层   第 64 个参数
# 第： 2 层   第 65 个参数
# 第： 2 层   第 66 个参数
# 第： 2 层   第 67 个参数
# 第： 2 层   第 68 个参数
# 第： 2 层   第 69 个参数
# 第： 2 层   第 70 个参数
# 第： 2 层   第 71 个参数
# 第： 2 层   第 72 个参数
# 第： 2 层   第 73 个参数
# 第： 2 层   第 74 个参数
# 第： 2 层   第 75 个参数
# 第： 2 层   第 76 个参数
# 第： 2 层   第 77 个参数
# 第： 2 层   第 78 个参数
# 第： 2 层   第 79 个参数
# 第： 2 层   第 80 个参数
# 第： 2 层   第 81 个参数
# 第： 2 层   第 82 个参数
# 第： 2 层   第 83 个参数
# 第： 2 层   第 84 个参数
# 第： 2 层   第 85 个参数
# 第： 2 层   第 86 个参数
# 第： 2 层   第 87 个参数
# 第： 2 层   第 88 个参数
# 第： 2 层   第 89 个参数
# 第： 2 层   第 90 个参数
# 第： 2 层   第 91 个参数
# 第： 2 层   第 92 个参数
# 第： 2 层   第 93 个参数
# 第： 2 层   第 94 个参数
# 第： 2 层   第 95 个参数
# 第： 2 层   第 96 个参数
# 第： 2 层   第 97 个参数
# 第： 2 层   第 98 个参数
# 第： 2 层   第 99 个参数
# 第： 2 层   第 100 个参数
# 第： 2 层   第 101 个参数
# 第： 2 层   第 102 个参数
# 第： 2 层   第 103 个参数
# 第： 2 层   第 104 个参数
# 第： 2 层   第 105 个参数
# 第： 2 层   第 106 个参数
# 第： 2 层   第 107 个参数
# 第： 2 层   第 108 个参数
# 第： 2 层   第 109 个参数
# 第： 2 层   第 110 个参数
# 第： 2 层   第 111 个参数
# 第： 2 层   第 112 个参数
# 第： 2 层   第 113 个参数
# 第： 2 层   第 114 个参数
# 第： 2 层   第 115 个参数
# 第： 2 层   第 116 个参数
# 第： 2 层   第 117 个参数
# 第： 2 层   第 118 个参数
# 第： 2 层   第 119 个参数
# 第： 2 层   第 120 个参数
# 第： 2 层   第 121 个参数
# 第： 2 层   第 122 个参数
# 第： 2 层   第 123 个参数
# 第： 2 层   第 124 个参数
# 第： 2 层   第 125 个参数
# 第： 2 层   第 126 个参数
# 第： 2 层   第 127 个参数
# 第： 2 层   第 128 个参数
# 第： 2 层   第 129 个参数
# 第： 2 层   第 130 个参数
# 第： 2 层   第 131 个参数
# 第： 2 层   第 132 个参数
# 第： 2 层   第 133 个参数
# 第： 2 层   第 134 个参数
# 第： 2 层   第 135 个参数
# 第： 2 层   第 136 个参数
# 第： 2 层   第 137 个参数
# 第： 2 层   第 138 个参数
# 第： 2 层   第 139 个参数
# 第： 2 层   第 140 个参数
# 第： 2 层   第 141 个参数
# 第： 2 层   第 142 个参数
# 第： 2 层   第 143 个参数
# 第： 2 层   第 144 个参数
# 第： 2 层   第 145 个参数
# 第： 2 层   第 146 个参数
# 第： 2 层   第 147 个参数
# 第： 2 层   第 148 个参数
# 第： 2 层   第 149 个参数
# 第： 2 层   第 150 个参数
# 第： 2 层   第 151 个参数
# 第： 2 层   第 152 个参数
# 第： 2 层   第 153 个参数
# 第： 2 层   第 154 个参数
# 第： 2 层   第 155 个参数
# 第： 2 层   第 156 个参数
# 第： 2 层   第 157 个参数
# 第： 2 层   第 158 个参数
# 第： 2 层   第 159 个参数
# 第： 2 层   第 160 个参数
# 第： 2 层   第 161 个参数
# 第： 2 层   第 162 个参数
# 第： 2 层   第 163 个参数
# 第： 2 层   第 164 个参数
# 第： 2 层   第 165 个参数
# 第： 2 层   第 166 个参数
# 第： 2 层   第 167 个参数
# 第： 2 层   第 168 个参数
# 第： 2 层   第 169 个参数
# 第： 2 层   第 170 个参数
# 第： 2 层   第 171 个参数
# 第： 2 层   第 172 个参数
# 第： 2 层   第 173 个参数
# 第： 2 层   第 174 个参数
# 第： 2 层   第 175 个参数
# 第： 2 层   第 176 个参数
# 第： 2 层   第 177 个参数
# 第： 2 层   第 178 个参数
# 第： 2 层   第 179 个参数
# 第： 2 层   第 180 个参数
# 第： 2 层   第 181 个参数
# 第： 2 层   第 182 个参数
# 第： 2 层   第 183 个参数
# 第： 2 层   第 184 个参数
# 第： 2 层   第 185 个参数
# 第： 2 层   第 186 个参数
# 第： 2 层   第 187 个参数
# 第： 2 层   第 188 个参数
# 第： 2 层   第 189 个参数
# 第： 2 层   第 190 个参数
# 第： 2 层   第 191 个参数
# 第： 2 层   第 192 个参数
# 第： 2 层   第 193 个参数
# 第： 2 层   第 194 个参数
# 第： 2 层   第 195 个参数
# 第： 2 层   第 196 个参数
# 第： 2 层   第 197 个参数
# 第： 2 层   第 198 个参数
# 第： 2 层   第 199 个参数
# 第： 2 层   第 200 个参数
# 第： 2 层   第 201 个参数
# 第： 2 层   第 202 个参数
# 第： 2 层   第 203 个参数
# 第： 2 层   第 204 个参数
# 第： 2 层   第 205 个参数
# 第： 2 层   第 206 个参数
# 第： 2 层   第 207 个参数
# 第： 2 层   第 208 个参数
# 第： 2 层   第 209 个参数
# 第： 2 层   第 210 个参数
# 第： 2 层   第 211 个参数
# 第： 2 层   第 212 个参数
# 第： 2 层   第 213 个参数
# 第： 2 层   第 214 个参数
# 第： 2 层   第 215 个参数
# 第： 2 层   第 216 个参数
# 第： 2 层   第 217 个参数
# 第： 2 层   第 218 个参数
# 第： 2 层   第 219 个参数
# 第： 2 层   第 220 个参数
# 第： 2 层   第 221 个参数
# 第： 2 层   第 222 个参数
# 第： 2 层   第 223 个参数
# 第： 2 层   第 224 个参数
# 第： 2 层   第 225 个参数
# 第： 2 层   第 226 个参数
# 第： 2 层   第 227 个参数
# 第： 2 层   第 228 个参数
# 第： 2 层   第 229 个参数
# 第： 2 层   第 230 个参数
# 第： 2 层   第 231 个参数
# 第： 2 层   第 232 个参数
# 第： 2 层   第 233 个参数
# 第： 2 层   第 234 个参数
# 第： 2 层   第 235 个参数
# 第： 2 层   第 236 个参数
# 第： 2 层   第 237 个参数
# 第： 2 层   第 238 个参数
# 第： 2 层   第 239 个参数
# 第： 2 层   第 240 个参数
# 第： 2 层   第 241 个参数
# 第： 2 层   第 242 个参数
# 第： 2 层   第 243 个参数
# 第： 2 层   第 244 个参数
# 第： 2 层   第 245 个参数
# 第： 2 层   第 246 个参数
# 第： 2 层   第 247 个参数
# 第： 2 层   第 248 个参数
# 第： 2 层   第 249 个参数
# 第： 2 层   第 250 个参数
# 第： 2 层   第 251 个参数
# 第： 2 层   第 252 个参数
# 第： 2 层   第 253 个参数
# 第： 2 层   第 254 个参数
# 第： 2 层   第 255 个参数
# 第： 2 层   第 256 个参数
# 第： 2 层   第 257 个参数
# 第： 2 层   第 258 个参数
# 第： 2 层   第 259 个参数
# 第： 2 层   第 260 个参数
# 第： 2 层   第 261 个参数
# 第： 2 层   第 262 个参数
# 第： 2 层   第 263 个参数
# 第： 2 层   第 264 个参数
# 第： 2 层   第 265 个参数
# 第： 2 层   第 266 个参数
# 第： 2 层   第 267 个参数
# 第： 2 层   第 268 个参数
# 第： 2 层   第 269 个参数
# 第： 2 层   第 270 个参数
# 第： 2 层   第 271 个参数
# 第： 2 层   第 272 个参数
# 第： 2 层   第 273 个参数
# 第： 2 层   第 274 个参数
# 第： 2 层   第 275 个参数
# 第： 2 层   第 276 个参数
# 第： 2 层   第 277 个参数
# 第： 2 层   第 278 个参数
# 第： 2 层   第 279 个参数
# 第： 2 层   第 280 个参数
# 第： 2 层   第 281 个参数
# 第： 2 层   第 282 个参数
# 第： 2 层   第 283 个参数
# 第： 2 层   第 284 个参数
# 第： 2 层   第 285 个参数
# 第： 2 层   第 286 个参数
# 第： 2 层   第 287 个参数
# 第： 2 层   第 288 个参数
# 第： 2 层   第 289 个参数
# 第： 2 层   第 290 个参数
# 第： 2 层   第 291 个参数
# 第： 2 层   第 292 个参数
# 第： 2 层   第 293 个参数
# 第： 2 层   第 294 个参数
# 第： 2 层   第 295 个参数
# 第： 2 层   第 296 个参数
# 第： 2 层   第 297 个参数
# 第： 2 层   第 298 个参数
# 第： 2 层   第 299 个参数
# 第： 3 层   第 0 个参数
# 第： 3 层   第 1 个参数
# 第： 3 层   第 2 个参数
# 第： 3 层   第 3 个参数
# 第： 3 层   第 4 个参数
# 第： 3 层   第 5 个参数
# 第： 3 层   第 6 个参数
# 第： 3 层   第 7 个参数
# 第： 3 层   第 8 个参数
# 第： 3 层   第 9 个参数
# 第： 3 层   第 10 个参数
# 第： 3 层   第 11 个参数
# 第： 3 层   第 12 个参数
# 第： 3 层   第 13 个参数
# 第： 3 层   第 14 个参数
# 第： 3 层   第 15 个参数
# 第： 3 层   第 16 个参数
# 第： 3 层   第 17 个参数
# 第： 3 层   第 18 个参数
# 第： 3 层   第 19 个参数
# 第： 3 层   第 20 个参数
# 第： 3 层   第 21 个参数
# 第： 3 层   第 22 个参数
# 第： 3 层   第 23 个参数
# 第： 3 层   第 24 个参数
# 第： 3 层   第 25 个参数
# 第： 3 层   第 26 个参数
# 第： 3 层   第 27 个参数
# 第： 3 层   第 28 个参数
# 第： 3 层   第 29 个参数
# 第： 3 层   第 30 个参数
# 第： 3 层   第 31 个参数
# 第： 3 层   第 32 个参数
# 第： 3 层   第 33 个参数
# 第： 3 层   第 34 个参数
# 第： 3 层   第 35 个参数
# 第： 3 层   第 36 个参数
# 第： 3 层   第 37 个参数
# 第： 3 层   第 38 个参数
# 第： 3 层   第 39 个参数
# 第： 3 层   第 40 个参数
# 第： 3 层   第 41 个参数
# 第： 3 层   第 42 个参数
# 第： 3 层   第 43 个参数
# 第： 3 层   第 44 个参数
# 第： 3 层   第 45 个参数
# 第： 3 层   第 46 个参数
# 第： 3 层   第 47 个参数
# 第： 3 层   第 48 个参数
# 第： 3 层   第 49 个参数
# 第： 3 层   第 50 个参数
# 第： 3 层   第 51 个参数
# 第： 3 层   第 52 个参数
# 第： 3 层   第 53 个参数
# 第： 3 层   第 54 个参数
# 第： 3 层   第 55 个参数
# 第： 3 层   第 56 个参数
# 第： 3 层   第 57 个参数
# 第： 3 层   第 58 个参数
# 第： 3 层   第 59 个参数
# 第： 3 层   第 60 个参数
# 第： 3 层   第 61 个参数
# 第： 3 层   第 62 个参数
# 第： 3 层   第 63 个参数
# 第： 3 层   第 64 个参数
# 第： 3 层   第 65 个参数
# 第： 3 层   第 66 个参数
# 第： 3 层   第 67 个参数
# 第： 3 层   第 68 个参数
# 第： 3 层   第 69 个参数
# 第： 3 层   第 70 个参数
# 第： 3 层   第 71 个参数
# 第： 3 层   第 72 个参数
# 第： 3 层   第 73 个参数
# 第： 3 层   第 74 个参数
# 第： 3 层   第 75 个参数
# 第： 3 层   第 76 个参数
# 第： 3 层   第 77 个参数
# 第： 3 层   第 78 个参数
# 第： 3 层   第 79 个参数
# 第： 3 层   第 80 个参数
# 第： 3 层   第 81 个参数
# 第： 3 层   第 82 个参数
# 第： 3 层   第 83 个参数
# 第： 3 层   第 84 个参数
# 第： 3 层   第 85 个参数
# 第： 3 层   第 86 个参数
# 第： 3 层   第 87 个参数
# 第： 3 层   第 88 个参数
# 第： 3 层   第 89 个参数
# 第： 3 层   第 90 个参数
# 第： 3 层   第 91 个参数
# 第： 3 层   第 92 个参数
# 第： 3 层   第 93 个参数
# 第： 3 层   第 94 个参数
# 第： 3 层   第 95 个参数
# 第： 3 层   第 96 个参数
# 第： 3 层   第 97 个参数
# 第： 3 层   第 98 个参数
# 第： 3 层   第 99 个参数
# 第： 3 层   第 100 个参数
# 第： 3 层   第 101 个参数
# 第： 3 层   第 102 个参数
# 第： 3 层   第 103 个参数
# 第： 3 层   第 104 个参数
# 第： 3 层   第 105 个参数
# 第： 3 层   第 106 个参数
# 第： 3 层   第 107 个参数
# 第： 3 层   第 108 个参数
# 第： 3 层   第 109 个参数
# 第： 3 层   第 110 个参数
# 第： 3 层   第 111 个参数
# 第： 3 层   第 112 个参数
# 第： 3 层   第 113 个参数
# 第： 3 层   第 114 个参数
# 第： 3 层   第 115 个参数
# 第： 3 层   第 116 个参数
# 第： 3 层   第 117 个参数
# 第： 3 层   第 118 个参数
# 第： 3 层   第 119 个参数
# 第： 3 层   第 120 个参数
# 第： 3 层   第 121 个参数
# 第： 3 层   第 122 个参数
# 第： 3 层   第 123 个参数
# 第： 3 层   第 124 个参数
# 第： 3 层   第 125 个参数
# 第： 3 层   第 126 个参数
# 第： 3 层   第 127 个参数
# 第： 3 层   第 128 个参数
# 第： 3 层   第 129 个参数
# 第： 3 层   第 130 个参数
# 第： 3 层   第 131 个参数
# 第： 3 层   第 132 个参数
# 第： 3 层   第 133 个参数
# 第： 3 层   第 134 个参数
# 第： 3 层   第 135 个参数
# 第： 3 层   第 136 个参数
# 第： 3 层   第 137 个参数
# 第： 3 层   第 138 个参数
# 第： 3 层   第 139 个参数
# 第： 3 层   第 140 个参数
# 第： 3 层   第 141 个参数
# 第： 3 层   第 142 个参数
# 第： 3 层   第 143 个参数
# 第： 3 层   第 144 个参数
# 第： 3 层   第 145 个参数
# 第： 3 层   第 146 个参数
# 第： 3 层   第 147 个参数
# 第： 3 层   第 148 个参数
# 第： 3 层   第 149 个参数
# 第： 3 层   第 150 个参数
# 第： 3 层   第 151 个参数
# 第： 3 层   第 152 个参数
# 第： 3 层   第 153 个参数
# 第： 3 层   第 154 个参数
# 第： 3 层   第 155 个参数
# 第： 3 层   第 156 个参数
# 第： 3 层   第 157 个参数
# 第： 3 层   第 158 个参数
# 第： 3 层   第 159 个参数
# 第： 3 层   第 160 个参数
# 第： 3 层   第 161 个参数
# 第： 3 层   第 162 个参数
# 第： 3 层   第 163 个参数
# 第： 3 层   第 164 个参数
# 第： 3 层   第 165 个参数
# 第： 3 层   第 166 个参数
# 第： 3 层   第 167 个参数
# 第： 3 层   第 168 个参数
# 第： 3 层   第 169 个参数
# 第： 3 层   第 170 个参数
# 第： 3 层   第 171 个参数
# 第： 3 层   第 172 个参数
# 第： 3 层   第 173 个参数
# 第： 3 层   第 174 个参数
# 第： 3 层   第 175 个参数
# 第： 3 层   第 176 个参数
# 第： 3 层   第 177 个参数
# 第： 3 层   第 178 个参数
# 第： 3 层   第 179 个参数
# 第： 3 层   第 180 个参数
# 第： 3 层   第 181 个参数
# 第： 3 层   第 182 个参数
# 第： 3 层   第 183 个参数
# 第： 3 层   第 184 个参数
# 第： 3 层   第 185 个参数
# 第： 3 层   第 186 个参数
# 第： 3 层   第 187 个参数
# 第： 3 层   第 188 个参数
# 第： 3 层   第 189 个参数
# 第： 3 层   第 190 个参数
# 第： 3 层   第 191 个参数
# 第： 3 层   第 192 个参数
# 第： 3 层   第 193 个参数
# 第： 3 层   第 194 个参数
# 第： 3 层   第 195 个参数
# 第： 3 层   第 196 个参数
# 第： 3 层   第 197 个参数
# 第： 3 层   第 198 个参数
# 第： 3 层   第 199 个参数
# 第： 3 层   第 200 个参数
# 第： 3 层   第 201 个参数
# 第： 3 层   第 202 个参数
# 第： 3 层   第 203 个参数
# 第： 3 层   第 204 个参数
# 第： 3 层   第 205 个参数
# 第： 3 层   第 206 个参数
# 第： 3 层   第 207 个参数
# 第： 3 层   第 208 个参数
# 第： 3 层   第 209 个参数
# 第： 3 层   第 210 个参数
# 第： 3 层   第 211 个参数
# 第： 3 层   第 212 个参数
# 第： 3 层   第 213 个参数
# 第： 3 层   第 214 个参数
# 第： 3 层   第 215 个参数
# 第： 3 层   第 216 个参数
# 第： 3 层   第 217 个参数
# 第： 3 层   第 218 个参数
# 第： 3 层   第 219 个参数
# 第： 3 层   第 220 个参数
# 第： 3 层   第 221 个参数
# 第： 3 层   第 222 个参数
# 第： 3 层   第 223 个参数
# 第： 3 层   第 224 个参数
# 第： 3 层   第 225 个参数
# 第： 3 层   第 226 个参数
# 第： 3 层   第 227 个参数
# 第： 3 层   第 228 个参数
# 第： 3 层   第 229 个参数
# 第： 3 层   第 230 个参数
# 第： 3 层   第 231 个参数
# 第： 3 层   第 232 个参数
# 第： 3 层   第 233 个参数
# 第： 3 层   第 234 个参数
# 第： 3 层   第 235 个参数
# 第： 3 层   第 236 个参数
# 第： 3 层   第 237 个参数
# 第： 3 层   第 238 个参数
# 第： 3 层   第 239 个参数
# 第： 3 层   第 240 个参数
# 第： 3 层   第 241 个参数
# 第： 3 层   第 242 个参数
# 第： 3 层   第 243 个参数
# 第： 3 层   第 244 个参数
# 第： 3 层   第 245 个参数
# 第： 3 层   第 246 个参数
# 第： 3 层   第 247 个参数
# 第： 3 层   第 248 个参数
# 第： 3 层   第 249 个参数
# 第： 3 层   第 250 个参数
# 第： 3 层   第 251 个参数
# 第： 3 层   第 252 个参数
# 第： 3 层   第 253 个参数
# 第： 3 层   第 254 个参数
# 第： 3 层   第 255 个参数
# 第： 3 层   第 256 个参数
# 第： 3 层   第 257 个参数
# 第： 3 层   第 258 个参数
# 第： 3 层   第 259 个参数
# 第： 3 层   第 260 个参数
# 第： 3 层   第 261 个参数
# 第： 3 层   第 262 个参数
# 第： 3 层   第 263 个参数
# 第： 3 层   第 264 个参数
# 第： 3 层   第 265 个参数
# 第： 3 层   第 266 个参数
# 第： 3 层   第 267 个参数
# 第： 3 层   第 268 个参数
# 第： 3 层   第 269 个参数
# 第： 3 层   第 270 个参数
# 第： 3 层   第 271 个参数
# 第： 3 层   第 272 个参数
# 第： 3 层   第 273 个参数
# 第： 3 层   第 274 个参数
# 第： 3 层   第 275 个参数
# 第： 3 层   第 276 个参数
# 第： 3 层   第 277 个参数
# 第： 3 层   第 278 个参数
# 第： 3 层   第 279 个参数
# 第： 3 层   第 280 个参数
# 第： 3 层   第 281 个参数
# 第： 3 层   第 282 个参数
# 第： 3 层   第 283 个参数
# 第： 3 层   第 284 个参数
# 第： 3 层   第 285 个参数
# 第： 3 层   第 286 个参数
# 第： 3 层   第 287 个参数
# 第： 3 层   第 288 个参数
# 第： 3 层   第 289 个参数
# 第： 3 层   第 290 个参数
# 第： 3 层   第 291 个参数
# 第： 3 层   第 292 个参数
# 第： 3 层   第 293 个参数
# 第： 3 层   第 294 个参数
# 第： 3 层   第 295 个参数
# 第： 3 层   第 296 个参数
# 第： 3 层   第 297 个参数
# 第： 3 层   第 298 个参数
# 第： 3 层   第 299 个参数
# 第： 4 层   第 0 个参数
# 第： 4 层   第 1 个参数
# 第： 4 层   第 2 个参数
# 第： 4 层   第 3 个参数
# 第： 4 层   第 4 个参数
# 第： 4 层   第 5 个参数
# 第： 4 层   第 6 个参数
# 第： 4 层   第 7 个参数
# 第： 4 层   第 8 个参数
# 第： 4 层   第 9 个参数
# 第： 4 层   第 10 个参数
# 第： 4 层   第 11 个参数
# 第： 4 层   第 12 个参数
# 第： 4 层   第 13 个参数
# 第： 4 层   第 14 个参数
# 第： 4 层   第 15 个参数
# 第： 4 层   第 16 个参数
# 第： 4 层   第 17 个参数
# 第： 4 层   第 18 个参数
# 第： 4 层   第 19 个参数
# 第： 4 层   第 20 个参数
# 第： 4 层   第 21 个参数
# 第： 4 层   第 22 个参数
# 第： 4 层   第 23 个参数
# 第： 4 层   第 24 个参数
# 第： 4 层   第 25 个参数
# 第： 4 层   第 26 个参数
# 第： 4 层   第 27 个参数
# 第： 4 层   第 28 个参数
# 第： 4 层   第 29 个参数
# 第： 4 层   第 30 个参数
# 第： 4 层   第 31 个参数
# 第： 4 层   第 32 个参数
# 第： 4 层   第 33 个参数
# 第： 4 层   第 34 个参数
# 第： 4 层   第 35 个参数
# 第： 4 层   第 36 个参数
# 第： 4 层   第 37 个参数
# 第： 4 层   第 38 个参数
# 第： 4 层   第 39 个参数
# 第： 4 层   第 40 个参数
# 第： 4 层   第 41 个参数
# 第： 4 层   第 42 个参数
# 第： 4 层   第 43 个参数
# 第： 4 层   第 44 个参数
# 第： 4 层   第 45 个参数
# 第： 4 层   第 46 个参数
# 第： 4 层   第 47 个参数
# 第： 4 层   第 48 个参数
# 第： 4 层   第 49 个参数
# 第： 4 层   第 50 个参数
# 第： 4 层   第 51 个参数
# 第： 4 层   第 52 个参数
# 第： 4 层   第 53 个参数
# 第： 4 层   第 54 个参数
# 第： 4 层   第 55 个参数
# 第： 4 层   第 56 个参数
# 第： 4 层   第 57 个参数
# 第： 4 层   第 58 个参数
# 第： 4 层   第 59 个参数
# 第： 4 层   第 60 个参数
# 第： 4 层   第 61 个参数
# 第： 4 层   第 62 个参数
# 第： 4 层   第 63 个参数
# 第： 4 层   第 64 个参数
# 第： 4 层   第 65 个参数
# 第： 4 层   第 66 个参数
# 第： 4 层   第 67 个参数
# 第： 4 层   第 68 个参数
# 第： 4 层   第 69 个参数
# 第： 4 层   第 70 个参数
# 第： 4 层   第 71 个参数
# 第： 4 层   第 72 个参数
# 第： 4 层   第 73 个参数
# 第： 4 层   第 74 个参数
# 第： 4 层   第 75 个参数
# 第： 4 层   第 76 个参数
# 第： 4 层   第 77 个参数
# 第： 4 层   第 78 个参数
# 第： 4 层   第 79 个参数
# 第： 4 层   第 80 个参数
# 第： 4 层   第 81 个参数
# 第： 4 层   第 82 个参数
# 第： 4 层   第 83 个参数
# 第： 4 层   第 84 个参数
# 第： 4 层   第 85 个参数
# 第： 4 层   第 86 个参数
# 第： 4 层   第 87 个参数
# 第： 4 层   第 88 个参数
# 第： 4 层   第 89 个参数
# 第： 4 层   第 90 个参数
# 第： 4 层   第 91 个参数
# 第： 4 层   第 92 个参数
# 第： 4 层   第 93 个参数
# 第： 4 层   第 94 个参数
# 第： 4 层   第 95 个参数
# 第： 4 层   第 96 个参数
# 第： 4 层   第 97 个参数
# 第： 4 层   第 98 个参数
# 第： 4 层   第 99 个参数
# 第： 4 层   第 100 个参数
# 第： 4 层   第 101 个参数
# 第： 4 层   第 102 个参数
# 第： 4 层   第 103 个参数
# 第： 4 层   第 104 个参数
# 第： 4 层   第 105 个参数
# 第： 4 层   第 106 个参数
# 第： 4 层   第 107 个参数
# 第： 4 层   第 108 个参数
# 第： 4 层   第 109 个参数
# 第： 4 层   第 110 个参数
# 第： 4 层   第 111 个参数
# 第： 4 层   第 112 个参数
# 第： 4 层   第 113 个参数
# 第： 4 层   第 114 个参数
# 第： 4 层   第 115 个参数
# 第： 4 层   第 116 个参数
# 第： 4 层   第 117 个参数
# 第： 4 层   第 118 个参数
# 第： 4 层   第 119 个参数
# 第： 4 层   第 120 个参数
# 第： 4 层   第 121 个参数
# 第： 4 层   第 122 个参数
# 第： 4 层   第 123 个参数
# 第： 4 层   第 124 个参数
# 第： 4 层   第 125 个参数
# 第： 4 层   第 126 个参数
# 第： 4 层   第 127 个参数
# 第： 4 层   第 128 个参数
# 第： 4 层   第 129 个参数
# 第： 4 层   第 130 个参数
# 第： 4 层   第 131 个参数
# 第： 4 层   第 132 个参数
# 第： 4 层   第 133 个参数
# 第： 4 层   第 134 个参数
# 第： 4 层   第 135 个参数
# 第： 4 层   第 136 个参数
# 第： 4 层   第 137 个参数
# 第： 4 层   第 138 个参数
# 第： 4 层   第 139 个参数
# 第： 4 层   第 140 个参数
# 第： 4 层   第 141 个参数
# 第： 4 层   第 142 个参数
# 第： 4 层   第 143 个参数
# 第： 4 层   第 144 个参数
# 第： 4 层   第 145 个参数
# 第： 4 层   第 146 个参数
# 第： 4 层   第 147 个参数
# 第： 4 层   第 148 个参数
# 第： 4 层   第 149 个参数
# 第： 4 层   第 150 个参数
# 第： 4 层   第 151 个参数
# 第： 4 层   第 152 个参数
# 第： 4 层   第 153 个参数
# 第： 4 层   第 154 个参数
# 第： 4 层   第 155 个参数
# 第： 4 层   第 156 个参数
# 第： 4 层   第 157 个参数
# 第： 4 层   第 158 个参数
# 第： 4 层   第 159 个参数
# 第： 4 层   第 160 个参数
# 第： 4 层   第 161 个参数
# 第： 4 层   第 162 个参数
# 第： 4 层   第 163 个参数
# 第： 4 层   第 164 个参数
# 第： 4 层   第 165 个参数
# 第： 4 层   第 166 个参数
# 第： 4 层   第 167 个参数
# 第： 4 层   第 168 个参数
# 第： 4 层   第 169 个参数
# 第： 4 层   第 170 个参数
# 第： 4 层   第 171 个参数
# 第： 4 层   第 172 个参数
# 第： 4 层   第 173 个参数
# 第： 4 层   第 174 个参数
# 第： 4 层   第 175 个参数
# 第： 4 层   第 176 个参数
# 第： 4 层   第 177 个参数
# 第： 4 层   第 178 个参数
# 第： 4 层   第 179 个参数
# 第： 4 层   第 180 个参数
# 第： 4 层   第 181 个参数
# 第： 4 层   第 182 个参数
# 第： 4 层   第 183 个参数
# 第： 4 层   第 184 个参数
# 第： 4 层   第 185 个参数
# 第： 4 层   第 186 个参数
# 第： 4 层   第 187 个参数
# 第： 4 层   第 188 个参数
# 第： 4 层   第 189 个参数
# 第： 4 层   第 190 个参数
# 第： 4 层   第 191 个参数
# 第： 4 层   第 192 个参数
# 第： 4 层   第 193 个参数
# 第： 4 层   第 194 个参数
# 第： 4 层   第 195 个参数
# 第： 4 层   第 196 个参数
# 第： 4 层   第 197 个参数
# 第： 4 层   第 198 个参数
# 第： 4 层   第 199 个参数
# 第： 4 层   第 200 个参数
# 第： 4 层   第 201 个参数
# 第： 4 层   第 202 个参数
# 第： 4 层   第 203 个参数
# 第： 4 层   第 204 个参数
# 第： 4 层   第 205 个参数
# 第： 4 层   第 206 个参数
# 第： 4 层   第 207 个参数
# 第： 4 层   第 208 个参数
# 第： 4 层   第 209 个参数
# 第： 4 层   第 210 个参数
# 第： 4 层   第 211 个参数
# 第： 4 层   第 212 个参数
# 第： 4 层   第 213 个参数
# 第： 4 层   第 214 个参数
# 第： 4 层   第 215 个参数
# 第： 4 层   第 216 个参数
# 第： 4 层   第 217 个参数
# 第： 4 层   第 218 个参数
# 第： 4 层   第 219 个参数
# 第： 4 层   第 220 个参数
# 第： 4 层   第 221 个参数
# 第： 4 层   第 222 个参数
# 第： 4 层   第 223 个参数
# 第： 4 层   第 224 个参数
# 第： 4 层   第 225 个参数
# 第： 4 层   第 226 个参数
# 第： 4 层   第 227 个参数
# 第： 4 层   第 228 个参数
# 第： 4 层   第 229 个参数
# 第： 4 层   第 230 个参数
# 第： 4 层   第 231 个参数
# 第： 4 层   第 232 个参数
# 第： 4 层   第 233 个参数
# 第： 4 层   第 234 个参数
# 第： 4 层   第 235 个参数
# 第： 4 层   第 236 个参数
# 第： 4 层   第 237 个参数
# 第： 4 层   第 238 个参数
# 第： 4 层   第 239 个参数
# 第： 4 层   第 240 个参数
# 第： 4 层   第 241 个参数
# 第： 4 层   第 242 个参数
# 第： 4 层   第 243 个参数
# 第： 4 层   第 244 个参数
# 第： 4 层   第 245 个参数
# 第： 4 层   第 246 个参数
# 第： 4 层   第 247 个参数
# 第： 4 层   第 248 个参数
# 第： 4 层   第 249 个参数
# 第： 4 层   第 250 个参数
# 第： 4 层   第 251 个参数
# 第： 4 层   第 252 个参数
# 第： 4 层   第 253 个参数
# 第： 4 层   第 254 个参数
# 第： 4 层   第 255 个参数
# 第： 4 层   第 256 个参数
# 第： 4 层   第 257 个参数
# 第： 4 层   第 258 个参数
# 第： 4 层   第 259 个参数
# 第： 4 层   第 260 个参数
# 第： 4 层   第 261 个参数
# 第： 4 层   第 262 个参数
# 第： 4 层   第 263 个参数
# 第： 4 层   第 264 个参数
# 第： 4 层   第 265 个参数
# 第： 4 层   第 266 个参数
# 第： 4 层   第 267 个参数
# 第： 4 层   第 268 个参数
# 第： 4 层   第 269 个参数
# 第： 4 层   第 270 个参数
# 第： 4 层   第 271 个参数
# 第： 4 层   第 272 个参数
# 第： 4 层   第 273 个参数
# 第： 4 层   第 274 个参数
# 第： 4 层   第 275 个参数
# 第： 4 层   第 276 个参数
# 第： 4 层   第 277 个参数
# 第： 4 层   第 278 个参数
# 第： 4 层   第 279 个参数
# 第： 4 层   第 280 个参数
# 第： 4 层   第 281 个参数
# 第： 4 层   第 282 个参数
# 第： 4 层   第 283 个参数
# 第： 4 层   第 284 个参数
# 第： 4 层   第 285 个参数
# 第： 4 层   第 286 个参数
# 第： 4 层   第 287 个参数
# 第： 4 层   第 288 个参数
# 第： 4 层   第 289 个参数
# 第： 4 层   第 290 个参数
# 第： 4 层   第 291 个参数
# 第： 4 层   第 292 个参数
# 第： 4 层   第 293 个参数
# 第： 4 层   第 294 个参数
# 第： 4 层   第 295 个参数
# 第： 4 层   第 296 个参数
# 第： 4 层   第 297 个参数
# 第： 4 层   第 298 个参数
# 第： 4 层   第 299 个参数
# 第： 5 层   第 0 个参数
# 第： 5 层   第 1 个参数
# 第： 5 层   第 2 个参数
# 第： 5 层   第 3 个参数
# 第： 5 层   第 4 个参数
# 第： 5 层   第 5 个参数
# 第： 5 层   第 6 个参数
# 第： 5 层   第 7 个参数
# 第： 5 层   第 8 个参数
# 第： 5 层   第 9 个参数
# 第： 5 层   第 10 个参数
# 第： 5 层   第 11 个参数
# 第： 5 层   第 12 个参数
# 第： 5 层   第 13 个参数
# 第： 5 层   第 14 个参数
# 第： 5 层   第 15 个参数
# 第： 5 层   第 16 个参数
# 第： 5 层   第 17 个参数
# 第： 5 层   第 18 个参数
# 第： 5 层   第 19 个参数
# 第： 5 层   第 20 个参数
# 第： 5 层   第 21 个参数
# 第： 5 层   第 22 个参数
# 第： 5 层   第 23 个参数
# 第： 5 层   第 24 个参数
# 第： 5 层   第 25 个参数
# 第： 5 层   第 26 个参数
# 第： 5 层   第 27 个参数
# 第： 5 层   第 28 个参数
# 第： 5 层   第 29 个参数
# 第： 5 层   第 30 个参数
# 第： 5 层   第 31 个参数
# 第： 5 层   第 32 个参数
# 第： 5 层   第 33 个参数
# 第： 5 层   第 34 个参数
# 第： 5 层   第 35 个参数
# 第： 5 层   第 36 个参数
# 第： 5 层   第 37 个参数
# 第： 5 层   第 38 个参数
# 第： 5 层   第 39 个参数
# 第： 5 层   第 40 个参数
# 第： 5 层   第 41 个参数
# 第： 5 层   第 42 个参数
# 第： 5 层   第 43 个参数
# 第： 5 层   第 44 个参数
# 第： 5 层   第 45 个参数
# 第： 5 层   第 46 个参数
# 第： 5 层   第 47 个参数
# 第： 5 层   第 48 个参数
# 第： 5 层   第 49 个参数
# 第： 5 层   第 50 个参数
# 第： 5 层   第 51 个参数
# 第： 5 层   第 52 个参数
# 第： 5 层   第 53 个参数
# 第： 5 层   第 54 个参数
# 第： 5 层   第 55 个参数
# 第： 5 层   第 56 个参数
# 第： 5 层   第 57 个参数
# 第： 5 层   第 58 个参数
# 第： 5 层   第 59 个参数
# 第： 5 层   第 60 个参数
# 第： 5 层   第 61 个参数
# 第： 5 层   第 62 个参数
# 第： 5 层   第 63 个参数
# 第： 5 层   第 64 个参数
# 第： 5 层   第 65 个参数
# 第： 5 层   第 66 个参数
# 第： 5 层   第 67 个参数
# 第： 5 层   第 68 个参数
# 第： 5 层   第 69 个参数
# 第： 5 层   第 70 个参数
# 第： 5 层   第 71 个参数
# 第： 5 层   第 72 个参数
# 第： 5 层   第 73 个参数
# 第： 5 层   第 74 个参数
# 第： 5 层   第 75 个参数
# 第： 5 层   第 76 个参数
# 第： 5 层   第 77 个参数
# 第： 5 层   第 78 个参数
# 第： 5 层   第 79 个参数
# 第： 5 层   第 80 个参数
# 第： 5 层   第 81 个参数
# 第： 5 层   第 82 个参数
# 第： 5 层   第 83 个参数
# 第： 5 层   第 84 个参数
# 第： 5 层   第 85 个参数
# 第： 5 层   第 86 个参数
# 第： 5 层   第 87 个参数
# 第： 5 层   第 88 个参数
# 第： 5 层   第 89 个参数
# 第： 5 层   第 90 个参数
# 第： 5 层   第 91 个参数
# 第： 5 层   第 92 个参数
# 第： 5 层   第 93 个参数
# 第： 5 层   第 94 个参数
# 第： 5 层   第 95 个参数
# 第： 5 层   第 96 个参数
# 第： 5 层   第 97 个参数
# 第： 5 层   第 98 个参数
# 第： 5 层   第 99 个参数
# 第： 5 层   第 100 个参数
# 第： 5 层   第 101 个参数
# 第： 5 层   第 102 个参数
# 第： 5 层   第 103 个参数
# 第： 5 层   第 104 个参数
# 第： 5 层   第 105 个参数
# 第： 5 层   第 106 个参数
# 第： 5 层   第 107 个参数
# 第： 5 层   第 108 个参数
# 第： 5 层   第 109 个参数
# 第： 5 层   第 110 个参数
# 第： 5 层   第 111 个参数
# 第： 5 层   第 112 个参数
# 第： 5 层   第 113 个参数
# 第： 5 层   第 114 个参数
# 第： 5 层   第 115 个参数
# 第： 5 层   第 116 个参数
# 第： 5 层   第 117 个参数
# 第： 5 层   第 118 个参数
# 第： 5 层   第 119 个参数
# 第： 5 层   第 120 个参数
# 第： 5 层   第 121 个参数
# 第： 5 层   第 122 个参数
# 第： 5 层   第 123 个参数
# 第： 5 层   第 124 个参数
# 第： 5 层   第 125 个参数
# 第： 5 层   第 126 个参数
# 第： 5 层   第 127 个参数
# 第： 5 层   第 128 个参数
# 第： 5 层   第 129 个参数
# 第： 5 层   第 130 个参数
# 第： 5 层   第 131 个参数
# 第： 5 层   第 132 个参数
# 第： 5 层   第 133 个参数
# 第： 5 层   第 134 个参数
# 第： 5 层   第 135 个参数
# 第： 5 层   第 136 个参数
# 第： 5 层   第 137 个参数
# 第： 5 层   第 138 个参数
# 第： 5 层   第 139 个参数
# 第： 5 层   第 140 个参数
# 第： 5 层   第 141 个参数
# 第： 5 层   第 142 个参数
# 第： 5 层   第 143 个参数
# 第： 5 层   第 144 个参数
# 第： 5 层   第 145 个参数
# 第： 5 层   第 146 个参数
# 第： 5 层   第 147 个参数
# 第： 5 层   第 148 个参数
# 第： 5 层   第 149 个参数
# 第： 5 层   第 150 个参数
# 第： 5 层   第 151 个参数
# 第： 5 层   第 152 个参数
# 第： 5 层   第 153 个参数
# 第： 5 层   第 154 个参数
# 第： 5 层   第 155 个参数
# 第： 5 层   第 156 个参数
# 第： 5 层   第 157 个参数
# 第： 5 层   第 158 个参数
# 第： 5 层   第 159 个参数
# 第： 5 层   第 160 个参数
# 第： 5 层   第 161 个参数
# 第： 5 层   第 162 个参数
# 第： 5 层   第 163 个参数
# 第： 5 层   第 164 个参数
# 第： 5 层   第 165 个参数
# 第： 5 层   第 166 个参数
# 第： 5 层   第 167 个参数
# 第： 5 层   第 168 个参数
# 第： 5 层   第 169 个参数
# 第： 5 层   第 170 个参数
# 第： 5 层   第 171 个参数
# 第： 5 层   第 172 个参数
# 第： 5 层   第 173 个参数
# 第： 5 层   第 174 个参数
# 第： 5 层   第 175 个参数
# 第： 5 层   第 176 个参数
# 第： 5 层   第 177 个参数
# 第： 5 层   第 178 个参数
# 第： 5 层   第 179 个参数
# 第： 5 层   第 180 个参数
# 第： 5 层   第 181 个参数
# 第： 5 层   第 182 个参数
# 第： 5 层   第 183 个参数
# 第： 5 层   第 184 个参数
# 第： 5 层   第 185 个参数
# 第： 5 层   第 186 个参数
# 第： 5 层   第 187 个参数
# 第： 5 层   第 188 个参数
# 第： 5 层   第 189 个参数
# 第： 5 层   第 190 个参数
# 第： 5 层   第 191 个参数
# 第： 5 层   第 192 个参数
# 第： 5 层   第 193 个参数
# 第： 5 层   第 194 个参数
# 第： 5 层   第 195 个参数
# 第： 5 层   第 196 个参数
# 第： 5 层   第 197 个参数
# 第： 5 层   第 198 个参数
# 第： 5 层   第 199 个参数
# 第： 5 层   第 200 个参数
# 第： 5 层   第 201 个参数
# 第： 5 层   第 202 个参数
# 第： 5 层   第 203 个参数
# 第： 5 层   第 204 个参数
# 第： 5 层   第 205 个参数
# 第： 5 层   第 206 个参数
# 第： 5 层   第 207 个参数
# 第： 5 层   第 208 个参数
# 第： 5 层   第 209 个参数
# 第： 5 层   第 210 个参数
# 第： 5 层   第 211 个参数
# 第： 5 层   第 212 个参数
# 第： 5 层   第 213 个参数
# 第： 5 层   第 214 个参数
# 第： 5 层   第 215 个参数
# 第： 5 层   第 216 个参数
# 第： 5 层   第 217 个参数
# 第： 5 层   第 218 个参数
# 第： 5 层   第 219 个参数
# 第： 5 层   第 220 个参数
# 第： 5 层   第 221 个参数
# 第： 5 层   第 222 个参数
# 第： 5 层   第 223 个参数
# 第： 5 层   第 224 个参数
# 第： 5 层   第 225 个参数
# 第： 5 层   第 226 个参数
# 第： 5 层   第 227 个参数
# 第： 5 层   第 228 个参数
# 第： 5 层   第 229 个参数
# 第： 5 层   第 230 个参数
# 第： 5 层   第 231 个参数
# 第： 5 层   第 232 个参数
# 第： 5 层   第 233 个参数
# 第： 5 层   第 234 个参数
# 第： 5 层   第 235 个参数
# 第： 5 层   第 236 个参数
# 第： 5 层   第 237 个参数
# 第： 5 层   第 238 个参数
# 第： 5 层   第 239 个参数
# 第： 5 层   第 240 个参数
# 第： 5 层   第 241 个参数
# 第： 5 层   第 242 个参数
# 第： 5 层   第 243 个参数
# 第： 5 层   第 244 个参数
# 第： 5 层   第 245 个参数
# 第： 5 层   第 246 个参数
# 第： 5 层   第 247 个参数
# 第： 5 层   第 248 个参数
# 第： 5 层   第 249 个参数
# 第： 5 层   第 250 个参数
# 第： 5 层   第 251 个参数
# 第： 5 层   第 252 个参数
# 第： 5 层   第 253 个参数
# 第： 5 层   第 254 个参数
# 第： 5 层   第 255 个参数
# 第： 5 层   第 256 个参数
# 第： 5 层   第 257 个参数
# 第： 5 层   第 258 个参数
# 第： 5 层   第 259 个参数
# 第： 5 层   第 260 个参数
# 第： 5 层   第 261 个参数
# 第： 5 层   第 262 个参数
# 第： 5 层   第 263 个参数
# 第： 5 层   第 264 个参数
# 第： 5 层   第 265 个参数
# 第： 5 层   第 266 个参数
# 第： 5 层   第 267 个参数
# 第： 5 层   第 268 个参数
# 第： 5 层   第 269 个参数
# 第： 5 层   第 270 个参数
# 第： 5 层   第 271 个参数
# 第： 5 层   第 272 个参数
# 第： 5 层   第 273 个参数
# 第： 5 层   第 274 个参数
# 第： 5 层   第 275 个参数
# 第： 5 层   第 276 个参数
# 第： 5 层   第 277 个参数
# 第： 5 层   第 278 个参数
# 第： 5 层   第 279 个参数
# 第： 5 层   第 280 个参数
# 第： 5 层   第 281 个参数
# 第： 5 层   第 282 个参数
# 第： 5 层   第 283 个参数
# 第： 5 层   第 284 个参数
# 第： 5 层   第 285 个参数
# 第： 5 层   第 286 个参数
# 第： 5 层   第 287 个参数
# 第： 5 层   第 288 个参数
# 第： 5 层   第 289 个参数
# 第： 5 层   第 290 个参数
# 第： 5 层   第 291 个参数
# 第： 5 层   第 292 个参数
# 第： 5 层   第 293 个参数
# 第： 5 层   第 294 个参数
# 第： 5 层   第 295 个参数
# 第： 5 层   第 296 个参数
# 第： 5 层   第 297 个参数
# 第： 5 层   第 298 个参数
# 第： 5 层   第 299 个参数

# %%
# 输出结果
print("运行时间：",endTime - startTime)
print("Optimal parameters:", final_result_xy.x)
print("Optimal value:", final_result_xy.fun)
# 使用最优参数运行量子电路并输出测量结果
final_expectation_xy, final_counts_xy = cost_function_xy(final_result_xy.x, n, m, l, K1, P, p, optimal_params)
# sorted_dict = dict(sorted(final_counts.items(), key=lambda item: item[1], reverse=True))
sorted_dict_xy = {item[0][::-1]: item[1] for item in sorted(counts_xy.items(), key=lambda item: item[1], reverse=True)}
print("Final expectation value:", final_expectation_xy)
print("Final measurement counts:", sorted_dict_xy)
# Out:
# 运行时间： 8523.170581102371
# Optimal parameters: [20.00659632 18.14465172 11.32225747  8.86471315  3.99856717  7.90032915
#   5.70715527  6.91925512  9.08237157  1.71143889]
# Optimal value: 25.773099999999996
# Final expectation value: 25.773099999999996
# Final measurement counts: {'1000100': 4083, '1000101': 3042, '0010101': 700, '1000011': 432, '0100011': 367, '0100010': 348, '0011001': 217, '0010100': 136, '0100101': 119, '1000010': 63, '0011000': 61, '0100100': 53, '0010010': 41, '0010011': 40, '0101000': 39, '1001001': 38, '0101001': 37, '1001000': 15, '0010111': 13, '1000110': 11, '0110010': 10, '1000111': 9, '0011100': 9, '1100101': 8, '0111001': 8, '1100011': 8, '1011001': 6, '1110011': 6, '1011000': 5, '1100010': 5, '0110101': 5, '0000011': 5, '1001100': 5, '0000100': 5, '0101111': 5, '0110100': 4, '0000101': 4, '1101000': 3, '0100111': 3, '0100001': 3, '0101110': 3, '1000000': 3, '0100000': 3, '1110010': 2, '1010100': 2, '0111000': 1, '0001101': 1, '0010000': 1, '0011011': 1, '1001010': 1, '0011010': 1, '0010110': 1, '1010110': 1, '0000010': 1, '0100110': 1, '0011101': 1, '1110100': 1, '1001011': 1, '0101101': 1, '0001000': 1, '1110101': 1}

# %%
# 计算最终的能量

energy, counts_temp = cost_function_xy(final_result_xy.x, n, m, l, K1, P, p,optimal_params)
plot_histogram(counts_temp)
print(energy)
print(counts_temp)

# %%
expectation = 0
bitstring = "0010011"
z_h = np.array([int(bit) for bit in bitstring[(n*m):]])
x_ij = np.array([int(bit) for bit in bitstring[:(n*m)]]).reshape(n, m)

E1 = np.sum([2 ** h * z for h, z in enumerate(z_h)])
E2 = K1 * np.sum([(np.sum(x_ij[i]) - 1) ** 2 for i in range(n)])
# alpha_s = np.max([0, np.sum(x_ij * p) - np.sum([2 ** h * z for h, z in enumerate(z_h)])])
E3 = 0
e1=0
e2=0
for j in range(m):

    sum_xp = np.sum([x_ij[i][j] * p[i][j] for i in range(n)])

    sum_zh = np.sum([2**h * z_h[h] for h in range(l)])

    max_value = max(0, sum_xp - sum_zh)
    e1+=sum_xp
    e2+=sum_zh
    E3 += P * (max_value)**2
E =  E1 + E2 + E3
print(E1)
print(E2)
print(E3)
# print(e1)
# print(e2)
