# %%
import numpy as np

# 假设有 3 台机器和 3 个操作
m = 3  # 机器数量
N = 2  # 表示机器的二进制 (0, 1)
n = 2  # 操作数量
l = 1  # 用于表示 C_max 的二进制位数

# 处理时间矩阵 (例如)
p = np.array([[3, 1, 3], [2, 3, 1]])

b = np.array([[0, 0], [1, 0], [0, 1]])
# 非法数组(用于表示机器数)(1, 1)
bw = np.array([[1, 1]])
# 常数
K1 = 100
P = 30
# print(len(bw))
# 量子比特数量
num_qubits = n * N + l

# %%
def append_multi_rzz_term(qc, qubits, gamma):
    """
    实现多体 Z 相互作用项 e^{-i \gamma Z_1 Z_2 \dots Z_k}.
    """
    if len(qubits) == 1:
        qc.rz(2 * gamma, qubits[0])
        return

    # 链式 CNOT 到最后一个量子比特
    for q in qubits[:-1]:
        qc.cx(q, qubits[-1])

    # 应用 RZ 门
    qc.rz(2 * gamma, qubits[-1])

    # 恢复链式 CNOT
    for q in reversed(qubits[:-1]):
        qc.cx(q, qubits[-1])

# %%
def append__zz_term(qc, qubit1, qubit2, gamma):
    qc.cx(qubit1, qubit2)
    qc.rz(gamma, qubit2)
    qc.cx(qubit1, qubit2)


def append__z_term(qc, qubit, gamma):
    qc.rz(gamma, qubit)


def append__mixer_term(qc, qubit, beta):
    qc.rx(2 * beta, qubit)

# %%
def get_cost_circuit1(gamma, qc):
    for h in range(l):
        coef = - 2 ** h
        append__z_term(qc, N * n + h, coef * gamma)
    return qc

# %% [markdown]
# \begin{align}K_{1} \sum_{j\in W} \sum_{i=0}^{n}\prod_{k=0}^{N}\left(\frac{1}2+\left(\frac{1}2-b_{j k}\right)Z_{ik}\right)\end{align}

# %%
import itertools


def get_cost_circuit2(gamma, qc):
    # print(len(bw))
    if len(bw) == 0:
        return qc
    all_combinations = list(itertools.chain(*(itertools.combinations(range(N), r) for r in range(1, N + 1))))
    for j in range(len(bw)):
        for i in range(n):
            constant = 1 / (2 ** N)  # 系数 1/2^N  
            for qubit_indices in all_combinations:  # 遍历各种组合
                qubits_index = np.array([], dtype=int)
                # 根据组合项生成子项的常数和qubit索引
                for k in range(N):
                    constant *= (1 - 2 * bw[j, k]) if k in qubit_indices else 1
                    if k in qubit_indices:
                        qubits_index = np.append(qubits_index, i * N + k)
                # print("qubits_index", qubits_index)
                append_multi_rzz_term(qc, qubits_index, K1 * constant * gamma)
    return qc

# %% [markdown]
# \begin{align}\sum_{j=0}^{m-1}\sum_{i=0}^{n-1} \sum_{i^{\prime}=0}^{n-1}\left(\prod_{k=0}^{N-1}\frac{1}{2}\left(1+\left(1-2b_{j k}\right) Z_{i k}\right)\right) p_{i j}\left(\prod_{k^{\prime}=0}^{N-1}\frac{1}{2}\left(1+\left(1-2b_{j k}\right) Z_{i^{\prime} k^{\prime}}\right)\right) p_{i^{\prime} j}\end{align}
# \begin{align}-2 \sum_{j=0}^{m-1} \sum_{i=0}^{n-1} \sum_{h=0}^{l-1} \left(\prod_{k=0}^{N-1}\frac{1}{2}\left(1+\left(1-2b_{j k}\right) Z_{i k}\right)\right) p_{i j} \cdot 2^{h-1}\left(1-Z_h\right)\end{align}
# \begin{align}\sum_{j=0}^{m-1}\sum_{h=0}^{l-1} \sum_{h^{\prime}=0}^{l-1} 2^{h-1} 2^{h^{\prime}-1}\left(1-Z_h-Z_{h^{\prime}}+Z_h Z_{h^{\prime}}\right)\end{align}

# %%
# import itertools
from collections import Counter


def get_cost_circuit3(gamma, qc):
    for j in range(len(b)):
        # 对应12, 13, 23, 45, 46, 56
        for i in range(n):  # 自身内部相乘，对应12, 13, 23, 45, 46, 56
            all_combinations_1 = list(itertools.chain(*(itertools.combinations(range(N), r) for r in range(1, N + 1))))
            # 获取 all_combinations_1 中任意两项的所有组合
            all_two_combinations = list(itertools.combinations(all_combinations_1, 2))
            for qubit_indices in all_two_combinations:  # 遍历各种组合
                # print("qubit_indices", qubit_indices)
                # sub_constant = constant
                qubits_index = np.array([], dtype=int)
                constant = 1
                # 将组合对中的每个元素（每个元素本身也是一个组合）放入数组
                for combo in qubit_indices:  # qubit_indices: ((0,), (1,))
                    for k in combo:  # combo: (0,)
                        constant = constant * (1 - 2 * b[j, k])
                        qubits_index = np.append(qubits_index, i * N + k)
                    # 将组合项中的所有元素添加到 qubits_index 中
                # 剔除出现偶次数的项，奇次数的项保留一个

                count = Counter(qubits_index)
                # 仅保留出现次数为奇数的元素一次
                qubits_index = [x for x in count if count[x] % 2 != 0]
                # print("qubits_index", qubits_index)
                constant = 1 / (2 ** (2 * N)) * constant * p[i, j] * p[i, j]
                append_multi_rzz_term(qc, qubits_index, P * constant * gamma)

        # 2，对应14, 15, 16, 24, 25, 26, 34, 35, 36
        all_combinations_1 = list(itertools.chain(*(itertools.combinations(range(N), r) for r in range(1, N + 1))))
        all_combinations_2 = list(itertools.chain(*(itertools.combinations(range(N), r) for r in range(1, N + 1))))
        for i1 in range(n - 1):  # 自身内部相乘，对应14, 15, 16, 24, 25, 26, 34, 35, 36
            for i2 in range(i1 + 1, n):  # 自身内部相乘，对应23, 45, 46, 56
                for qubit_indices_1 in all_combinations_1:
                    # print("qubit_indices1", qubit_indices_1)
                    for qubit_indices_2 in all_combinations_2:
                        # print("qubit_indices2", qubit_indices_2)
                        qubits_index = np.array([], dtype=int)
                        constant = 1
                        for k1 in qubit_indices_1:  # qubit_indices: ((0,), (1,))
                            constant = constant * (1 - 2 * b[j, k1])
                            qubits_index = np.append(qubits_index, i1 * N + k1)
                        for k2 in qubit_indices_2:  # qubit_indices: ((0,), (1,))
                            constant = constant * (1 - 2 * b[j, k2])
                            qubits_index = np.append(qubits_index, i2 * N + k2)
                        constant = 1 / (2 ** (2 * N)) * constant * p[i1, j] * p[i2, j]
                        # print("qubits_index", qubits_index)
                        append_multi_rzz_term(qc, qubits_index, P * constant * gamma)

        # 对应01,02,03,74,75,76
        all_combinations = list(itertools.chain(*(itertools.combinations(range(N), r) for r in range(1, N + 1))))
        for i1 in range(n):  # 取常数 1 固定一个为 p[i_1, j]
            for i2 in range(n):  # 取 Z 的下标 Z_i2k
                for qubit_indices in all_combinations:  # 取 排列组合
                    qubits_index = np.array([], dtype=int)
                    constant = 1
                    for k in qubit_indices:
                        constant = constant * (1 - 2 * b[j, k])
                        qubits_index = np.append(qubits_index, i2 * N + k)
                    constant = 1 / (2 ** (2 * N)) * constant * p[i1, j] * p[i2, j]
                    # print("qubits_index", qubits_index)
                    append_multi_rzz_term(qc, qubits_index, P * constant * gamma)

        all_combinations = list(itertools.chain(*(itertools.combinations(range(N), r) for r in range(1, N + 1))))
        for i in range(n):
            constant = 1 / (2 ** N) * p[i, j]  # 系数
            constant1 = constant
            for qubit_indices in all_combinations:  # 遍历各种组合
                qubits_index = np.array([], dtype=int)
                # 根据组合项生成子项的常数和qubit索引
                for k in range(N):
                    constant1 *= (1 - 2 * b[j, k]) if k in qubit_indices else 1
                    if k in qubit_indices:
                        qubits_index = np.append(qubits_index, i * N + k)
                # print("qubits_index", qubits_index)
                constant1 = constant1 * (2 ** (l - 1)) * (-2)
                append_multi_rzz_term(qc, qubits_index, P * constant1 * gamma)
            constant2 = constant
            for h in range(l):
                for qubit_indices in all_combinations:  # 遍历各种组合
                    qubits_index = np.array([], dtype=int)
                    # 根据组合项生成子项的常数和qubit索引
                    for k in range(N):
                        constant2 *= (1 - 2 * b[j, k]) if k in qubit_indices else 1
                        if k in qubit_indices:
                            qubits_index = np.append(qubits_index, i * N + k)
                    # print("qubits_index", qubits_index)
                    qubits_index = np.append(qubits_index, n * N + h)
                    constant2 = constant2 * (2 ** (h - 1)) * (-2)
                    append_multi_rzz_term(qc, qubits_index, P * constant2 * gamma)

        for h1 in range(l):  # 遍历 h 的范围
            for h2 in range(l):  # 遍历 h' 的范围
                coef = 2 ** (h1 - 1) * 2 ** (h2 - 1)  # 计算系数权重

                # -Z_h1 项
                append__z_term(qc, n * N + h1, 2 * P * coef * gamma)

                # -Z_h2 项
                append__z_term(qc, n * N + h2, 2 * P * coef * gamma)

                # Z_h1 Z_h2 项
                if h1 != h2:  # 避免重复
                    append__zz_term(qc, n * N + h1, n * N + h2, P * coef * gamma)

# %%
def get_mixer_circuit(beta, qc):
    # beta, gamma = params[:len(params)//2], params[len(params)//2:]
    for i in range(num_qubits):
        append__mixer_term(qc, i, beta)
    return qc

# %%
def invert_counts(s):
    return s[::-1]

# %%
from qiskit import Aer, QuantumCircuit, execute


# 定义成本函数
def cost_function(params):
    beta, gamma = params[:len(params) // 2], params[len(params) // 2:]
    num_qubits = n * N + l
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(range(num_qubits))
    # print(qc)

    length = len(params)
    for i in range(int(length / 2)):
        get_cost_circuit1(gamma[i], qc)
        get_cost_circuit2(gamma[i], qc)
        get_cost_circuit3(gamma[i], qc)
        get_mixer_circuit(beta[i], qc)
    # 模拟电路
    # 添加测量指令
    qc.measure(range(num_qubits), range(num_qubits))
    backend = Aer.get_backend('qasm_simulator')
    result = execute(qc, backend, seed_simulator=20, shots=10000).result()
    counts = result.get_counts(qc)
    # 计算期望值
    expectation = 0
    for bitstring, count in counts.items():
        bitstring = invert_counts(bitstring)
        prob = count / 10000
        z_h = np.array([int(bit) for bit in bitstring[(n * N):]])
        s_ik = np.array([int(bit) for bit in bitstring[:(n * N)]]).reshape(n, N)
        E1 = np.sum([2 ** h * z for h, z in enumerate(z_h)])
        E2 = 0
        for j in range(len(bw)):
            for i in range(n):
                constant = 1
                for k in range(N):
                    constant = constant * (1 - (s_ik[i, k] - bw[j, k]) ** 2)
                E2 += constant
        E2 = K1 * E2
        E3 = 0
        for j in range(m):
            constant1 = 0
            for i in range(n):
                constant2 = 1
                for k in range(N):
                    constant2 = constant2 * (1 - (s_ik[i, k] - b[j, k]) ** 2)
                constant1 += p[i, j] * constant2
            constant3 = 0
            for h in range(l):
                constant3 += 2 ** h * z_h[h]
            constant = max(0, constant1 - constant3)
            E3 += P * (constant) ** 2

        # alpha_s = np.max([0, np.sum(x_ij * p) - np.sum([2 ** h * z for h, z in enumerate(z_h)])])

        E = E1 + E2 + E3

        expectation += E * prob

    return expectation, counts

# %%
from qiskit_algorithms.optimizers import COBYLA


# 优化 QAOA 参数
def optimize_qaoa(params):
    def objective(params):
        expectation, _ = cost_function(params)

        return expectation

    optimizer = COBYLA(rhobeg=1.5, tol=1e-8)
    # params = np.random.rand(2 * p_max) * 2 * np.pi
    result = optimizer.minimize(fun=objective, x0=params)

    return result

# %%
# 插值法初始化函数
def interpolate_parameters(prev_params, p_old, p_new):
    if p_old == 0:
        return np.random.uniform(0, np.pi, p_new), np.random.uniform(0, 2 * np.pi, p_new)
    prev_beta = prev_params[:p_old]
    prev_gamma = prev_params[p_old:]
    new_beta = np.zeros(p_new)
    new_gamma = np.zeros(p_new)
    for i in range(p_new):
        t = i / (p_new - 1) if p_new > 1 else 0
        new_beta[i] = (1 - t) * prev_beta[0] + t * prev_beta[-1]
        new_gamma[i] = (1 - t) * prev_gamma[0] + t * prev_gamma[-1]
    return np.concatenate([new_beta, new_gamma])

# %%
# 主程序
import time

startTime = time.time()
min_energy = float('inf')
init_point = np.array([])
counts = {}
final_result = None

for p1 in range(1, 2):
    min_energy = 100000
    for k in range(500):
        print(f"第 {p1} 层，第 {k} 个参数")
        if k == 0 and p1 == 1:
            init_point_temp = np.concatenate([np.random.uniform(0, np.pi, p1),
                                              np.random.uniform(0, 2 * np.pi, p1)])
        elif k == 0:
            # 使用插值法从前一层生成新参数
            init_point_temp = interpolate_parameters(init_point, p1 - 1, p1)
        else:
            # 随机调整当前层的参数
            init_point_temp = init_point.copy()
            beta_p = np.random.uniform(0, np.pi)
            gamma_p = np.random.uniform(0, 2 * np.pi)
            init_point_temp = np.delete(init_point_temp, 2 * p1 - 1)
            init_point_temp = np.delete(init_point_temp, p1 - 1)
            init_point_temp = np.insert(init_point_temp, p1 - 1, beta_p)
            init_point_temp = np.insert(init_point_temp, 2 * p1 - 1, gamma_p)

        result = optimize_qaoa(init_point_temp)
        optimal_params = result.x
        energy, counts_temp = cost_function(result.x)

        if min_energy > energy:
            min_energy = energy
            init_point = optimal_params
            counts = counts_temp
            final_result = result
            print(f"New best energy: {min_energy}")
            print(f"Optimal parameters: {init_point}")

endTime = time.time()
# Out:
# 第 1 层，第 0 个参数
# C:\Users\李华宪\AppData\Local\Temp\ipykernel_34620\3086604383.py:21: DeprecationWarning: The function ``qiskit.execute_function.execute()`` is deprecated as of qiskit 0.46.0. It will be removed in the Qiskit 1.0 release. This function combines ``transpile`` and ``backend.run``, which is covered by ``Sampler`` :mod:`~qiskit.primitives`. Alternatively, you can also run :func:`.transpile` followed by ``backend.run()``.
#   result = execute(qc, backend, seed_simulator=20, shots=10000).result()
# New best energy: 199.7928999999999
# Optimal parameters: [2.3817174  6.15076949]
# 第 1 层，第 1 个参数
# New best energy: 156.07240000000007
# Optimal parameters: [3.63477459 3.03429005]
# 第 1 层，第 2 个参数
# 第 1 层，第 3 个参数
# New best energy: 149.39040000000003
# Optimal parameters: [2.2600761  3.21229044]
# 第 1 层，第 4 个参数
# 第 1 层，第 5 个参数
# 第 1 层，第 6 个参数
# 第 1 层，第 7 个参数
# 第 1 层，第 8 个参数
# 第 1 层，第 9 个参数
# 第 1 层，第 10 个参数
# 第 1 层，第 11 个参数
# 第 1 层，第 12 个参数
# 第 1 层，第 13 个参数
# 第 1 层，第 14 个参数
# 第 1 层，第 15 个参数
# 第 1 层，第 16 个参数
# 第 1 层，第 17 个参数
# 第 1 层，第 18 个参数
# 第 1 层，第 19 个参数
# 第 1 层，第 20 个参数
# 第 1 层，第 21 个参数
# 第 1 层，第 22 个参数
# 第 1 层，第 23 个参数
# 第 1 层，第 24 个参数
# 第 1 层，第 25 个参数
# 第 1 层，第 26 个参数
# 第 1 层，第 27 个参数
# 第 1 层，第 28 个参数
# 第 1 层，第 29 个参数
# 第 1 层，第 30 个参数
# 第 1 层，第 31 个参数
# 第 1 层，第 32 个参数
# 第 1 层，第 33 个参数
# 第 1 层，第 34 个参数
# 第 1 层，第 35 个参数
# 第 1 层，第 36 个参数
# 第 1 层，第 37 个参数
# 第 1 层，第 38 个参数
# New best energy: 148.78180000000003
# Optimal parameters: [2.43815156 5.9703181 ]
# 第 1 层，第 39 个参数
# 第 1 层，第 40 个参数
# 第 1 层，第 41 个参数
# 第 1 层，第 42 个参数
# 第 1 层，第 43 个参数
# 第 1 层，第 44 个参数
# 第 1 层，第 45 个参数
# 第 1 层，第 46 个参数
# 第 1 层，第 47 个参数
# 第 1 层，第 48 个参数
# 第 1 层，第 49 个参数
# 第 1 层，第 50 个参数
# 第 1 层，第 51 个参数
# 第 1 层，第 52 个参数
# 第 1 层，第 53 个参数
# 第 1 层，第 54 个参数
# 第 1 层，第 55 个参数
# 第 1 层，第 56 个参数
# 第 1 层，第 57 个参数
# 第 1 层，第 58 个参数
# 第 1 层，第 59 个参数
# 第 1 层，第 60 个参数
# 第 1 层，第 61 个参数
# 第 1 层，第 62 个参数
# 第 1 层，第 63 个参数
# 第 1 层，第 64 个参数
# 第 1 层，第 65 个参数
# 第 1 层，第 66 个参数
# 第 1 层，第 67 个参数
# 第 1 层，第 68 个参数
# 第 1 层，第 69 个参数
# 第 1 层，第 70 个参数
# 第 1 层，第 71 个参数
# 第 1 层，第 72 个参数
# 第 1 层，第 73 个参数
# 第 1 层，第 74 个参数
# 第 1 层，第 75 个参数
# 第 1 层，第 76 个参数
# 第 1 层，第 77 个参数
# 第 1 层，第 78 个参数
# 第 1 层，第 79 个参数
# 第 1 层，第 80 个参数
# 第 1 层，第 81 个参数
# 第 1 层，第 82 个参数
# 第 1 层，第 83 个参数
# 第 1 层，第 84 个参数
# 第 1 层，第 85 个参数
# 第 1 层，第 86 个参数
# 第 1 层，第 87 个参数
# 第 1 层，第 88 个参数
# 第 1 层，第 89 个参数
# 第 1 层，第 90 个参数
# 第 1 层，第 91 个参数
# 第 1 层，第 92 个参数
# 第 1 层，第 93 个参数
# 第 1 层，第 94 个参数
# 第 1 层，第 95 个参数
# 第 1 层，第 96 个参数
# 第 1 层，第 97 个参数
# 第 1 层，第 98 个参数
# 第 1 层，第 99 个参数
# New best energy: 139.46120000000005
# Optimal parameters: [0.86559433 5.23757999]
# 第 1 层，第 100 个参数
# 第 1 层，第 101 个参数
# 第 1 层，第 102 个参数
# 第 1 层，第 103 个参数
# 第 1 层，第 104 个参数
# 第 1 层，第 105 个参数
# 第 1 层，第 106 个参数
# 第 1 层，第 107 个参数
# 第 1 层，第 108 个参数
# 第 1 层，第 109 个参数
# 第 1 层，第 110 个参数
# 第 1 层，第 111 个参数
# 第 1 层，第 112 个参数
# 第 1 层，第 113 个参数
# 第 1 层，第 114 个参数
# 第 1 层，第 115 个参数
# 第 1 层，第 116 个参数
# 第 1 层，第 117 个参数
# 第 1 层，第 118 个参数
# 第 1 层，第 119 个参数
# 第 1 层，第 120 个参数
# 第 1 层，第 121 个参数
# 第 1 层，第 122 个参数
# 第 1 层，第 123 个参数
# 第 1 层，第 124 个参数
# 第 1 层，第 125 个参数
# 第 1 层，第 126 个参数
# 第 1 层，第 127 个参数
# 第 1 层，第 128 个参数
# 第 1 层，第 129 个参数
# 第 1 层，第 130 个参数
# 第 1 层，第 131 个参数
# 第 1 层，第 132 个参数
# 第 1 层，第 133 个参数
# 第 1 层，第 134 个参数
# 第 1 层，第 135 个参数
# 第 1 层，第 136 个参数
# 第 1 层，第 137 个参数
# 第 1 层，第 138 个参数
# 第 1 层，第 139 个参数
# 第 1 层，第 140 个参数
# 第 1 层，第 141 个参数
# 第 1 层，第 142 个参数
# 第 1 层，第 143 个参数
# 第 1 层，第 144 个参数
# 第 1 层，第 145 个参数
# 第 1 层，第 146 个参数
# 第 1 层，第 147 个参数
# 第 1 层，第 148 个参数
# 第 1 层，第 149 个参数
# 第 1 层，第 150 个参数
# 第 1 层，第 151 个参数
# 第 1 层，第 152 个参数
# 第 1 层，第 153 个参数
# 第 1 层，第 154 个参数
# 第 1 层，第 155 个参数
# 第 1 层，第 156 个参数
# 第 1 层，第 157 个参数
# 第 1 层，第 158 个参数
# 第 1 层，第 159 个参数
# 第 1 层，第 160 个参数
# 第 1 层，第 161 个参数
# 第 1 层，第 162 个参数
# 第 1 层，第 163 个参数
# 第 1 层，第 164 个参数
# 第 1 层，第 165 个参数
# 第 1 层，第 166 个参数
# 第 1 层，第 167 个参数
# 第 1 层，第 168 个参数
# 第 1 层，第 169 个参数
# 第 1 层，第 170 个参数
# 第 1 层，第 171 个参数
# 第 1 层，第 172 个参数
# 第 1 层，第 173 个参数
# 第 1 层，第 174 个参数
# 第 1 层，第 175 个参数
# 第 1 层，第 176 个参数
# 第 1 层，第 177 个参数
# 第 1 层，第 178 个参数
# 第 1 层，第 179 个参数
# 第 1 层，第 180 个参数
# 第 1 层，第 181 个参数
# 第 1 层，第 182 个参数
# 第 1 层，第 183 个参数
# 第 1 层，第 184 个参数
# 第 1 层，第 185 个参数
# 第 1 层，第 186 个参数
# 第 1 层，第 187 个参数
# 第 1 层，第 188 个参数
# 第 1 层，第 189 个参数
# 第 1 层，第 190 个参数
# 第 1 层，第 191 个参数
# 第 1 层，第 192 个参数
# 第 1 层，第 193 个参数
# 第 1 层，第 194 个参数
# 第 1 层，第 195 个参数
# 第 1 层，第 196 个参数
# 第 1 层，第 197 个参数
# 第 1 层，第 198 个参数
# 第 1 层，第 199 个参数
# 第 1 层，第 200 个参数
# 第 1 层，第 201 个参数
# 第 1 层，第 202 个参数
# 第 1 层，第 203 个参数
# 第 1 层，第 204 个参数
# 第 1 层，第 205 个参数
# 第 1 层，第 206 个参数
# 第 1 层，第 207 个参数
# 第 1 层，第 208 个参数
# 第 1 层，第 209 个参数
# 第 1 层，第 210 个参数
# 第 1 层，第 211 个参数
# 第 1 层，第 212 个参数
# 第 1 层，第 213 个参数
# 第 1 层，第 214 个参数
# 第 1 层，第 215 个参数
# 第 1 层，第 216 个参数
# 第 1 层，第 217 个参数
# 第 1 层，第 218 个参数
# 第 1 层，第 219 个参数
# 第 1 层，第 220 个参数
# 第 1 层，第 221 个参数
# 第 1 层，第 222 个参数
# 第 1 层，第 223 个参数
# 第 1 层，第 224 个参数
# 第 1 层，第 225 个参数
# 第 1 层，第 226 个参数
# 第 1 层，第 227 个参数
# 第 1 层，第 228 个参数
# 第 1 层，第 229 个参数
# 第 1 层，第 230 个参数
# 第 1 层，第 231 个参数
# 第 1 层，第 232 个参数
# 第 1 层，第 233 个参数
# 第 1 层，第 234 个参数
# 第 1 层，第 235 个参数
# 第 1 层，第 236 个参数
# 第 1 层，第 237 个参数
# 第 1 层，第 238 个参数
# 第 1 层，第 239 个参数
# 第 1 层，第 240 个参数
# 第 1 层，第 241 个参数
# 第 1 层，第 242 个参数
# 第 1 层，第 243 个参数
# 第 1 层，第 244 个参数
# 第 1 层，第 245 个参数
# 第 1 层，第 246 个参数
# 第 1 层，第 247 个参数
# 第 1 层，第 248 个参数
# 第 1 层，第 249 个参数
# 第 1 层，第 250 个参数
# 第 1 层，第 251 个参数
# 第 1 层，第 252 个参数
# 第 1 层，第 253 个参数
# 第 1 层，第 254 个参数
# 第 1 层，第 255 个参数
# 第 1 层，第 256 个参数
# 第 1 层，第 257 个参数
# 第 1 层，第 258 个参数
# 第 1 层，第 259 个参数
# 第 1 层，第 260 个参数
# 第 1 层，第 261 个参数
# 第 1 层，第 262 个参数
# 第 1 层，第 263 个参数
# 第 1 层，第 264 个参数
# 第 1 层，第 265 个参数
# 第 1 层，第 266 个参数
# 第 1 层，第 267 个参数
# 第 1 层，第 268 个参数
# 第 1 层，第 269 个参数
# 第 1 层，第 270 个参数
# 第 1 层，第 271 个参数
# 第 1 层，第 272 个参数
# 第 1 层，第 273 个参数
# 第 1 层，第 274 个参数
# 第 1 层，第 275 个参数
# 第 1 层，第 276 个参数
# 第 1 层，第 277 个参数
# 第 1 层，第 278 个参数
# 第 1 层，第 279 个参数
# 第 1 层，第 280 个参数
# 第 1 层，第 281 个参数
# 第 1 层，第 282 个参数
# 第 1 层，第 283 个参数
# 第 1 层，第 284 个参数
# 第 1 层，第 285 个参数
# 第 1 层，第 286 个参数
# 第 1 层，第 287 个参数
# 第 1 层，第 288 个参数
# 第 1 层，第 289 个参数
# 第 1 层，第 290 个参数
# 第 1 层，第 291 个参数
# 第 1 层，第 292 个参数
# 第 1 层，第 293 个参数
# 第 1 层，第 294 个参数
# 第 1 层，第 295 个参数
# 第 1 层，第 296 个参数
# 第 1 层，第 297 个参数
# 第 1 层，第 298 个参数
# 第 1 层，第 299 个参数
# 第 1 层，第 300 个参数
# 第 1 层，第 301 个参数
# 第 1 层，第 302 个参数
# 第 1 层，第 303 个参数
# 第 1 层，第 304 个参数
# 第 1 层，第 305 个参数
# 第 1 层，第 306 个参数
# 第 1 层，第 307 个参数
# 第 1 层，第 308 个参数
# 第 1 层，第 309 个参数
# 第 1 层，第 310 个参数
# 第 1 层，第 311 个参数
# 第 1 层，第 312 个参数
# 第 1 层，第 313 个参数
# 第 1 层，第 314 个参数
# 第 1 层，第 315 个参数
# 第 1 层，第 316 个参数
# 第 1 层，第 317 个参数
# 第 1 层，第 318 个参数
# 第 1 层，第 319 个参数
# 第 1 层，第 320 个参数
# 第 1 层，第 321 个参数
# 第 1 层，第 322 个参数
# 第 1 层，第 323 个参数
# 第 1 层，第 324 个参数
# 第 1 层，第 325 个参数
# 第 1 层，第 326 个参数
# 第 1 层，第 327 个参数
# 第 1 层，第 328 个参数
# 第 1 层，第 329 个参数
# 第 1 层，第 330 个参数
# 第 1 层，第 331 个参数
# 第 1 层，第 332 个参数
# 第 1 层，第 333 个参数
# 第 1 层，第 334 个参数
# 第 1 层，第 335 个参数
# 第 1 层，第 336 个参数
# 第 1 层，第 337 个参数
# 第 1 层，第 338 个参数
# 第 1 层，第 339 个参数
# 第 1 层，第 340 个参数
# 第 1 层，第 341 个参数
# 第 1 层，第 342 个参数
# 第 1 层，第 343 个参数
# 第 1 层，第 344 个参数
# 第 1 层，第 345 个参数
# 第 1 层，第 346 个参数
# 第 1 层，第 347 个参数
# 第 1 层，第 348 个参数
# 第 1 层，第 349 个参数
# 第 1 层，第 350 个参数
# 第 1 层，第 351 个参数
# 第 1 层，第 352 个参数
# 第 1 层，第 353 个参数
# 第 1 层，第 354 个参数
# 第 1 层，第 355 个参数
# 第 1 层，第 356 个参数
# 第 1 层，第 357 个参数
# 第 1 层，第 358 个参数
# 第 1 层，第 359 个参数
# 第 1 层，第 360 个参数
# 第 1 层，第 361 个参数
# 第 1 层，第 362 个参数
# 第 1 层，第 363 个参数
# 第 1 层，第 364 个参数
# 第 1 层，第 365 个参数
# 第 1 层，第 366 个参数
# 第 1 层，第 367 个参数
# 第 1 层，第 368 个参数
# 第 1 层，第 369 个参数
# 第 1 层，第 370 个参数
# 第 1 层，第 371 个参数
# 第 1 层，第 372 个参数
# 第 1 层，第 373 个参数
# 第 1 层，第 374 个参数
# 第 1 层，第 375 个参数
# 第 1 层，第 376 个参数
# 第 1 层，第 377 个参数
# 第 1 层，第 378 个参数
# 第 1 层，第 379 个参数
# 第 1 层，第 380 个参数
# 第 1 层，第 381 个参数
# 第 1 层，第 382 个参数
# 第 1 层，第 383 个参数
# 第 1 层，第 384 个参数
# 第 1 层，第 385 个参数
# 第 1 层，第 386 个参数
# 第 1 层，第 387 个参数
# 第 1 层，第 388 个参数
# 第 1 层，第 389 个参数
# 第 1 层，第 390 个参数
# 第 1 层，第 391 个参数
# 第 1 层，第 392 个参数
# 第 1 层，第 393 个参数
# 第 1 层，第 394 个参数
# 第 1 层，第 395 个参数
# 第 1 层，第 396 个参数
# 第 1 层，第 397 个参数
# 第 1 层，第 398 个参数
# 第 1 层，第 399 个参数
# 第 1 层，第 400 个参数
# 第 1 层，第 401 个参数
# 第 1 层，第 402 个参数
# 第 1 层，第 403 个参数
# 第 1 层，第 404 个参数
# 第 1 层，第 405 个参数
# 第 1 层，第 406 个参数
# 第 1 层，第 407 个参数
# 第 1 层，第 408 个参数
# 第 1 层，第 409 个参数
# 第 1 层，第 410 个参数
# 第 1 层，第 411 个参数
# 第 1 层，第 412 个参数
# 第 1 层，第 413 个参数
# 第 1 层，第 414 个参数
# 第 1 层，第 415 个参数
# 第 1 层，第 416 个参数
# 第 1 层，第 417 个参数
# 第 1 层，第 418 个参数
# 第 1 层，第 419 个参数
# 第 1 层，第 420 个参数
# 第 1 层，第 421 个参数
# 第 1 层，第 422 个参数
# 第 1 层，第 423 个参数
# 第 1 层，第 424 个参数
# 第 1 层，第 425 个参数
# 第 1 层，第 426 个参数
# 第 1 层，第 427 个参数
# 第 1 层，第 428 个参数
# 第 1 层，第 429 个参数
# 第 1 层，第 430 个参数
# 第 1 层，第 431 个参数
# 第 1 层，第 432 个参数
# 第 1 层，第 433 个参数
# 第 1 层，第 434 个参数
# 第 1 层，第 435 个参数
# 第 1 层，第 436 个参数
# 第 1 层，第 437 个参数
# 第 1 层，第 438 个参数
# 第 1 层，第 439 个参数
# 第 1 层，第 440 个参数
# 第 1 层，第 441 个参数
# 第 1 层，第 442 个参数
# 第 1 层，第 443 个参数
# 第 1 层，第 444 个参数
# 第 1 层，第 445 个参数
# 第 1 层，第 446 个参数
# 第 1 层，第 447 个参数
# 第 1 层，第 448 个参数
# 第 1 层，第 449 个参数
# 第 1 层，第 450 个参数
# 第 1 层，第 451 个参数
# 第 1 层，第 452 个参数
# 第 1 层，第 453 个参数
# 第 1 层，第 454 个参数
# 第 1 层，第 455 个参数
# 第 1 层，第 456 个参数
# 第 1 层，第 457 个参数
# 第 1 层，第 458 个参数
# 第 1 层，第 459 个参数
# 第 1 层，第 460 个参数
# 第 1 层，第 461 个参数
# 第 1 层，第 462 个参数
# 第 1 层，第 463 个参数
# 第 1 层，第 464 个参数
# 第 1 层，第 465 个参数
# 第 1 层，第 466 个参数
# 第 1 层，第 467 个参数
# 第 1 层，第 468 个参数
# 第 1 层，第 469 个参数
# 第 1 层，第 470 个参数
# 第 1 层，第 471 个参数
# 第 1 层，第 472 个参数
# 第 1 层，第 473 个参数
# 第 1 层，第 474 个参数
# 第 1 层，第 475 个参数
# 第 1 层，第 476 个参数
# 第 1 层，第 477 个参数
# 第 1 层，第 478 个参数
# 第 1 层，第 479 个参数
# 第 1 层，第 480 个参数
# 第 1 层，第 481 个参数
# 第 1 层，第 482 个参数
# 第 1 层，第 483 个参数
# 第 1 层，第 484 个参数
# 第 1 层，第 485 个参数
# 第 1 层，第 486 个参数
# 第 1 层，第 487 个参数
# 第 1 层，第 488 个参数
# 第 1 层，第 489 个参数
# 第 1 层，第 490 个参数
# 第 1 层，第 491 个参数
# 第 1 层，第 492 个参数
# 第 1 层，第 493 个参数
# 第 1 层，第 494 个参数
# 第 1 层，第 495 个参数
# 第 1 层，第 496 个参数
# 第 1 层，第 497 个参数
# 第 1 层，第 498 个参数
# 第 1 层，第 499 个参数

# %%
import warnings
from qiskit.visualization import plot_histogram

# 忽略弃用警告
warnings.filterwarnings("ignore", category=DeprecationWarning)
# 输出结果
print("优化时间：", endTime - startTime)
print("Optimal parameters:", final_result.x)
print("Optimal value:", final_result.fun)
# 使用最优参数运行量子电路并输出测量结果
final_expectation, final_counts = cost_function(final_result.x)
sorted_dict = {item[0][::-1]: item[1] for item in sorted(final_counts.items(), key=lambda item: item[1], reverse=True)}
# 过滤掉计数小于 100 的结果
filtered_dict = {key: value for key, value in sorted_dict.items() if value >= 100}
print("Final expectation value:", final_expectation)
print("Final measurement counts:", filtered_dict)
plot_histogram(filtered_dict)
# Out:
# 优化时间： 1287.8180713653564
# Optimal parameters: [0.86559433 5.23757999]
# Optimal value: 139.46120000000005
# Final expectation value: 139.46120000000005
# Final measurement counts: {'11011': 2894, '00011': 1966, '01011': 1901, '10011': 1651, '00010': 244, '11001': 149, '11010': 146, '00111': 145, '11111': 144, '00001': 141, '01001': 130, '10111': 100}

# %%
# 计算期望值
expectation = 0
for bitstring, count in sorted_dict.items():
    bitstring = invert_counts(bitstring)
    prob = count / 10000
    z_h = np.array([int(bit) for bit in bitstring[(n * N):]])
    s_ik = np.array([int(bit) for bit in bitstring[:(n * N)]]).reshape(n, N)
    E1 = np.sum([2 ** h * z for h, z in enumerate(z_h)])
    E2 = 0
    for j in range(len(bw)):
        for i in range(n):
            constant = 1
            for k in range(N):
                constant = constant * (1 - (s_ik[i, k] - bw[j, k]) ** 2)
            E2 += constant
    E2 = E2
    E3 = 0
    for j in range(m):
        constant1 = 0
        for i in range(n):
            constant2 = 1
            for k in range(N):
                constant2 = constant2 * (1 - (s_ik[i, k] - b[j, k]) ** 2)
            constant1 += p[i, j] * constant2
        constant3 = 0
        for h in range(l):
            constant3 += 2 ** h * z_h[h]
        constant = max(0, constant1 - constant3)
        E3 += (constant) ** 2

    # alpha_s = np.max([0, np.sum(x_ij * p) - np.sum([2 ** h * z for h, z in enumerate(z_h)])])

    E = E1 + E2 + E3

    expectation += E * prob
print(expectation)
# Out:
# 10.908100000000006

# %%
expectation = 0
bitstring = "1001001"
z_h = np.array([int(bit) for bit in bitstring[(n * N):]])
s_ik = np.array([int(bit) for bit in bitstring[:(n * N)]]).reshape(n, N)
E1 = np.sum([2 ** h * z for h, z in enumerate(z_h)])
E2 = 0
for j in range(len(bw)):
    for i in range(n):
        constant = 1
        for k in range(N):
            constant = constant * (1 - (s_ik[i, k] - bw[j, k]) ** 2)
        E2 += constant
E2 = K1 * E2
E3 = 0
for j in range(m):
    constant1 = 0
    # print("机器：", j)
    for i in range(n):
        constant2 = 1
        for k in range(N):
            constant2 = constant2 * (1 - (s_ik[i, k] - b[j, k]) ** 2)
        # print("constant2:", constant2)
        # print("p[i,j]:", p[i,j])
        constant1 += p[i, j] * constant2
    # print("constant1:", constant1)
    constant3 = 0
    for h in range(l):
        constant3 += 2 ** h * z_h[h]
    # print("constant3:", constant3)
    constant = max(0, constant1 - constant3)
    E3 += (constant) ** 2

    # alpha_s = np.max([0, np.sum(x_ij * p) - np.sum([2 ** h * z for h, z in enumerate(z_h)])])

E = E1 + K1 * E2 + P * E3
print(E1)
print(E2)
print(E3)
# print(e1)
# print(e2)
# Out:
# 1
# 0
# 0
