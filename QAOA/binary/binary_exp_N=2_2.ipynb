# %%
import numpy as np

# 假设有 3 台机器和 3 个操作
m = 4  # 机器数量
N = 2  # 表示机器的二进制 (0, 1)
n = 2  # 操作数量
l = 1  # 用于表示 C_max 的二进制位数

# 处理时间矩阵 (例如)
p = np.array([[1, 2, 3, 4], [4, 2, 3, 1]])

b = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
# 非法数组(用于表示机器数)(1, 1)
bw = np.array([])
# 常数
K1 = 100
P = 30
# print(len(bw))
# 量子比特数量
num_qubits = n * N + l

# %%
def append_multi_rzz_term(qc, qubits, gamma):
    """
    构建一个类RZZ门，n-1个控制位，1个目标位，进行旋转操作。
    参数:
    control_qubits: List[int]，控制量子比特的索引
    target_qubit: int，目标量子比特的索引
    """
    if len(qubits) == 1:
        qc.rz(gamma, qubits[0])
    else:
        control_qubits = list(qubits[:len(qubits) - 1])

        target_qubit = qubits[len(qubits) - 1:]

        n_controls = len(control_qubits)
        if n_controls == 1:
            qc.cx(control_qubits[0], target_qubit[0])
        else:
            qc.mcx(control_qubits, target_qubit[0])
        qc.rz(gamma, target_qubit[0])
        if n_controls == 1:
            qc.cx(control_qubits[0], target_qubit[0])
        else:
            qc.mcx(control_qubits, target_qubit[0])

# %%
def append__zz_term(qc, qubit1, qubit2, gamma):
    qc.cx(qubit1, qubit2)
    qc.rz(gamma, qubit2)
    qc.cx(qubit1, qubit2)


def append__z_term(qc, qubit, gamma):
    qc.rz(gamma, qubit)


def append__mixer_term(qc, qubit, beta):
    qc.rx(2 * beta, qubit)

# %%
def get_cost_circuit1(gamma, qc):
    for h in range(l):
        coef = - 2 ** h
        append__z_term(qc, N * n + h, coef * gamma)
    return qc

# %% [markdown]
# \begin{align}K_{1} \sum_{j\in W} \sum_{i=0}^{n}\prod_{k=0}^{N}\left(\frac{1}2+\left(\frac{1}2-b_{j k}\right)Z_{ik}\right)\end{align}

# %%
import itertools


def get_cost_circuit2(gamma, qc):
    # print(len(bw))
    if len(bw) == 0:
        return qc
    for j in range(len(bw)):
        for i in range(n):
            constant1 = (1 / 4) * (1 - 2 * bw[j, 0])
            append__z_term(qc, i * N, constant1 * gamma)  # 系数 1/2^N
            constant2 = (1 / 4) * (1 - 2 * bw[j, 1])
            append__z_term(qc, i * N + 1, constant2 * gamma)  # 系数
            constant3 = (1 / 4) * (1 - 2 * bw[j, 0]) * (1 - 2 * bw[j, 1])
            append__zz_term(qc, i * N, i * N + 1, constant3 * gamma)
    return qc

# %% [markdown]
# \begin{align}\sum_{j=0}^{m-1}\sum_{i=0}^{n-1} \sum_{i^{\prime}=0}^{n-1}\left(\prod_{k=0}^{N-1}\frac{1}{2}\left(1+\left(1-2b_{j k}\right) Z_{i k}\right)\right) p_{i j}\left(\prod_{k^{\prime}=0}^{N-1}\frac{1}{2}\left(1+\left(1-2b_{j k}\right) Z_{i^{\prime} k^{\prime}}\right)\right) p_{i^{\prime} j}\end{align}
# \begin{align}-2 \sum_{j=0}^{m-1} \sum_{i=0}^{n-1} \sum_{h=0}^{l-1} \left(\prod_{k=0}^{N-1}\frac{1}{2}\left(1+\left(1-2b_{j k}\right) Z_{i k}\right)\right) p_{i j} \cdot 2^{h-1}\left(1-Z_h\right)\end{align}
# \begin{align}\sum_{j=0}^{m-1}\sum_{h=0}^{l-1} \sum_{h^{\prime}=0}^{l-1} 2^{h-1} 2^{h^{\prime}-1}\left(1-Z_h-Z_{h^{\prime}}+Z_h Z_{h^{\prime}}\right)\end{align}

# %%
def get_cost_circuit3(gamma, qc):
    for j in range(m):
        # 12
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[0, j] * p[0, j]
        append__zz_term(qc, 0, 1, P * 2 * constant * gamma)
        # 14
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 0]) * p[0, j] * p[1, j]
        append__zz_term(qc, 0, 2, P * 2 * constant * gamma)
        # 15
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[0, j] * p[1, j]
        append__zz_term(qc, 0, 3, P * 2 * constant * gamma)
        # 24
        constant = (1 / 16) * (1 - 2 * b[j, 1]) * (1 - 2 * b[j, 0]) * p[0, j] * p[1, j]
        append__zz_term(qc, 1, 2, P * 2 * constant * gamma)
        # 25
        constant = (1 / 16) * (1 - 2 * b[j, 1]) * (1 - 2 * b[j, 1]) * p[0, j] * p[1, j]
        append__zz_term(qc, 1, 3, P * 2 * constant * gamma)
        # 45
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[1, j] * p[1, j]
        append__zz_term(qc, 2, 3, P * 2 * constant * gamma)
        # 13
        qubits_index = np.array([1])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[0, j] * p[0, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 16
        qubits_index = np.array([0, 2, 3])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[0, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 23
        qubits_index = np.array([0])
        constant = (1 / 16) * (1 - 2 * b[j, 1]) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[0, j] * p[0, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 26
        qubits_index = np.array([1, 2, 3])
        constant = (1 / 16) * (1 - 2 * b[j, 1]) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[0, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 34
        qubits_index = np.array([0, 1, 2])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * (1 - 2 * b[j, 0]) * p[0, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 35
        qubits_index = np.array([0, 1, 3])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * (1 - 2 * b[j, 1]) * p[0, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 36
        qubits_index = np.array([0, 1, 2, 3])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * (1 - 2 * b[j, 1]) * p[0, j] * \
                   p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 46
        qubits_index = np.array([3])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[1, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 56
        qubits_index = np.array([2])
        constant = (1 / 16) * (1 - 2 * b[j, 1]) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[1, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 01
        qubits_index = np.array([0])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * p[0, j] * p[0, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 02
        qubits_index = np.array([1])
        constant = (1 / 16) * (1 - 2 * b[j, 1]) * p[0, j] * p[0, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 03
        qubits_index = np.array([0, 1])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[0, j] * p[0, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 04
        qubits_index = np.array([2])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * p[0, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 05
        qubits_index = np.array([3])
        constant = (1 / 16) * (1 - 2 * b[j, 1]) * p[0, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 06
        qubits_index = np.array([2, 3])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[0, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 71
        qubits_index = np.array([0])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * p[1, j] * p[0, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 72
        qubits_index = np.array([1])
        constant = (1 / 16) * (1 - 2 * b[j, 1]) * p[1, j] * p[0, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 73
        qubits_index = np.array([0, 1])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[1, j] * p[0, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 74
        qubits_index = np.array([2])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * p[1, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 75
        qubits_index = np.array([3])
        constant = (1 / 16) * (1 - 2 * b[j, 1]) * p[1, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)
        # 76
        qubits_index = np.array([2, 3])
        constant = (1 / 16) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[1, j] * p[1, j]
        append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)

        for i in range(n):  # 遍历 i 的范围
            qubits_index = np.array([i * N])
            constant = (1 / 8) * (1 - 2 * b[j, 0]) * p[i, j]
            append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)

            qubits_index = np.array([i * N + 1])
            constant = (1 / 8) * (1 - 2 * b[j, 1]) * p[i, j]
            append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)

            qubits_index = np.array([i * N, i * N + 1])
            constant = (1 / 8) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[i, j]
            append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)

            qubits_index = np.array([4])
            constant = (-1 / 8) * p[i, j]
            append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)

            qubits_index = np.array([i * N + 1])
            constant = (1 / 8) * (1 - 2 * b[j, 1]) * p[i, j]
            append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)

            qubits_index = np.array([i * N, i * N + 1])
            constant = (1 / 8) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[i, j]
            append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)

            qubits_index = np.array([i * N, 4])
            constant = (-1 / 8) * (1 - 2 * b[j, 0]) * p[i, j]
            append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)

            qubits_index = np.array([i * N + 1, 4])
            constant = (-1 / 8) * (1 - 2 * b[j, 1]) * p[i, j]
            append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)

            qubits_index = np.array([i * N, i * N + 1, 4])
            constant = (-1 / 8) * (1 - 2 * b[j, 0]) * (1 - 2 * b[j, 1]) * p[i, j]
            append_multi_rzz_term(qc, qubits_index, P * 2 * constant * gamma)

        for h1 in range(l):  # 遍历 h 的范围
            for h2 in range(l):  # 遍历 h' 的范围
                coef = 2 ** (h1 - 1) * 2 ** (h2 - 1)  # 计算系数权重

                # -Z_h1 项
                append__z_term(qc, n * N + h1, 2 * P * coef * gamma)

                # -Z_h2 项
                append__z_term(qc, n * N + h2, 2 * P * coef * gamma)

                # Z_h1 Z_h2 项
                if h1 != h2:  # 避免重复
                    append__zz_term(qc, n * N + h1, n * N + h2, 2 * P * coef * gamma)

# %%
def get_mixer_circuit(beta, qc):
    # beta, gamma = params[:len(params)//2], params[len(params)//2:]
    for i in range(num_qubits):
        append__mixer_term(qc, i, beta)
    return qc

# %%
def invert_counts(s):
    return s[::-1]

# %%
from qiskit import Aer, QuantumCircuit, execute


# 定义成本函数
def cost_function(params):
    beta, gamma = params[:len(params) // 2], params[len(params) // 2:]
    num_qubits = n * N + l
    qc = QuantumCircuit(num_qubits, num_qubits)
    qc.h(range(num_qubits))
    # print(qc)

    length = len(params)
    for i in range(int(length / 2)):
        get_cost_circuit1(gamma[i], qc)
        get_cost_circuit2(gamma[i], qc)
        get_cost_circuit3(gamma[i], qc)
        get_mixer_circuit(beta[i], qc)
    # 模拟电路
    # 添加测量指令
    qc.measure(range(num_qubits), range(num_qubits))
    backend = Aer.get_backend('qasm_simulator')
    result = execute(qc, backend, seed_simulator=10, shots=10000).result()
    counts = result.get_counts(qc)
    # 计算期望值
    expectation = 0
    for bitstring, count in counts.items():
        bitstring = invert_counts(bitstring)
        prob = count / 10000
        z_h = np.array([int(bit) for bit in bitstring[(n * N):]])
        s_ik = np.array([int(bit) for bit in bitstring[:(n * N)]]).reshape(n, N)
        E1 = np.sum([2 ** h * z for h, z in enumerate(z_h)])
        E2 = 0
        for j in range(len(bw)):
            for i in range(n):
                constant = 1
                for k in range(N):
                    constant = constant * (1 - (s_ik[i, k] - bw[j, k]) ** 2)
                E2 += constant
        E2 = K1 * E2
        E3 = 0
        for j in range(m):
            constant1 = 0
            for i in range(n):
                constant2 = 1
                for k in range(N):
                    constant2 = constant2 * (1 - (s_ik[i, k] - b[j, k]) ** 2)
                constant1 += p[i, j] * constant2
            constant3 = 0
            for h in range(l):
                constant3 += 2 ** h * z_h[h]
            constant = max(0, constant1 - constant3)
            E3 += P * (constant) ** 2

        # alpha_s = np.max([0, np.sum(x_ij * p) - np.sum([2 ** h * z for h, z in enumerate(z_h)])])

        E = E1 + E2 + E3

        expectation += E * prob

    return expectation, counts

# %%
# from qiskit_algorithms.optimizers import COBYLA
# 
# # 优化 QAOA 参数
# def optimize_qaoa(params):
#     def objective(params):
#         expectation, _ = cost_function(params)
# 
#         return expectation
# 
#     optimizer = COBYLA(rhobeg = 1.5, tol = 1e-8)
#     # params = np.random.rand(2 * p_max) * 2 * np.pi
#     result = optimizer.minimize(fun=objective, x0=params)
# 
#     return result
from qiskit_algorithms.optimizers import COBYLA


# 优化 QAOA 参数
def optimize_qaoa(params, optimizer):
    def objective(params):
        expectation, _ = cost_function(params)

        return expectation

    # optimizer = COBYLA(rhobeg = 1.5, tol = 1e-7)
    # params = np.random.rand(2 * p_max) * 2 * np.pi
    # 判断优化器类型：Qiskit 优化器 vs Scipy Optimizer
    if isinstance(optimizer, dict):  # 如果是Scipy的优化器
        result = minimize(
            fun=objective,
            x0=params,
            method=optimizer["method"],
            options=optimizer["options"]
        )
    else:  # 如果是Qiskit优化器
        result = optimizer.minimize(fun=objective, x0=params)
    # result = optimizer.minimize(fun=objective, x0=params)

    return result

# %%
from qiskit_algorithms.optimizers import L_BFGS_B, SLSQP
from scipy.optimize import minimize

# from qiskit.algorithms.optimizers import SPSA

# 优化器配置
optimizers = [
    {
        # COBYLA(rhobeg = 1.5, tol = 1e-7)
        "name": "COBYLA",
        "func": lambda: COBYLA(rhobeg=1.5, tol=1e-7)
    },
    # {
    #     "name": "SPSA",
    #     "func": lambda: SPSA(maxiter = 300)
    # },
    {
        "name": "L-BFGS-B",
        "func": lambda: L_BFGS_B(tol=1e-6, maxfun=15000)
    },
    {
        "name": "SLSQP",
        "func": lambda: SLSQP(tol=1e-6)
    },
    {
        "name": "Powell",
        "func": lambda: {"method": "Powell", "options": {"xtol": 1e-6, "ftol": 1e-6, "maxiter": 1000, "disp": True}}
    }

    # {
    #     "name": "Nelder-Mead",
    #     "func": lambda: Nelder-Mead(xatol = 1e-6)xatol': 1e-6, 'maxiter': 200}}
    # },
    # {
    #     "name": "PSO",
    #     "func": lambda: {"optimizer": "PSO", "swarmsize": 50, "maxiter": 100, "bounds": [0, 2 * 3.14]}
    # },
    # {
    #     "name": "Adam",
    #     "func": lambda: {"optimizer": "Adam", "learning_rate": 0.01}
    # }
]

# %%
import time
from qiskit.visualization import plot_histogram

# 运行优化
for optimizer in optimizers:
    print(f"Running optimizer: {optimizer['name']}")
    # print(optimizer)
    startTime = time.time()
    ansatz_final = object()
    init_point = np.array([])
    counts = {}
    min_energy = 0
    final_result = object()
    for p1 in range(1, 4):
        min_energy = 10000
        for k in range(100):
            print('第：', p1, '层', ' ', '第', k, '个参数')
            init_point_temp = init_point
            beta_p = np.random.uniform(0, np.pi)
            gamma_p = np.random.uniform(0, 2 * np.pi)
            if k > 0:
                init_point_temp = np.delete(init_point_temp, 2 * p1 - 1)
                init_point_temp = np.delete(init_point_temp, p1 - 1)
            init_point_temp = np.insert(init_point_temp, p1 - 1, beta_p)
            init_point_temp = np.insert(init_point_temp, 2 * p1 - 1, gamma_p)

            result = optimize_qaoa(init_point_temp, optimizer['func']())

            # print(result.x)
            optimal_params = result.x

            # 计算最终的能量
            energy, counts_temp = cost_function(result.x)
            if min_energy > energy:
                min_energy = energy
                init_point = optimal_params
                counts = counts_temp
                final_result = result
    endTime = time.time()
    # 输出结果
    print("优化时间：", endTime - startTime)
    print("Optimal parameters:", final_result.x)
    print("Optimal value:", final_result.fun)
    # 使用最优参数运行量子电路并输出测量结果
    final_expectation, final_counts = cost_function(final_result.x)
    sorted_dict = {item[0][::-1]: item[1] for item in
                   sorted(final_counts.items(), key=lambda item: item[1], reverse=True)}
    print("Final expectation value:", final_expectation)
    print("Final measurement counts:", sorted_dict)
    plot_histogram(sorted_dict)
# Out:
# Running optimizer: COBYLA
# 第： 1 层   第 0 个参数
# 第： 1 层   第 1 个参数
# 第： 1 层   第 2 个参数
# 第： 1 层   第 3 个参数
# 第： 1 层   第 4 个参数
# 第： 1 层   第 5 个参数
# 第： 1 层   第 6 个参数
# 第： 1 层   第 7 个参数
# 第： 1 层   第 8 个参数
# 第： 1 层   第 9 个参数
# 第： 1 层   第 10 个参数
# 第： 1 层   第 11 个参数
# 第： 1 层   第 12 个参数
# 第： 1 层   第 13 个参数
# 第： 1 层   第 14 个参数
# 第： 1 层   第 15 个参数
# 第： 1 层   第 16 个参数
# 第： 1 层   第 17 个参数
# 第： 1 层   第 18 个参数
# 第： 1 层   第 19 个参数
# 第： 1 层   第 20 个参数
# 第： 1 层   第 21 个参数
# 第： 1 层   第 22 个参数
# 第： 1 层   第 23 个参数
# 第： 1 层   第 24 个参数
# 第： 1 层   第 25 个参数
# 第： 1 层   第 26 个参数
# 第： 1 层   第 27 个参数
# 第： 1 层   第 28 个参数
# 第： 1 层   第 29 个参数
# 第： 1 层   第 30 个参数
# 第： 1 层   第 31 个参数
# 第： 1 层   第 32 个参数
# 第： 1 层   第 33 个参数
# 第： 1 层   第 34 个参数
# 第： 1 层   第 35 个参数
# 第： 1 层   第 36 个参数
# 第： 1 层   第 37 个参数
# 第： 1 层   第 38 个参数
# 第： 1 层   第 39 个参数
# 第： 1 层   第 40 个参数
# 第： 1 层   第 41 个参数
# 第： 1 层   第 42 个参数
# 第： 1 层   第 43 个参数
# 第： 1 层   第 44 个参数
# 第： 1 层   第 45 个参数
# 第： 1 层   第 46 个参数
# 第： 1 层   第 47 个参数
# 第： 1 层   第 48 个参数
# 第： 1 层   第 49 个参数
# 第： 1 层   第 50 个参数
# 第： 1 层   第 51 个参数
# 第： 1 层   第 52 个参数
# 第： 1 层   第 53 个参数
# 第： 1 层   第 54 个参数
# 第： 1 层   第 55 个参数
# 第： 1 层   第 56 个参数
# 第： 1 层   第 57 个参数
# 第： 1 层   第 58 个参数
# 第： 1 层   第 59 个参数
# 第： 1 层   第 60 个参数
# 第： 1 层   第 61 个参数
# 第： 1 层   第 62 个参数
# 第： 1 层   第 63 个参数
# 第： 1 层   第 64 个参数
# 第： 1 层   第 65 个参数
# 第： 1 层   第 66 个参数
# 第： 1 层   第 67 个参数
# 第： 1 层   第 68 个参数
# 第： 1 层   第 69 个参数
# 第： 1 层   第 70 个参数
# 第： 1 层   第 71 个参数
# 第： 1 层   第 72 个参数
# 第： 1 层   第 73 个参数
# 第： 1 层   第 74 个参数
# 第： 1 层   第 75 个参数
# 第： 1 层   第 76 个参数
# 第： 1 层   第 77 个参数
# 第： 1 层   第 78 个参数
# 第： 1 层   第 79 个参数
# 第： 1 层   第 80 个参数
# 第： 1 层   第 81 个参数
# 第： 1 层   第 82 个参数
# 第： 1 层   第 83 个参数
# 第： 1 层   第 84 个参数
# 第： 1 层   第 85 个参数
# 第： 1 层   第 86 个参数
# 第： 1 层   第 87 个参数
# 第： 1 层   第 88 个参数
# 第： 1 层   第 89 个参数
# 第： 1 层   第 90 个参数
# 第： 1 层   第 91 个参数
# 第： 1 层   第 92 个参数
# 第： 1 层   第 93 个参数
# 第： 1 层   第 94 个参数
# 第： 1 层   第 95 个参数
# 第： 1 层   第 96 个参数
# 第： 1 层   第 97 个参数
# 第： 1 层   第 98 个参数
# 第： 1 层   第 99 个参数
# 第： 2 层   第 0 个参数
# 第： 2 层   第 1 个参数
# 第： 2 层   第 2 个参数
# 第： 2 层   第 3 个参数
# 第： 2 层   第 4 个参数
# 第： 2 层   第 5 个参数
# 第： 2 层   第 6 个参数
# 第： 2 层   第 7 个参数
# 第： 2 层   第 8 个参数
# 第： 2 层   第 9 个参数
# 第： 2 层   第 10 个参数
# 第： 2 层   第 11 个参数
# 第： 2 层   第 12 个参数
# 第： 2 层   第 13 个参数
# 第： 2 层   第 14 个参数
# 第： 2 层   第 15 个参数
# 第： 2 层   第 16 个参数
# 第： 2 层   第 17 个参数
# 第： 2 层   第 18 个参数
# 第： 2 层   第 19 个参数
# 第： 2 层   第 20 个参数
# 第： 2 层   第 21 个参数
# 第： 2 层   第 22 个参数
# 第： 2 层   第 23 个参数
# 第： 2 层   第 24 个参数
# 第： 2 层   第 25 个参数
# 第： 2 层   第 26 个参数
# 第： 2 层   第 27 个参数
# 第： 2 层   第 28 个参数
# 第： 2 层   第 29 个参数
# 第： 2 层   第 30 个参数
# 第： 2 层   第 31 个参数
# 第： 2 层   第 32 个参数
# 第： 2 层   第 33 个参数
# 第： 2 层   第 34 个参数
# 第： 2 层   第 35 个参数
# 第： 2 层   第 36 个参数
# 第： 2 层   第 37 个参数
# 第： 2 层   第 38 个参数
# 第： 2 层   第 39 个参数
# 第： 2 层   第 40 个参数
# 第： 2 层   第 41 个参数
# 第： 2 层   第 42 个参数
# 第： 2 层   第 43 个参数
# 第： 2 层   第 44 个参数
# 第： 2 层   第 45 个参数
# 第： 2 层   第 46 个参数
# 第： 2 层   第 47 个参数
# 第： 2 层   第 48 个参数
# 第： 2 层   第 49 个参数
# 第： 2 层   第 50 个参数
# 第： 2 层   第 51 个参数
# 第： 2 层   第 52 个参数
# 第： 2 层   第 53 个参数
# 第： 2 层   第 54 个参数
# 第： 2 层   第 55 个参数
# 第： 2 层   第 56 个参数
# 第： 2 层   第 57 个参数
# 第： 2 层   第 58 个参数
# 第： 2 层   第 59 个参数
# 第： 2 层   第 60 个参数
# 第： 2 层   第 61 个参数
# 第： 2 层   第 62 个参数
# 第： 2 层   第 63 个参数
# 第： 2 层   第 64 个参数
# 第： 2 层   第 65 个参数
# 第： 2 层   第 66 个参数
# 第： 2 层   第 67 个参数
# 第： 2 层   第 68 个参数
# 第： 2 层   第 69 个参数
# 第： 2 层   第 70 个参数
# 第： 2 层   第 71 个参数
# 第： 2 层   第 72 个参数
# 第： 2 层   第 73 个参数
# 第： 2 层   第 74 个参数
# 第： 2 层   第 75 个参数
# 第： 2 层   第 76 个参数
# 第： 2 层   第 77 个参数
# 第： 2 层   第 78 个参数
# 第： 2 层   第 79 个参数
# 第： 2 层   第 80 个参数
# 第： 2 层   第 81 个参数
# 第： 2 层   第 82 个参数
# 第： 2 层   第 83 个参数
# 第： 2 层   第 84 个参数
# 第： 2 层   第 85 个参数
# 第： 2 层   第 86 个参数
# 第： 2 层   第 87 个参数
# 第： 2 层   第 88 个参数
# 第： 2 层   第 89 个参数
# 第： 2 层   第 90 个参数
# 第： 2 层   第 91 个参数
# 第： 2 层   第 92 个参数
# 第： 2 层   第 93 个参数
# 第： 2 层   第 94 个参数
# 第： 2 层   第 95 个参数
# 第： 2 层   第 96 个参数
# 第： 2 层   第 97 个参数
# 第： 2 层   第 98 个参数
# 第： 2 层   第 99 个参数
# 第： 3 层   第 0 个参数
# 第： 3 层   第 1 个参数
# 第： 3 层   第 2 个参数
# 第： 3 层   第 3 个参数
# 第： 3 层   第 4 个参数
# 第： 3 层   第 5 个参数
# 第： 3 层   第 6 个参数
# 第： 3 层   第 7 个参数
# 第： 3 层   第 8 个参数
# 第： 3 层   第 9 个参数
# 第： 3 层   第 10 个参数
# 第： 3 层   第 11 个参数
# 第： 3 层   第 12 个参数
# 第： 3 层   第 13 个参数
# 第： 3 层   第 14 个参数
# 第： 3 层   第 15 个参数
# 第： 3 层   第 16 个参数
# 第： 3 层   第 17 个参数
# 第： 3 层   第 18 个参数
# 第： 3 层   第 19 个参数
# 第： 3 层   第 20 个参数
# 第： 3 层   第 21 个参数
# 第： 3 层   第 22 个参数
# 第： 3 层   第 23 个参数
# 第： 3 层   第 24 个参数
# 第： 3 层   第 25 个参数
# 第： 3 层   第 26 个参数
# 第： 3 层   第 27 个参数
# 第： 3 层   第 28 个参数
# 第： 3 层   第 29 个参数
# 第： 3 层   第 30 个参数
# 第： 3 层   第 31 个参数
# 第： 3 层   第 32 个参数
# 第： 3 层   第 33 个参数
# 第： 3 层   第 34 个参数
# 第： 3 层   第 35 个参数
# 第： 3 层   第 36 个参数
# 第： 3 层   第 37 个参数
# 第： 3 层   第 38 个参数
# 第： 3 层   第 39 个参数
# 第： 3 层   第 40 个参数
# 第： 3 层   第 41 个参数
# 第： 3 层   第 42 个参数
# 第： 3 层   第 43 个参数
# 第： 3 层   第 44 个参数
# 第： 3 层   第 45 个参数
# 第： 3 层   第 46 个参数
# 第： 3 层   第 47 个参数
# 第： 3 层   第 48 个参数
# 第： 3 层   第 49 个参数
# 第： 3 层   第 50 个参数
# 第： 3 层   第 51 个参数
# 第： 3 层   第 52 个参数
# 第： 3 层   第 53 个参数
# 第： 3 层   第 54 个参数
# 第： 3 层   第 55 个参数
# 第： 3 层   第 56 个参数
# 第： 3 层   第 57 个参数
# 第： 3 层   第 58 个参数
# 第： 3 层   第 59 个参数
# 第： 3 层   第 60 个参数
# 第： 3 层   第 61 个参数
# 第： 3 层   第 62 个参数
# 第： 3 层   第 63 个参数
# 第： 3 层   第 64 个参数
# 第： 3 层   第 65 个参数
# 第： 3 层   第 66 个参数
# 第： 3 层   第 67 个参数
# 第： 3 层   第 68 个参数
# 第： 3 层   第 69 个参数
# 第： 3 层   第 70 个参数
# 第： 3 层   第 71 个参数
# 第： 3 层   第 72 个参数
# 第： 3 层   第 73 个参数
# 第： 3 层   第 74 个参数
# 第： 3 层   第 75 个参数
# 第： 3 层   第 76 个参数
# 第： 3 层   第 77 个参数
# 第： 3 层   第 78 个参数
# 第： 3 层   第 79 个参数
# 第： 3 层   第 80 个参数
# 第： 3 层   第 81 个参数
# 第： 3 层   第 82 个参数
# 第： 3 层   第 83 个参数
# 第： 3 层   第 84 个参数
# 第： 3 层   第 85 个参数
# 第： 3 层   第 86 个参数
# 第： 3 层   第 87 个参数
# 第： 3 层   第 88 个参数
# 第： 3 层   第 89 个参数
# 第： 3 层   第 90 个参数
# 第： 3 层   第 91 个参数
# 第： 3 层   第 92 个参数
# 第： 3 层   第 93 个参数
# 第： 3 层   第 94 个参数
# 第： 3 层   第 95 个参数
# 第： 3 层   第 96 个参数
# 第： 3 层   第 97 个参数
# 第： 3 层   第 98 个参数
# 第： 3 层   第 99 个参数
# 优化时间： 2334.578521490097
# Optimal parameters: [12.49663127  1.67108563  2.59545569  4.80185046  3.82344258  3.10444583]
# Optimal value: 88.42439999999998
# Final expectation value: 88.42439999999998
# Final measurement counts: {'00111': 3821, '00101': 2128, '10111': 774, '00011': 752, '10001': 450, '00110': 383, '01101': 377, '10110': 201, '10101': 191, '11111': 132, '00001': 86, '01001': 76, '01100': 66, '01111': 64, '01110': 57, '10000': 47, '00100': 46, '10100': 44, '11011': 41, '00010': 40, '10011': 39, '11001': 37, '01010': 29, '00000': 26, '11101': 20, '11110': 20, '10010': 15, '11000': 9, '01000': 9, '11100': 8, '01011': 6, '11010': 6}
# Running optimizer: L-BFGS-B
# 第： 1 层   第 0 个参数
# 第： 1 层   第 1 个参数
# 第： 1 层   第 2 个参数
# 第： 1 层   第 3 个参数
# 第： 1 层   第 4 个参数
# 第： 1 层   第 5 个参数
# 第： 1 层   第 6 个参数
# 第： 1 层   第 7 个参数
# 第： 1 层   第 8 个参数
# 第： 1 层   第 9 个参数
# 第： 1 层   第 10 个参数
# 第： 1 层   第 11 个参数
# 第： 1 层   第 12 个参数
# 第： 1 层   第 13 个参数
# 第： 1 层   第 14 个参数
# 第： 1 层   第 15 个参数
# 第： 1 层   第 16 个参数
# 第： 1 层   第 17 个参数
# 第： 1 层   第 18 个参数
# 第： 1 层   第 19 个参数
# 第： 1 层   第 20 个参数
# 第： 1 层   第 21 个参数
# 第： 1 层   第 22 个参数
# 第： 1 层   第 23 个参数
# 第： 1 层   第 24 个参数
# 第： 1 层   第 25 个参数
# 第： 1 层   第 26 个参数
# 第： 1 层   第 27 个参数
# 第： 1 层   第 28 个参数
# 第： 1 层   第 29 个参数
# 第： 1 层   第 30 个参数
# 第： 1 层   第 31 个参数
# 第： 1 层   第 32 个参数
# 第： 1 层   第 33 个参数
# 第： 1 层   第 34 个参数
# 第： 1 层   第 35 个参数
# 第： 1 层   第 36 个参数
# 第： 1 层   第 37 个参数
# 第： 1 层   第 38 个参数
# 第： 1 层   第 39 个参数
# 第： 1 层   第 40 个参数
# 第： 1 层   第 41 个参数
# 第： 1 层   第 42 个参数
# 第： 1 层   第 43 个参数
# 第： 1 层   第 44 个参数
# 第： 1 层   第 45 个参数
# 第： 1 层   第 46 个参数
# 第： 1 层   第 47 个参数
# 第： 1 层   第 48 个参数
# 第： 1 层   第 49 个参数
# 第： 1 层   第 50 个参数
# 第： 1 层   第 51 个参数
# 第： 1 层   第 52 个参数
# 第： 1 层   第 53 个参数
# 第： 1 层   第 54 个参数
# 第： 1 层   第 55 个参数
# 第： 1 层   第 56 个参数
# 第： 1 层   第 57 个参数
# 第： 1 层   第 58 个参数
# 第： 1 层   第 59 个参数
# 第： 1 层   第 60 个参数
# 第： 1 层   第 61 个参数
# 第： 1 层   第 62 个参数
# 第： 1 层   第 63 个参数
# 第： 1 层   第 64 个参数
# 第： 1 层   第 65 个参数
# 第： 1 层   第 66 个参数
# 第： 1 层   第 67 个参数
# 第： 1 层   第 68 个参数
# 第： 1 层   第 69 个参数
# 第： 1 层   第 70 个参数
# 第： 1 层   第 71 个参数
# 第： 1 层   第 72 个参数
# 第： 1 层   第 73 个参数
# 第： 1 层   第 74 个参数
# 第： 1 层   第 75 个参数
# 第： 1 层   第 76 个参数
# 第： 1 层   第 77 个参数
# 第： 1 层   第 78 个参数
# 第： 1 层   第 79 个参数
# 第： 1 层   第 80 个参数
# 第： 1 层   第 81 个参数
# 第： 1 层   第 82 个参数
# 第： 1 层   第 83 个参数
# 第： 1 层   第 84 个参数
# 第： 1 层   第 85 个参数
# 第： 1 层   第 86 个参数
# 第： 1 层   第 87 个参数
# 第： 1 层   第 88 个参数
# 第： 1 层   第 89 个参数
# 第： 1 层   第 90 个参数
# 第： 1 层   第 91 个参数
# 第： 1 层   第 92 个参数
# 第： 1 层   第 93 个参数
# 第： 1 层   第 94 个参数
# 第： 1 层   第 95 个参数
# 第： 1 层   第 96 个参数
# 第： 1 层   第 97 个参数
# 第： 1 层   第 98 个参数
# 第： 1 层   第 99 个参数
# 第： 2 层   第 0 个参数
# 第： 2 层   第 1 个参数
# 第： 2 层   第 2 个参数
# 第： 2 层   第 3 个参数
# 第： 2 层   第 4 个参数
# 第： 2 层   第 5 个参数
# 第： 2 层   第 6 个参数
# 第： 2 层   第 7 个参数
# 第： 2 层   第 8 个参数
# 第： 2 层   第 9 个参数
# 第： 2 层   第 10 个参数
# 第： 2 层   第 11 个参数
# 第： 2 层   第 12 个参数
# 第： 2 层   第 13 个参数
# 第： 2 层   第 14 个参数
# 第： 2 层   第 15 个参数
# 第： 2 层   第 16 个参数
# 第： 2 层   第 17 个参数
# 第： 2 层   第 18 个参数
# 第： 2 层   第 19 个参数
# 第： 2 层   第 20 个参数
# 第： 2 层   第 21 个参数
# 第： 2 层   第 22 个参数
# 第： 2 层   第 23 个参数
# 第： 2 层   第 24 个参数
# 第： 2 层   第 25 个参数
# 第： 2 层   第 26 个参数
# 第： 2 层   第 27 个参数
# 第： 2 层   第 28 个参数
# 第： 2 层   第 29 个参数
# 第： 2 层   第 30 个参数
# 第： 2 层   第 31 个参数
# 第： 2 层   第 32 个参数
# 第： 2 层   第 33 个参数
# 第： 2 层   第 34 个参数
# 第： 2 层   第 35 个参数
# 第： 2 层   第 36 个参数
# 第： 2 层   第 37 个参数
# 第： 2 层   第 38 个参数
# 第： 2 层   第 39 个参数
# 第： 2 层   第 40 个参数
# 第： 2 层   第 41 个参数
# 第： 2 层   第 42 个参数
# 第： 2 层   第 43 个参数
# 第： 2 层   第 44 个参数
# 第： 2 层   第 45 个参数
# 第： 2 层   第 46 个参数
# 第： 2 层   第 47 个参数
# 第： 2 层   第 48 个参数
# 第： 2 层   第 49 个参数
# 第： 2 层   第 50 个参数
# 第： 2 层   第 51 个参数
# 第： 2 层   第 52 个参数
# 第： 2 层   第 53 个参数
# 第： 2 层   第 54 个参数
# 第： 2 层   第 55 个参数
# 第： 2 层   第 56 个参数
# 第： 2 层   第 57 个参数
# 第： 2 层   第 58 个参数
# 第： 2 层   第 59 个参数
# 第： 2 层   第 60 个参数
# 第： 2 层   第 61 个参数
# 第： 2 层   第 62 个参数
# 第： 2 层   第 63 个参数
# 第： 2 层   第 64 个参数
# 第： 2 层   第 65 个参数
# 第： 2 层   第 66 个参数
# 第： 2 层   第 67 个参数
# 第： 2 层   第 68 个参数
# 第： 2 层   第 69 个参数
# 第： 2 层   第 70 个参数
# 第： 2 层   第 71 个参数
# 第： 2 层   第 72 个参数
# 第： 2 层   第 73 个参数
# 第： 2 层   第 74 个参数
# 第： 2 层   第 75 个参数
# 第： 2 层   第 76 个参数
# 第： 2 层   第 77 个参数
# 第： 2 层   第 78 个参数
# 第： 2 层   第 79 个参数
# 第： 2 层   第 80 个参数
# 第： 2 层   第 81 个参数
# 第： 2 层   第 82 个参数
# 第： 2 层   第 83 个参数
# 第： 2 层   第 84 个参数
# 第： 2 层   第 85 个参数
# 第： 2 层   第 86 个参数
# 第： 2 层   第 87 个参数
# 第： 2 层   第 88 个参数
# 第： 2 层   第 89 个参数
# 第： 2 层   第 90 个参数
# 第： 2 层   第 91 个参数
# 第： 2 层   第 92 个参数
# 第： 2 层   第 93 个参数
# 第： 2 层   第 94 个参数
# 第： 2 层   第 95 个参数
# 第： 2 层   第 96 个参数
# 第： 2 层   第 97 个参数
# 第： 2 层   第 98 个参数
# 第： 2 层   第 99 个参数
# 第： 3 层   第 0 个参数
# 第： 3 层   第 1 个参数
# 第： 3 层   第 2 个参数
# 第： 3 层   第 3 个参数
# 第： 3 层   第 4 个参数
# 第： 3 层   第 5 个参数
# 第： 3 层   第 6 个参数
# 第： 3 层   第 7 个参数
# 第： 3 层   第 8 个参数
# 第： 3 层   第 9 个参数
# 第： 3 层   第 10 个参数
# 第： 3 层   第 11 个参数
# 第： 3 层   第 12 个参数
# 第： 3 层   第 13 个参数
# 第： 3 层   第 14 个参数
# 第： 3 层   第 15 个参数
# 第： 3 层   第 16 个参数
# 第： 3 层   第 17 个参数
# 第： 3 层   第 18 个参数
# 第： 3 层   第 19 个参数
# 第： 3 层   第 20 个参数
# 第： 3 层   第 21 个参数
# 第： 3 层   第 22 个参数
# 第： 3 层   第 23 个参数
# 第： 3 层   第 24 个参数
# 第： 3 层   第 25 个参数
# 第： 3 层   第 26 个参数
# 第： 3 层   第 27 个参数
# 第： 3 层   第 28 个参数
# 第： 3 层   第 29 个参数
# 第： 3 层   第 30 个参数
# 第： 3 层   第 31 个参数
# 第： 3 层   第 32 个参数
# 第： 3 层   第 33 个参数
# 第： 3 层   第 34 个参数
# 第： 3 层   第 35 个参数
# 第： 3 层   第 36 个参数
# 第： 3 层   第 37 个参数
# 第： 3 层   第 38 个参数
# 第： 3 层   第 39 个参数
# 第： 3 层   第 40 个参数
# 第： 3 层   第 41 个参数
# 第： 3 层   第 42 个参数
# 第： 3 层   第 43 个参数
# 第： 3 层   第 44 个参数
# 第： 3 层   第 45 个参数
# 第： 3 层   第 46 个参数
# 第： 3 层   第 47 个参数
# 第： 3 层   第 48 个参数
# 第： 3 层   第 49 个参数
# 第： 3 层   第 50 个参数
# 第： 3 层   第 51 个参数
# 第： 3 层   第 52 个参数
# 第： 3 层   第 53 个参数
# 第： 3 层   第 54 个参数
# 第： 3 层   第 55 个参数
# 第： 3 层   第 56 个参数
# 第： 3 层   第 57 个参数
# 第： 3 层   第 58 个参数
# 第： 3 层   第 59 个参数
# 第： 3 层   第 60 个参数
# 第： 3 层   第 61 个参数
# 第： 3 层   第 62 个参数
# 第： 3 层   第 63 个参数
# 第： 3 层   第 64 个参数
# 第： 3 层   第 65 个参数
# 第： 3 层   第 66 个参数
# 第： 3 层   第 67 个参数
# 第： 3 层   第 68 个参数
# 第： 3 层   第 69 个参数
# 第： 3 层   第 70 个参数
# 第： 3 层   第 71 个参数
# 第： 3 层   第 72 个参数
# 第： 3 层   第 73 个参数
# 第： 3 层   第 74 个参数
# 第： 3 层   第 75 个参数
# 第： 3 层   第 76 个参数
# 第： 3 层   第 77 个参数
# 第： 3 层   第 78 个参数
# 第： 3 层   第 79 个参数
# 第： 3 层   第 80 个参数
# 第： 3 层   第 81 个参数
# 第： 3 层   第 82 个参数
# 第： 3 层   第 83 个参数
# 第： 3 层   第 84 个参数
# 第： 3 层   第 85 个参数
# 第： 3 层   第 86 个参数
# 第： 3 层   第 87 个参数
# 第： 3 层   第 88 个参数
# 第： 3 层   第 89 个参数
# 第： 3 层   第 90 个参数
# 第： 3 层   第 91 个参数
# 第： 3 层   第 92 个参数
# 第： 3 层   第 93 个参数
# 第： 3 层   第 94 个参数
# 第： 3 层   第 95 个参数
# 第： 3 层   第 96 个参数
# 第： 3 层   第 97 个参数
# 第： 3 层   第 98 个参数
# 第： 3 层   第 99 个参数
# 优化时间： 318.9297938346863
# Optimal parameters: [2.28594585 1.75438423 0.1053949  3.34151077 0.8578108  0.16233232]
# Optimal value: 154.49250000000004
# Final expectation value: 154.49250000000004
# Final measurement counts: {'00111': 1961, '00110': 1716, '01101': 1245, '10111': 888, '01111': 609, '01100': 556, '10110': 466, '11101': 350, '10011': 328, '00010': 270, '00101': 250, '00100': 236, '11011': 152, '11010': 128, '01000': 107, '00001': 102, '11111': 88, '11100': 81, '10010': 66, '00011': 61, '01011': 61, '10001': 58, '01110': 56, '10101': 43, '00000': 32, '10000': 29, '01001': 27, '01010': 24, '10100': 4, '11000': 3, '11001': 2, '11110': 1}
# Running optimizer: SLSQP
# 第： 1 层   第 0 个参数
# 第： 1 层   第 1 个参数
# 第： 1 层   第 2 个参数
# 第： 1 层   第 3 个参数
# 第： 1 层   第 4 个参数
# 第： 1 层   第 5 个参数
# 第： 1 层   第 6 个参数
# 第： 1 层   第 7 个参数
# 第： 1 层   第 8 个参数
# 第： 1 层   第 9 个参数
# 第： 1 层   第 10 个参数
# 第： 1 层   第 11 个参数
# 第： 1 层   第 12 个参数
# 第： 1 层   第 13 个参数
# 第： 1 层   第 14 个参数
# 第： 1 层   第 15 个参数
# 第： 1 层   第 16 个参数
# 第： 1 层   第 17 个参数
# 第： 1 层   第 18 个参数
# 第： 1 层   第 19 个参数
# 第： 1 层   第 20 个参数
# 第： 1 层   第 21 个参数
# 第： 1 层   第 22 个参数
# 第： 1 层   第 23 个参数
# 第： 1 层   第 24 个参数
# 第： 1 层   第 25 个参数
# 第： 1 层   第 26 个参数
# 第： 1 层   第 27 个参数
# 第： 1 层   第 28 个参数
# 第： 1 层   第 29 个参数
# 第： 1 层   第 30 个参数
# 第： 1 层   第 31 个参数
# 第： 1 层   第 32 个参数
# 第： 1 层   第 33 个参数
# 第： 1 层   第 34 个参数
# 第： 1 层   第 35 个参数
# 第： 1 层   第 36 个参数
# 第： 1 层   第 37 个参数
# 第： 1 层   第 38 个参数
# 第： 1 层   第 39 个参数
# 第： 1 层   第 40 个参数
# 第： 1 层   第 41 个参数
# 第： 1 层   第 42 个参数
# 第： 1 层   第 43 个参数
# 第： 1 层   第 44 个参数
# 第： 1 层   第 45 个参数
# 第： 1 层   第 46 个参数
# 第： 1 层   第 47 个参数
# 第： 1 层   第 48 个参数
# 第： 1 层   第 49 个参数
# 第： 1 层   第 50 个参数
# 第： 1 层   第 51 个参数
# 第： 1 层   第 52 个参数
# 第： 1 层   第 53 个参数
# 第： 1 层   第 54 个参数
# 第： 1 层   第 55 个参数
# 第： 1 层   第 56 个参数
# 第： 1 层   第 57 个参数
# 第： 1 层   第 58 个参数
# 第： 1 层   第 59 个参数
# 第： 1 层   第 60 个参数
# 第： 1 层   第 61 个参数
# 第： 1 层   第 62 个参数
# 第： 1 层   第 63 个参数
# 第： 1 层   第 64 个参数
# 第： 1 层   第 65 个参数
# 第： 1 层   第 66 个参数
# 第： 1 层   第 67 个参数
# 第： 1 层   第 68 个参数
# 第： 1 层   第 69 个参数
# 第： 1 层   第 70 个参数
# 第： 1 层   第 71 个参数
# 第： 1 层   第 72 个参数
# 第： 1 层   第 73 个参数
# 第： 1 层   第 74 个参数
# 第： 1 层   第 75 个参数
# 第： 1 层   第 76 个参数
# 第： 1 层   第 77 个参数
# 第： 1 层   第 78 个参数
# 第： 1 层   第 79 个参数
# 第： 1 层   第 80 个参数
# 第： 1 层   第 81 个参数
# 第： 1 层   第 82 个参数
# 第： 1 层   第 83 个参数
# 第： 1 层   第 84 个参数
# 第： 1 层   第 85 个参数
# 第： 1 层   第 86 个参数
# 第： 1 层   第 87 个参数
# 第： 1 层   第 88 个参数
# 第： 1 层   第 89 个参数
# 第： 1 层   第 90 个参数
# 第： 1 层   第 91 个参数
# 第： 1 层   第 92 个参数
# 第： 1 层   第 93 个参数
# 第： 1 层   第 94 个参数
# 第： 1 层   第 95 个参数
# 第： 1 层   第 96 个参数
# 第： 1 层   第 97 个参数
# 第： 1 层   第 98 个参数
# 第： 1 层   第 99 个参数
# 第： 2 层   第 0 个参数
# 第： 2 层   第 1 个参数
# 第： 2 层   第 2 个参数
# 第： 2 层   第 3 个参数
# 第： 2 层   第 4 个参数
# 第： 2 层   第 5 个参数
# 第： 2 层   第 6 个参数
# 第： 2 层   第 7 个参数
# 第： 2 层   第 8 个参数
# 第： 2 层   第 9 个参数
# 第： 2 层   第 10 个参数
# 第： 2 层   第 11 个参数
# 第： 2 层   第 12 个参数
# 第： 2 层   第 13 个参数
# 第： 2 层   第 14 个参数
# 第： 2 层   第 15 个参数
# 第： 2 层   第 16 个参数
# 第： 2 层   第 17 个参数
# 第： 2 层   第 18 个参数
# 第： 2 层   第 19 个参数
# 第： 2 层   第 20 个参数
# 第： 2 层   第 21 个参数
# 第： 2 层   第 22 个参数
# 第： 2 层   第 23 个参数
# 第： 2 层   第 24 个参数
# 第： 2 层   第 25 个参数
# 第： 2 层   第 26 个参数
# 第： 2 层   第 27 个参数
# 第： 2 层   第 28 个参数
# 第： 2 层   第 29 个参数
# 第： 2 层   第 30 个参数
# 第： 2 层   第 31 个参数
# 第： 2 层   第 32 个参数
# 第： 2 层   第 33 个参数
# 第： 2 层   第 34 个参数
# 第： 2 层   第 35 个参数
# 第： 2 层   第 36 个参数
# 第： 2 层   第 37 个参数
# 第： 2 层   第 38 个参数
# 第： 2 层   第 39 个参数
# 第： 2 层   第 40 个参数
# 第： 2 层   第 41 个参数
# 第： 2 层   第 42 个参数
# 第： 2 层   第 43 个参数
# 第： 2 层   第 44 个参数
# 第： 2 层   第 45 个参数
# 第： 2 层   第 46 个参数
# 第： 2 层   第 47 个参数
# 第： 2 层   第 48 个参数
# 第： 2 层   第 49 个参数
# 第： 2 层   第 50 个参数
# 第： 2 层   第 51 个参数
# 第： 2 层   第 52 个参数
# 第： 2 层   第 53 个参数
# 第： 2 层   第 54 个参数
# 第： 2 层   第 55 个参数
# 第： 2 层   第 56 个参数
# 第： 2 层   第 57 个参数
# 第： 2 层   第 58 个参数
# 第： 2 层   第 59 个参数
# 第： 2 层   第 60 个参数
# 第： 2 层   第 61 个参数
# 第： 2 层   第 62 个参数
# 第： 2 层   第 63 个参数
# 第： 2 层   第 64 个参数
# 第： 2 层   第 65 个参数
# 第： 2 层   第 66 个参数
# 第： 2 层   第 67 个参数
# 第： 2 层   第 68 个参数
# 第： 2 层   第 69 个参数
# 第： 2 层   第 70 个参数
# 第： 2 层   第 71 个参数
# 第： 2 层   第 72 个参数
# 第： 2 层   第 73 个参数
# 第： 2 层   第 74 个参数
# 第： 2 层   第 75 个参数
# 第： 2 层   第 76 个参数
# 第： 2 层   第 77 个参数
# 第： 2 层   第 78 个参数
# 第： 2 层   第 79 个参数
# 第： 2 层   第 80 个参数
# 第： 2 层   第 81 个参数
# 第： 2 层   第 82 个参数
# 第： 2 层   第 83 个参数
# 第： 2 层   第 84 个参数
# 第： 2 层   第 85 个参数
# 第： 2 层   第 86 个参数
# 第： 2 层   第 87 个参数
# 第： 2 层   第 88 个参数
# 第： 2 层   第 89 个参数
# 第： 2 层   第 90 个参数
# 第： 2 层   第 91 个参数
# 第： 2 层   第 92 个参数
# 第： 2 层   第 93 个参数
# 第： 2 层   第 94 个参数
# 第： 2 层   第 95 个参数
# 第： 2 层   第 96 个参数
# 第： 2 层   第 97 个参数
# 第： 2 层   第 98 个参数
# 第： 2 层   第 99 个参数
# 第： 3 层   第 0 个参数
# 第： 3 层   第 1 个参数
# 第： 3 层   第 2 个参数
# 第： 3 层   第 3 个参数
# 第： 3 层   第 4 个参数
# 第： 3 层   第 5 个参数
# 第： 3 层   第 6 个参数
# 第： 3 层   第 7 个参数
# 第： 3 层   第 8 个参数
# 第： 3 层   第 9 个参数
# 第： 3 层   第 10 个参数
# 第： 3 层   第 11 个参数
# 第： 3 层   第 12 个参数
# 第： 3 层   第 13 个参数
# 第： 3 层   第 14 个参数
# 第： 3 层   第 15 个参数
# 第： 3 层   第 16 个参数
# 第： 3 层   第 17 个参数
# 第： 3 层   第 18 个参数
# 第： 3 层   第 19 个参数
# 第： 3 层   第 20 个参数
# 第： 3 层   第 21 个参数
# 第： 3 层   第 22 个参数
# 第： 3 层   第 23 个参数
# 第： 3 层   第 24 个参数
# 第： 3 层   第 25 个参数
# 第： 3 层   第 26 个参数
# 第： 3 层   第 27 个参数
# 第： 3 层   第 28 个参数
# 第： 3 层   第 29 个参数
# 第： 3 层   第 30 个参数
# 第： 3 层   第 31 个参数
# 第： 3 层   第 32 个参数
# 第： 3 层   第 33 个参数
# 第： 3 层   第 34 个参数
# 第： 3 层   第 35 个参数
# 第： 3 层   第 36 个参数
# 第： 3 层   第 37 个参数
# 第： 3 层   第 38 个参数
# 第： 3 层   第 39 个参数
# 第： 3 层   第 40 个参数
# 第： 3 层   第 41 个参数
# 第： 3 层   第 42 个参数
# 第： 3 层   第 43 个参数
# 第： 3 层   第 44 个参数
# 第： 3 层   第 45 个参数
# 第： 3 层   第 46 个参数
# 第： 3 层   第 47 个参数
# 第： 3 层   第 48 个参数
# 第： 3 层   第 49 个参数
# 第： 3 层   第 50 个参数
# 第： 3 层   第 51 个参数
# 第： 3 层   第 52 个参数
# 第： 3 层   第 53 个参数
# 第： 3 层   第 54 个参数
# 第： 3 层   第 55 个参数
# 第： 3 层   第 56 个参数
# 第： 3 层   第 57 个参数
# 第： 3 层   第 58 个参数
# 第： 3 层   第 59 个参数
# 第： 3 层   第 60 个参数
# 第： 3 层   第 61 个参数
# 第： 3 层   第 62 个参数
# 第： 3 层   第 63 个参数
# 第： 3 层   第 64 个参数
# 第： 3 层   第 65 个参数
# 第： 3 层   第 66 个参数
# 第： 3 层   第 67 个参数
# 第： 3 层   第 68 个参数
# 第： 3 层   第 69 个参数
# 第： 3 层   第 70 个参数
# 第： 3 层   第 71 个参数
# 第： 3 层   第 72 个参数
# 第： 3 层   第 73 个参数
# 第： 3 层   第 74 个参数
# 第： 3 层   第 75 个参数
# 第： 3 层   第 76 个参数
# 第： 3 层   第 77 个参数
# 第： 3 层   第 78 个参数
# 第： 3 层   第 79 个参数
# 第： 3 层   第 80 个参数
# 第： 3 层   第 81 个参数
# 第： 3 层   第 82 个参数
# 第： 3 层   第 83 个参数
# 第： 3 层   第 84 个参数
# 第： 3 层   第 85 个参数
# 第： 3 层   第 86 个参数
# 第： 3 层   第 87 个参数
# 第： 3 层   第 88 个参数
# 第： 3 层   第 89 个参数
# 第： 3 层   第 90 个参数
# 第： 3 层   第 91 个参数
# 第： 3 层   第 92 个参数
# 第： 3 层   第 93 个参数
# 第： 3 层   第 94 个参数
# 第： 3 层   第 95 个参数
# 第： 3 层   第 96 个参数
# 第： 3 层   第 97 个参数
# 第： 3 层   第 98 个参数
# 第： 3 层   第 99 个参数
# 优化时间： 201.28855729103088
# Optimal parameters: [2.65459734 0.31816328 2.88409293 1.67944904 1.28729036 4.87408099]
# Optimal value: 221.52650000000006
# Final expectation value: 221.52650000000006
# Final measurement counts: {'00110': 3613, '00111': 1396, '10010': 1128, '01110': 619, '10100': 461, '11010': 376, '01100': 365, '00011': 291, '00100': 252, '11110': 184, '10111': 184, '11100': 164, '10011': 160, '10000': 111, '10110': 93, '00000': 70, '01011': 69, '11000': 62, '00001': 61, '00101': 56, '10101': 46, '10001': 39, '11011': 36, '00010': 35, '01010': 31, '11101': 28, '11111': 22, '01101': 21, '01111': 18, '11001': 4, '01001': 4, '01000': 1}
# Running optimizer: Powell
# 第： 1 层   第 0 个参数
# Optimization terminated successfully.
#          Current function value: 284.953800
#          Iterations: 5
#          Function evaluations: 357
# 第： 1 层   第 1 个参数
# Optimization terminated successfully.
#          Current function value: 234.297600
#          Iterations: 4
#          Function evaluations: 271
# 第： 1 层   第 2 个参数
# Optimization terminated successfully.
#          Current function value: 310.107900
#          Iterations: 3
#          Function evaluations: 239
# 第： 1 层   第 3 个参数
# Optimization terminated successfully.
#          Current function value: 313.993400
#          Iterations: 3
#          Function evaluations: 201
# 第： 1 层   第 4 个参数
# Optimization terminated successfully.
#          Current function value: 279.671900
#          Iterations: 5
#          Function evaluations: 364
# 第： 1 层   第 5 个参数
# Optimization terminated successfully.
#          Current function value: 281.455100
#          Iterations: 3
#          Function evaluations: 186
# 第： 1 层   第 6 个参数
# Optimization terminated successfully.
#          Current function value: 270.340200
#          Iterations: 3
#          Function evaluations: 221
# 第： 1 层   第 7 个参数
# Optimization terminated successfully.
#          Current function value: 340.813300
#          Iterations: 2
#          Function evaluations: 149
# 第： 1 层   第 8 个参数
# Optimization terminated successfully.
#          Current function value: 101.654500
#          Iterations: 4
#          Function evaluations: 251
# 第： 1 层   第 9 个参数
# Optimization terminated successfully.
#          Current function value: 178.820200
#          Iterations: 3
#          Function evaluations: 191
# 第： 1 层   第 10 个参数
# Optimization terminated successfully.
#          Current function value: 181.367400
#          Iterations: 4
#          Function evaluations: 279
# 第： 1 层   第 11 个参数
# Optimization terminated successfully.
#          Current function value: 312.876300
#          Iterations: 5
#          Function evaluations: 312
# 第： 1 层   第 12 个参数
# Optimization terminated successfully.
#          Current function value: 258.489700
#          Iterations: 6
#          Function evaluations: 378
# 第： 1 层   第 13 个参数
# Optimization terminated successfully.
#          Current function value: 181.595100
#          Iterations: 3
#          Function evaluations: 211
# 第： 1 层   第 14 个参数
# Optimization terminated successfully.
#          Current function value: 286.712200
#          Iterations: 3
#          Function evaluations: 206
# 第： 1 层   第 15 个参数
# Optimization terminated successfully.
#          Current function value: 326.810400
#          Iterations: 6
#          Function evaluations: 389
# 第： 1 层   第 16 个参数
# Optimization terminated successfully.
#          Current function value: 168.262900
#          Iterations: 3
#          Function evaluations: 194
# 第： 1 层   第 17 个参数
# Optimization terminated successfully.
#          Current function value: 281.305100
#          Iterations: 4
#          Function evaluations: 278
# 第： 1 层   第 18 个参数
# Optimization terminated successfully.
#          Current function value: 347.354600
#          Iterations: 5
#          Function evaluations: 355
# 第： 1 层   第 19 个参数
# Optimization terminated successfully.
#          Current function value: 234.033200
#          Iterations: 5
#          Function evaluations: 343
# 第： 1 层   第 20 个参数
# Optimization terminated successfully.
#          Current function value: 316.537100
#          Iterations: 6
#          Function evaluations: 449
# 第： 1 层   第 21 个参数
# Optimization terminated successfully.
#          Current function value: 76.752000
#          Iterations: 3
#          Function evaluations: 196
# 第： 1 层   第 22 个参数
# Optimization terminated successfully.
#          Current function value: 288.535800
#          Iterations: 4
#          Function evaluations: 281
# 第： 1 层   第 23 个参数
# Optimization terminated successfully.
#          Current function value: 181.369900
#          Iterations: 6
#          Function evaluations: 354
# 第： 1 层   第 24 个参数
# Optimization terminated successfully.
#          Current function value: 241.933000
#          Iterations: 4
#          Function evaluations: 262
# 第： 1 层   第 25 个参数
# Optimization terminated successfully.
#          Current function value: 322.430800
#          Iterations: 8
#          Function evaluations: 501
# 第： 1 层   第 26 个参数
# Optimization terminated successfully.
#          Current function value: 262.772900
#          Iterations: 4
#          Function evaluations: 263
# 第： 1 层   第 27 个参数
# Optimization terminated successfully.
#          Current function value: 178.011400
#          Iterations: 5
#          Function evaluations: 314
# 第： 1 层   第 28 个参数
# Optimization terminated successfully.
#          Current function value: 181.927100
#          Iterations: 4
#          Function evaluations: 269
# 第： 1 层   第 29 个参数
# Optimization terminated successfully.
#          Current function value: 273.399400
#          Iterations: 5
#          Function evaluations: 321
# 第： 1 层   第 30 个参数
# Optimization terminated successfully.
#          Current function value: 102.447700
#          Iterations: 3
#          Function evaluations: 180
# 第： 1 层   第 31 个参数
# Optimization terminated successfully.
#          Current function value: 181.550000
#          Iterations: 3
#          Function evaluations: 192
# 第： 1 层   第 32 个参数
# Optimization terminated successfully.
#          Current function value: 223.466400
#          Iterations: 3
#          Function evaluations: 185
# 第： 1 层   第 33 个参数
# Optimization terminated successfully.
#          Current function value: 352.392000
#          Iterations: 6
#          Function evaluations: 401
# 第： 1 层   第 34 个参数
# Optimization terminated successfully.
#          Current function value: 137.306300
#          Iterations: 4
#          Function evaluations: 324
# 第： 1 层   第 35 个参数
# Optimization terminated successfully.
#          Current function value: 284.608100
#          Iterations: 4
#          Function evaluations: 271
# 第： 1 层   第 36 个参数
# Optimization terminated successfully.
#          Current function value: 309.709600
#          Iterations: 3
#          Function evaluations: 233
# 第： 1 层   第 37 个参数
# Optimization terminated successfully.
#          Current function value: 269.125300
#          Iterations: 3
#          Function evaluations: 242
# 第： 1 层   第 38 个参数
# Optimization terminated successfully.
#          Current function value: 161.921900
#          Iterations: 5
#          Function evaluations: 324
# 第： 1 层   第 39 个参数
# Optimization terminated successfully.
#          Current function value: 301.726100
#          Iterations: 5
#          Function evaluations: 383
# 第： 1 层   第 40 个参数
# Optimization terminated successfully.
#          Current function value: 169.394100
#          Iterations: 3
#          Function evaluations: 242
# 第： 1 层   第 41 个参数
# Optimization terminated successfully.
#          Current function value: 269.139100
#          Iterations: 3
#          Function evaluations: 216
# 第： 1 层   第 42 个参数
# Optimization terminated successfully.
#          Current function value: 270.117300
#          Iterations: 3
#          Function evaluations: 210
# 第： 1 层   第 43 个参数
# Optimization terminated successfully.
#          Current function value: 201.446600
#          Iterations: 4
#          Function evaluations: 257
# 第： 1 层   第 44 个参数
# Optimization terminated successfully.
#          Current function value: 310.612200
#          Iterations: 3
#          Function evaluations: 228
# 第： 1 层   第 45 个参数
# Optimization terminated successfully.
#          Current function value: 222.743100
#          Iterations: 5
#          Function evaluations: 311
# 第： 1 层   第 46 个参数
# Optimization terminated successfully.
#          Current function value: 172.404100
#          Iterations: 3
#          Function evaluations: 249
# 第： 1 层   第 47 个参数
# Optimization terminated successfully.
#          Current function value: 281.002100
#          Iterations: 2
#          Function evaluations: 159
# 第： 1 层   第 48 个参数
# Optimization terminated successfully.
#          Current function value: 322.555700
#          Iterations: 2
#          Function evaluations: 175
# 第： 1 层   第 49 个参数
# Optimization terminated successfully.
#          Current function value: 316.303100
#          Iterations: 5
#          Function evaluations: 349
# 第： 1 层   第 50 个参数
# Optimization terminated successfully.
#          Current function value: 298.201200
#          Iterations: 6
#          Function evaluations: 409
# 第： 1 层   第 51 个参数
# Optimization terminated successfully.
#          Current function value: 269.713200
#          Iterations: 4
#          Function evaluations: 275
# 第： 1 层   第 52 个参数
# Optimization terminated successfully.
#          Current function value: 232.424800
#          Iterations: 5
#          Function evaluations: 338
# 第： 1 层   第 53 个参数
# Optimization terminated successfully.
#          Current function value: 266.250400
#          Iterations: 3
#          Function evaluations: 186
# 第： 1 层   第 54 个参数
# Optimization terminated successfully.
#          Current function value: 190.842200
#          Iterations: 8
#          Function evaluations: 585
# 第： 1 层   第 55 个参数
# Optimization terminated successfully.
#          Current function value: 279.973100
#          Iterations: 3
#          Function evaluations: 185
# 第： 1 层   第 56 个参数
# Optimization terminated successfully.
#          Current function value: 115.740600
#          Iterations: 5
#          Function evaluations: 322
# 第： 1 层   第 57 个参数
# Optimization terminated successfully.
#          Current function value: 137.285300
#          Iterations: 4
#          Function evaluations: 248
# 第： 1 层   第 58 个参数
# Optimization terminated successfully.
#          Current function value: 292.477000
#          Iterations: 4
#          Function evaluations: 268
# 第： 1 层   第 59 个参数
# Optimization terminated successfully.
#          Current function value: 288.082200
#          Iterations: 4
#          Function evaluations: 283
# 第： 1 层   第 60 个参数
# Optimization terminated successfully.
#          Current function value: 284.788300
#          Iterations: 3
#          Function evaluations: 241
# 第： 1 层   第 61 个参数
# Optimization terminated successfully.
#          Current function value: 68.488700
#          Iterations: 3
#          Function evaluations: 186
# 第： 1 层   第 62 个参数
# Optimization terminated successfully.
#          Current function value: 280.273100
#          Iterations: 3
#          Function evaluations: 229
# 第： 1 层   第 63 个参数
# Optimization terminated successfully.
#          Current function value: 225.227000
#          Iterations: 4
#          Function evaluations: 264
# 第： 1 层   第 64 个参数
# Optimization terminated successfully.
#          Current function value: 357.895700
#          Iterations: 2
#          Function evaluations: 168
# 第： 1 层   第 65 个参数
# Optimization terminated successfully.
#          Current function value: 322.423400
#          Iterations: 4
#          Function evaluations: 273
# 第： 1 层   第 66 个参数
# Optimization terminated successfully.
#          Current function value: 223.124900
#          Iterations: 5
#          Function evaluations: 322
# 第： 1 层   第 67 个参数
# Optimization terminated successfully.
#          Current function value: 274.793600
#          Iterations: 2
#          Function evaluations: 163
# 第： 1 层   第 68 个参数
# Optimization terminated successfully.
#          Current function value: 271.751000
#          Iterations: 5
#          Function evaluations: 319
# 第： 1 层   第 69 个参数
# Optimization terminated successfully.
#          Current function value: 280.999100
#          Iterations: 4
#          Function evaluations: 274
# 第： 1 层   第 70 个参数
# Optimization terminated successfully.
#          Current function value: 178.977300
#          Iterations: 3
#          Function evaluations: 223
# 第： 1 层   第 71 个参数
# Optimization terminated successfully.
#          Current function value: 231.576000
#          Iterations: 7
#          Function evaluations: 499
# 第： 1 层   第 72 个参数
# Optimization terminated successfully.
#          Current function value: 282.533300
#          Iterations: 6
#          Function evaluations: 385
# 第： 1 层   第 73 个参数
# Optimization terminated successfully.
#          Current function value: 337.567700
#          Iterations: 7
#          Function evaluations: 475
# 第： 1 层   第 74 个参数
# Optimization terminated successfully.
#          Current function value: 292.047500
#          Iterations: 4
#          Function evaluations: 254
# 第： 1 层   第 75 个参数
# Optimization terminated successfully.
#          Current function value: 303.262400
#          Iterations: 6
#          Function evaluations: 368
# 第： 1 层   第 76 个参数
# Optimization terminated successfully.
#          Current function value: 322.790800
#          Iterations: 4
#          Function evaluations: 287
# 第： 1 层   第 77 个参数
# Optimization terminated successfully.
#          Current function value: 137.329600
#          Iterations: 4
#          Function evaluations: 302
# 第： 1 层   第 78 个参数
# Optimization terminated successfully.
#          Current function value: 265.689100
#          Iterations: 3
#          Function evaluations: 200
# 第： 1 层   第 79 个参数
# Optimization terminated successfully.
#          Current function value: 258.699000
#          Iterations: 3
#          Function evaluations: 223
# 第： 1 层   第 80 个参数
# Optimization terminated successfully.
#          Current function value: 312.484200
#          Iterations: 5
#          Function evaluations: 333
# 第： 1 层   第 81 个参数
# Optimization terminated successfully.
#          Current function value: 234.475300
#          Iterations: 4
#          Function evaluations: 290
# 第： 1 层   第 82 个参数
# Optimization terminated successfully.
#          Current function value: 178.873300
#          Iterations: 4
#          Function evaluations: 267
# 第： 1 层   第 83 个参数
# Optimization terminated successfully.
#          Current function value: 265.900100
#          Iterations: 4
#          Function evaluations: 275
# 第： 1 层   第 84 个参数
# Optimization terminated successfully.
#          Current function value: 76.752000
#          Iterations: 5
#          Function evaluations: 314
# 第： 1 层   第 85 个参数
# Optimization terminated successfully.
#          Current function value: 285.327900
#          Iterations: 5
#          Function evaluations: 398
# 第： 1 层   第 86 个参数
# Optimization terminated successfully.
#          Current function value: 232.303300
#          Iterations: 6
#          Function evaluations: 404
# 第： 1 层   第 87 个参数
# Optimization terminated successfully.
#          Current function value: 263.876700
#          Iterations: 5
#          Function evaluations: 322
# 第： 1 层   第 88 个参数
# Optimization terminated successfully.
#          Current function value: 282.736700
#          Iterations: 6
#          Function evaluations: 373
# 第： 1 层   第 89 个参数
# Optimization terminated successfully.
#          Current function value: 265.527100
#          Iterations: 4
#          Function evaluations: 271
# 第： 1 层   第 90 个参数
# Optimization terminated successfully.
#          Current function value: 152.210700
#          Iterations: 4
#          Function evaluations: 238
# 第： 1 层   第 91 个参数
# Optimization terminated successfully.
#          Current function value: 284.530100
#          Iterations: 4
#          Function evaluations: 271
# 第： 1 层   第 92 个参数
# Optimization terminated successfully.
#          Current function value: 310.453100
#          Iterations: 5
#          Function evaluations: 356
# 第： 1 层   第 93 个参数
# Optimization terminated successfully.
#          Current function value: 241.166100
#          Iterations: 4
#          Function evaluations: 324
# 第： 1 层   第 94 个参数
# Optimization terminated successfully.
#          Current function value: 303.301400
#          Iterations: 4
#          Function evaluations: 275
# 第： 1 层   第 95 个参数
# Optimization terminated successfully.
#          Current function value: 279.997100
#          Iterations: 5
#          Function evaluations: 341
# 第： 1 层   第 96 个参数
# Optimization terminated successfully.
#          Current function value: 205.079800
#          Iterations: 4
#          Function evaluations: 268
# 第： 1 层   第 97 个参数
# Optimization terminated successfully.
#          Current function value: 312.848400
#          Iterations: 4
#          Function evaluations: 262
# 第： 1 层   第 98 个参数
# Optimization terminated successfully.
#          Current function value: 249.220300
#          Iterations: 3
#          Function evaluations: 188
# 第： 1 层   第 99 个参数
# Optimization terminated successfully.
#          Current function value: 345.415000
#          Iterations: 4
#          Function evaluations: 312
# 第： 2 层   第 0 个参数
# Optimization terminated successfully.
#          Current function value: 63.910800
#          Iterations: 4
#          Function evaluations: 558
# 第： 2 层   第 1 个参数
# Optimization terminated successfully.
#          Current function value: 64.554000
#          Iterations: 4
#          Function evaluations: 633
# 第： 2 层   第 2 个参数
# Optimization terminated successfully.
#          Current function value: 63.020400
#          Iterations: 7
#          Function evaluations: 918
# 第： 2 层   第 3 个参数
# Optimization terminated successfully.
#          Current function value: 64.835600
#          Iterations: 4
#          Function evaluations: 612
# 第： 2 层   第 4 个参数
# Optimization terminated successfully.
#          Current function value: 62.104300
#          Iterations: 4
#          Function evaluations: 625
# 第： 2 层   第 5 个参数
# Optimization terminated successfully.
#          Current function value: 45.893300
#          Iterations: 5
#          Function evaluations: 688
# 第： 2 层   第 6 个参数
# Optimization terminated successfully.
#          Current function value: 58.835900
#          Iterations: 5
#          Function evaluations: 715
# 第： 2 层   第 7 个参数
# Optimization terminated successfully.
#          Current function value: 61.819300
#          Iterations: 6
#          Function evaluations: 853
# 第： 2 层   第 8 个参数
# Optimization terminated successfully.
#          Current function value: 59.843500
#          Iterations: 4
#          Function evaluations: 509
# 第： 2 层   第 9 个参数
# Optimization terminated successfully.
#          Current function value: 60.577800
#          Iterations: 5
#          Function evaluations: 664
# 第： 2 层   第 10 个参数
# Optimization terminated successfully.
#          Current function value: 63.684600
#          Iterations: 6
#          Function evaluations: 850
# 第： 2 层   第 11 个参数
# Optimization terminated successfully.
#          Current function value: 63.821300
#          Iterations: 5
#          Function evaluations: 703
# 第： 2 层   第 12 个参数
# Optimization terminated successfully.
#          Current function value: 67.353800
#          Iterations: 4
#          Function evaluations: 565
# 第： 2 层   第 13 个参数
# Optimization terminated successfully.
#          Current function value: 66.902100
#          Iterations: 6
#          Function evaluations: 856
# 第： 2 层   第 14 个参数
# Optimization terminated successfully.
#          Current function value: 66.851000
#          Iterations: 3
#          Function evaluations: 473
# 第： 2 层   第 15 个参数
# Optimization terminated successfully.
#          Current function value: 67.867300
#          Iterations: 3
#          Function evaluations: 423
# 第： 2 层   第 16 个参数
# Optimization terminated successfully.
#          Current function value: 66.486700
#          Iterations: 4
#          Function evaluations: 568
# 第： 2 层   第 17 个参数
# Optimization terminated successfully.
#          Current function value: 64.547700
#          Iterations: 4
#          Function evaluations: 603
# 第： 2 层   第 18 个参数
# Optimization terminated successfully.
#          Current function value: 67.160900
#          Iterations: 5
#          Function evaluations: 721
# 第： 2 层   第 19 个参数
# Optimization terminated successfully.
#          Current function value: 60.184800
#          Iterations: 4
#          Function evaluations: 607
# 第： 2 层   第 20 个参数
# Optimization terminated successfully.
#          Current function value: 42.265400
#          Iterations: 5
#          Function evaluations: 639
# 第： 2 层   第 21 个参数
# Optimization terminated successfully.
#          Current function value: 64.749000
#          Iterations: 5
#          Function evaluations: 738
# 第： 2 层   第 22 个参数
# Optimization terminated successfully.
#          Current function value: 58.389800
#          Iterations: 4
#          Function evaluations: 522
# 第： 2 层   第 23 个参数
# Optimization terminated successfully.
#          Current function value: 63.427800
#          Iterations: 2
#          Function evaluations: 285
# 第： 2 层   第 24 个参数
# Optimization terminated successfully.
#          Current function value: 60.921800
#          Iterations: 4
#          Function evaluations: 535
# 第： 2 层   第 25 个参数
# Optimization terminated successfully.
#          Current function value: 59.942800
#          Iterations: 3
#          Function evaluations: 406
# 第： 2 层   第 26 个参数
# Optimization terminated successfully.
#          Current function value: 59.758300
#          Iterations: 3
#          Function evaluations: 435
# 第： 2 层   第 27 个参数
# Optimization terminated successfully.
#          Current function value: 63.538800
#          Iterations: 3
#          Function evaluations: 387
# 第： 2 层   第 28 个参数
# Optimization terminated successfully.
#          Current function value: 65.027100
#          Iterations: 3
#          Function evaluations: 434
# 第： 2 层   第 29 个参数
# Optimization terminated successfully.
#          Current function value: 64.519700
#          Iterations: 4
#          Function evaluations: 553
# 第： 2 层   第 30 个参数
# Optimization terminated successfully.
#          Current function value: 55.431200
#          Iterations: 5
#          Function evaluations: 640
# 第： 2 层   第 31 个参数
# Optimization terminated successfully.
#          Current function value: 63.865300
#          Iterations: 4
#          Function evaluations: 537
# 第： 2 层   第 32 个参数
# Optimization terminated successfully.
#          Current function value: 61.577300
#          Iterations: 8
#          Function evaluations: 983
# 第： 2 层   第 33 个参数
# Optimization terminated successfully.
#          Current function value: 61.808200
#          Iterations: 7
#          Function evaluations: 993
# 第： 2 层   第 34 个参数
# Optimization terminated successfully.
#          Current function value: 68.471000
#          Iterations: 4
#          Function evaluations: 583
# 第： 2 层   第 35 个参数
# Optimization terminated successfully.
#          Current function value: 63.473400
#          Iterations: 6
#          Function evaluations: 838
# 第： 2 层   第 36 个参数
# Optimization terminated successfully.
#          Current function value: 63.982700
#          Iterations: 3
#          Function evaluations: 403
# 第： 2 层   第 37 个参数
# Optimization terminated successfully.
#          Current function value: 62.848400
#          Iterations: 3
#          Function evaluations: 447
# 第： 2 层   第 38 个参数
# Optimization terminated successfully.
#          Current function value: 60.309000
#          Iterations: 4
#          Function evaluations: 510
# 第： 2 层   第 39 个参数
# Optimization terminated successfully.
#          Current function value: 64.775400
#          Iterations: 5
#          Function evaluations: 734
# 第： 2 层   第 40 个参数
# Optimization terminated successfully.
#          Current function value: 63.426600
#          Iterations: 5
#          Function evaluations: 729
# 第： 2 层   第 41 个参数
# Optimization terminated successfully.
#          Current function value: 61.683000
#          Iterations: 2
#          Function evaluations: 325
# 第： 2 层   第 42 个参数
# Optimization terminated successfully.
#          Current function value: 66.394300
#          Iterations: 4
#          Function evaluations: 577
# 第： 2 层   第 43 个参数
# Optimization terminated successfully.
#          Current function value: 62.909500
#          Iterations: 6
#          Function evaluations: 808
# 第： 2 层   第 44 个参数
# Optimization terminated successfully.
#          Current function value: 64.215400
#          Iterations: 6
#          Function evaluations: 933
# 第： 2 层   第 45 个参数
# Optimization terminated successfully.
#          Current function value: 32.172600
#          Iterations: 7
#          Function evaluations: 976
# 第： 2 层   第 46 个参数
# Optimization terminated successfully.
#          Current function value: 60.511300
#          Iterations: 7
#          Function evaluations: 946
# 第： 2 层   第 47 个参数
# Optimization terminated successfully.
#          Current function value: 66.628800
#          Iterations: 3
#          Function evaluations: 479
# 第： 2 层   第 48 个参数
# Optimization terminated successfully.
#          Current function value: 59.857800
#          Iterations: 5
#          Function evaluations: 717
# 第： 2 层   第 49 个参数
# Optimization terminated successfully.
#          Current function value: 63.889200
#          Iterations: 7
#          Function evaluations: 933
# 第： 2 层   第 50 个参数
# Optimization terminated successfully.
#          Current function value: 64.194900
#          Iterations: 5
#          Function evaluations: 655
# 第： 2 层   第 51 个参数
# Optimization terminated successfully.
#          Current function value: 63.268700
#          Iterations: 4
#          Function evaluations: 524
# 第： 2 层   第 52 个参数
# Optimization terminated successfully.
#          Current function value: 63.944600
#          Iterations: 5
#          Function evaluations: 614
# 第： 2 层   第 53 个参数
# Optimization terminated successfully.
#          Current function value: 46.219800
#          Iterations: 5
#          Function evaluations: 682
# 第： 2 层   第 54 个参数
# Optimization terminated successfully.
#          Current function value: 63.164300
#          Iterations: 5
#          Function evaluations: 692
# 第： 2 层   第 55 个参数
# Optimization terminated successfully.
#          Current function value: 48.600200
#          Iterations: 4
#          Function evaluations: 540
# 第： 2 层   第 56 个参数
# Optimization terminated successfully.
#          Current function value: 60.559700
#          Iterations: 4
#          Function evaluations: 537
# 第： 2 层   第 57 个参数
# Optimization terminated successfully.
#          Current function value: 69.051100
#          Iterations: 3
#          Function evaluations: 428
# 第： 2 层   第 58 个参数
# Optimization terminated successfully.
#          Current function value: 62.103700
#          Iterations: 5
#          Function evaluations: 649
# 第： 2 层   第 59 个参数
# Optimization terminated successfully.
#          Current function value: 61.149200
#          Iterations: 4
#          Function evaluations: 561
# 第： 2 层   第 60 个参数
# Optimization terminated successfully.
#          Current function value: 59.667600
#          Iterations: 5
#          Function evaluations: 638
# 第： 2 层   第 61 个参数
# Optimization terminated successfully.
#          Current function value: 61.224300
#          Iterations: 3
#          Function evaluations: 453
# 第： 2 层   第 62 个参数
# Optimization terminated successfully.
#          Current function value: 64.989200
#          Iterations: 6
#          Function evaluations: 869
# 第： 2 层   第 63 个参数
# Optimization terminated successfully.
#          Current function value: 62.118900
#          Iterations: 7
#          Function evaluations: 935
# 第： 2 层   第 64 个参数
# Optimization terminated successfully.
#          Current function value: 58.112700
#          Iterations: 6
#          Function evaluations: 788
# 第： 2 层   第 65 个参数
# Optimization terminated successfully.
#          Current function value: 63.823300
#          Iterations: 4
#          Function evaluations: 547
# 第： 2 层   第 66 个参数
# Optimization terminated successfully.
#          Current function value: 63.359900
#          Iterations: 4
#          Function evaluations: 553
# 第： 2 层   第 67 个参数
# Optimization terminated successfully.
#          Current function value: 57.764700
#          Iterations: 4
#          Function evaluations: 507
# 第： 2 层   第 68 个参数
# Optimization terminated successfully.
#          Current function value: 61.621800
#          Iterations: 9
#          Function evaluations: 1199
# 第： 2 层   第 69 个参数
# Optimization terminated successfully.
#          Current function value: 60.070700
#          Iterations: 10
#          Function evaluations: 1326
# 第： 2 层   第 70 个参数
# Optimization terminated successfully.
#          Current function value: 59.375700
#          Iterations: 7
#          Function evaluations: 954
# 第： 2 层   第 71 个参数
# Optimization terminated successfully.
#          Current function value: 60.035400
#          Iterations: 6
#          Function evaluations: 783
# 第： 2 层   第 72 个参数
# Optimization terminated successfully.
#          Current function value: 60.877400
#          Iterations: 5
#          Function evaluations: 678
# 第： 2 层   第 73 个参数
# Optimization terminated successfully.
#          Current function value: 32.108900
#          Iterations: 6
#          Function evaluations: 767
# 第： 2 层   第 74 个参数
# Optimization terminated successfully.
#          Current function value: 62.427300
#          Iterations: 5
#          Function evaluations: 698
# 第： 2 层   第 75 个参数
# Optimization terminated successfully.
#          Current function value: 59.381300
#          Iterations: 6
#          Function evaluations: 815
# 第： 2 层   第 76 个参数
# Optimization terminated successfully.
#          Current function value: 64.295700
#          Iterations: 6
#          Function evaluations: 876
# 第： 2 层   第 77 个参数
# Optimization terminated successfully.
#          Current function value: 64.114400
#          Iterations: 6
#          Function evaluations: 763
# 第： 2 层   第 78 个参数
# Optimization terminated successfully.
#          Current function value: 32.948400
#          Iterations: 10
#          Function evaluations: 1368
# 第： 2 层   第 79 个参数
# Optimization terminated successfully.
#          Current function value: 61.961700
#          Iterations: 6
#          Function evaluations: 859
# 第： 2 层   第 80 个参数
# Optimization terminated successfully.
#          Current function value: 62.525600
#          Iterations: 8
#          Function evaluations: 1219
# 第： 2 层   第 81 个参数
# Optimization terminated successfully.
#          Current function value: 61.769300
#          Iterations: 4
#          Function evaluations: 587
# 第： 2 层   第 82 个参数
# Optimization terminated successfully.
#          Current function value: 45.976700
#          Iterations: 7
#          Function evaluations: 931
# 第： 2 层   第 83 个参数
# Optimization terminated successfully.
#          Current function value: 61.778200
#          Iterations: 6
#          Function evaluations: 866
# 第： 2 层   第 84 个参数
# Optimization terminated successfully.
#          Current function value: 63.881700
#          Iterations: 4
#          Function evaluations: 557
# 第： 2 层   第 85 个参数
# Optimization terminated successfully.
#          Current function value: 61.993800
#          Iterations: 5
#          Function evaluations: 699
# 第： 2 层   第 86 个参数
# Optimization terminated successfully.
#          Current function value: 63.434500
#          Iterations: 6
#          Function evaluations: 867
# 第： 2 层   第 87 个参数
# Optimization terminated successfully.
#          Current function value: 63.380500
#          Iterations: 6
#          Function evaluations: 890
# 第： 2 层   第 88 个参数
# Optimization terminated successfully.
#          Current function value: 64.327400
#          Iterations: 6
#          Function evaluations: 829
# 第： 2 层   第 89 个参数
# Optimization terminated successfully.
# ...
# Optimization terminated successfully.
#          Current function value: 36.860100
#          Iterations: 7
#          Function evaluations: 1441
# 第： 3 层   第 3 个参数
# Optimization terminated successfully.
#          Current function value: 157.839600
#          Iterations: 9
#          Function evaluations: 1812
# 第： 3 层   第 4 个参数
# Optimization terminated successfully.
#          Current function value: 30.025200
#          Iterations: 7
#          Function evaluations: 1343
# 第： 3 层   第 5 个参数
# Optimization terminated successfully.
#          Current function value: 62.179700
#          Iterations: 10
#          Function evaluations: 2076
# 第： 3 层   第 6 个参数
# Optimization terminated successfully.
#          Current function value: 54.654100
#          Iterations: 7
#          Function evaluations: 1495
# 第： 3 层   第 7 个参数
# Optimization terminated successfully.
#          Current function value: 32.141700
#          Iterations: 5
#          Function evaluations: 1033
# 第： 3 层   第 8 个参数
# Optimization terminated successfully.
#          Current function value: 109.128900
#          Iterations: 4
#          Function evaluations: 851
# 第： 3 层   第 9 个参数
# Optimization terminated successfully.
#          Current function value: 61.133600
#          Iterations: 5
#          Function evaluations: 1005
# 第： 3 层   第 10 个参数
# Optimization terminated successfully.
#          Current function value: 49.968000
#          Iterations: 5
#          Function evaluations: 1093
# 第： 3 层   第 11 个参数
# Optimization terminated successfully.
#          Current function value: 45.866100
#          Iterations: 5
#          Function evaluations: 984
# 第： 3 层   第 12 个参数
# Optimization terminated successfully.
#          Current function value: 66.001300
#          Iterations: 5
#          Function evaluations: 1058
# 第： 3 层   第 13 个参数
# Optimization terminated successfully.
#          Current function value: 29.616000
#          Iterations: 6
#          Function evaluations: 1195
# 第： 3 层   第 14 个参数
# Optimization terminated successfully.
#          Current function value: 43.495000
#          Iterations: 7
#          Function evaluations: 1435
# 第： 3 层   第 15 个参数
# Optimization terminated successfully.
#          Current function value: 57.477000
#          Iterations: 5
#          Function evaluations: 1012
# 第： 3 层   第 16 个参数
# Optimization terminated successfully.
#          Current function value: 31.015000
#          Iterations: 5
#          Function evaluations: 1042
# 第： 3 层   第 17 个参数
# Optimization terminated successfully.
#          Current function value: 31.265900
#          Iterations: 3
#          Function evaluations: 627
# 第： 3 层   第 18 个参数
# Optimization terminated successfully.
#          Current function value: 32.783900
#          Iterations: 3
#          Function evaluations: 622
# 第： 3 层   第 19 个参数
# Optimization terminated successfully.
#          Current function value: 37.776100
#          Iterations: 8
#          Function evaluations: 1682
# 第： 3 层   第 20 个参数
# Optimization terminated successfully.
#          Current function value: 58.627900
#          Iterations: 5
#          Function evaluations: 993
# 第： 3 层   第 21 个参数
# Optimization terminated successfully.
#          Current function value: 24.783000
#          Iterations: 4
#          Function evaluations: 847
# 第： 3 层   第 22 个参数
# Optimization terminated successfully.
#          Current function value: 28.474900
#          Iterations: 8
#          Function evaluations: 1582
# 第： 3 层   第 23 个参数
# Optimization terminated successfully.
#          Current function value: 59.026300
#          Iterations: 5
#          Function evaluations: 1086
# 第： 3 层   第 24 个参数
# Optimization terminated successfully.
#          Current function value: 29.945300
#          Iterations: 8
#          Function evaluations: 1616
# 第： 3 层   第 25 个参数
# Optimization terminated successfully.
#          Current function value: 39.721900
#          Iterations: 6
#          Function evaluations: 1218
# 第： 3 层   第 26 个参数
# Optimization terminated successfully.
#          Current function value: 29.527700
#          Iterations: 3
#          Function evaluations: 682
# 第： 3 层   第 27 个参数
# Optimization terminated successfully.
#          Current function value: 28.144700
#          Iterations: 5
#          Function evaluations: 1075
# 第： 3 层   第 28 个参数
# Optimization terminated successfully.
#          Current function value: 37.137200
#          Iterations: 13
#          Function evaluations: 2733
# 第： 3 层   第 29 个参数
# Optimization terminated successfully.
#          Current function value: 55.177500
#          Iterations: 7
#          Function evaluations: 1488
# 第： 3 层   第 30 个参数
# Optimization terminated successfully.
#          Current function value: 48.962800
#          Iterations: 6
#          Function evaluations: 1156
# 第： 3 层   第 31 个参数
# Optimization terminated successfully.
#          Current function value: 63.908400
#          Iterations: 6
#          Function evaluations: 1308
# 第： 3 层   第 32 个参数
# Optimization terminated successfully.
#          Current function value: 60.800600
#          Iterations: 7
#          Function evaluations: 1510
# 第： 3 层   第 33 个参数
# Optimization terminated successfully.
#          Current function value: 31.167200
#          Iterations: 6
#          Function evaluations: 1405
# 第： 3 层   第 34 个参数
# Optimization terminated successfully.
#          Current function value: 30.916500
#          Iterations: 4
#          Function evaluations: 890
# 第： 3 层   第 35 个参数
# Optimization terminated successfully.
#          Current function value: 58.339800
#          Iterations: 5
#          Function evaluations: 1010
# 第： 3 层   第 36 个参数
# Optimization terminated successfully.
#          Current function value: 30.961100
#          Iterations: 6
#          Function evaluations: 1321
# 第： 3 层   第 37 个参数
# Optimization terminated successfully.
#          Current function value: 29.588600
#          Iterations: 6
#          Function evaluations: 1335
# 第： 3 层   第 38 个参数
# Optimization terminated successfully.
#          Current function value: 60.528500
#          Iterations: 4
#          Function evaluations: 840
# 第： 3 层   第 39 个参数
# Optimization terminated successfully.
#          Current function value: 48.996600
#          Iterations: 7
#          Function evaluations: 1407
# 第： 3 层   第 40 个参数
# Optimization terminated successfully.
#          Current function value: 29.873300
#          Iterations: 4
#          Function evaluations: 864
# 第： 3 层   第 41 个参数
# Optimization terminated successfully.
#          Current function value: 68.323900
#          Iterations: 9
#          Function evaluations: 1898
# 第： 3 层   第 42 个参数
# Optimization terminated successfully.
#          Current function value: 29.763200
#          Iterations: 6
#          Function evaluations: 1379
# 第： 3 层   第 43 个参数
# Optimization terminated successfully.
#          Current function value: 63.498800
#          Iterations: 6
#          Function evaluations: 1302
# 第： 3 层   第 44 个参数
# Optimization terminated successfully.
#          Current function value: 31.712600
#          Iterations: 6
#          Function evaluations: 1368
# 第： 3 层   第 45 个参数
# Optimization terminated successfully.
#          Current function value: 28.741100
#          Iterations: 6
#          Function evaluations: 1262
# 第： 3 层   第 46 个参数
# Optimization terminated successfully.
#          Current function value: 51.718500
#          Iterations: 6
#          Function evaluations: 1232
# 第： 3 层   第 47 个参数
# Optimization terminated successfully.
#          Current function value: 55.474300
#          Iterations: 6
#          Function evaluations: 1202
# 第： 3 层   第 48 个参数
# Optimization terminated successfully.
#          Current function value: 31.972400
#          Iterations: 7
#          Function evaluations: 1372
# 第： 3 层   第 49 个参数
# Optimization terminated successfully.
#          Current function value: 31.062000
#          Iterations: 4
#          Function evaluations: 794
# 第： 3 层   第 50 个参数
# Optimization terminated successfully.
#          Current function value: 33.147100
#          Iterations: 4
#          Function evaluations: 882
# 第： 3 层   第 51 个参数
# Optimization terminated successfully.
#          Current function value: 33.049600
#          Iterations: 5
#          Function evaluations: 1052
# 第： 3 层   第 52 个参数
# Optimization terminated successfully.
#          Current function value: 28.629200
#          Iterations: 6
#          Function evaluations: 1257
# 第： 3 层   第 53 个参数
# Optimization terminated successfully.
#          Current function value: 41.794000
#          Iterations: 7
#          Function evaluations: 1417
# 第： 3 层   第 54 个参数
# Optimization terminated successfully.
#          Current function value: 30.825100
#          Iterations: 6
#          Function evaluations: 1280
# 第： 3 层   第 55 个参数
# Optimization terminated successfully.
#          Current function value: 64.654800
#          Iterations: 3
#          Function evaluations: 624
# 第： 3 层   第 56 个参数
# Optimization terminated successfully.
#          Current function value: 61.732700
#          Iterations: 5
#          Function evaluations: 1095
# 第： 3 层   第 57 个参数
# Optimization terminated successfully.
#          Current function value: 30.657200
#          Iterations: 4
#          Function evaluations: 863
# 第： 3 层   第 58 个参数
# Optimization terminated successfully.
#          Current function value: 32.076300
#          Iterations: 4
#          Function evaluations: 868
# 第： 3 层   第 59 个参数
# Optimization terminated successfully.
#          Current function value: 34.629000
#          Iterations: 9
#          Function evaluations: 2023
# 第： 3 层   第 60 个参数
# Optimization terminated successfully.
#          Current function value: 30.239700
#          Iterations: 5
#          Function evaluations: 1108
# 第： 3 层   第 61 个参数
# Optimization terminated successfully.
#          Current function value: 58.497800
#          Iterations: 5
#          Function evaluations: 1077
# 第： 3 层   第 62 个参数
# Optimization terminated successfully.
#          Current function value: 29.878100
#          Iterations: 5
#          Function evaluations: 1075
# 第： 3 层   第 63 个参数
# Optimization terminated successfully.
#          Current function value: 31.610700
#          Iterations: 5
#          Function evaluations: 1102
# 第： 3 层   第 64 个参数
# Optimization terminated successfully.
#          Current function value: 28.908400
#          Iterations: 5
#          Function evaluations: 1050
# 第： 3 层   第 65 个参数
# Optimization terminated successfully.
#          Current function value: 65.585700
#          Iterations: 5
#          Function evaluations: 1146
# 第： 3 层   第 66 个参数
# Optimization terminated successfully.
#          Current function value: 29.774800
#          Iterations: 8
#          Function evaluations: 1719
# 第： 3 层   第 67 个参数
# Optimization terminated successfully.
#          Current function value: 27.290400
#          Iterations: 3
#          Function evaluations: 610
# 第： 3 层   第 68 个参数
# Optimization terminated successfully.
#          Current function value: 31.041400
#          Iterations: 7
#          Function evaluations: 1364
# 第： 3 层   第 69 个参数
# Optimization terminated successfully.
#          Current function value: 32.404100
#          Iterations: 5
#          Function evaluations: 948
# 第： 3 层   第 70 个参数
# Optimization terminated successfully.
#          Current function value: 29.191300
#          Iterations: 4
#          Function evaluations: 849
# 第： 3 层   第 71 个参数
# Optimization terminated successfully.
#          Current function value: 66.521500
#          Iterations: 6
#          Function evaluations: 1250
# 第： 3 层   第 72 个参数
# Optimization terminated successfully.
#          Current function value: 30.772000
#          Iterations: 7
#          Function evaluations: 1481
# 第： 3 层   第 73 个参数
# Optimization terminated successfully.
#          Current function value: 47.892400
#          Iterations: 7
#          Function evaluations: 1417
# 第： 3 层   第 74 个参数
# Optimization terminated successfully.
#          Current function value: 55.662200
#          Iterations: 4
#          Function evaluations: 749
# 第： 3 层   第 75 个参数
# Optimization terminated successfully.
#          Current function value: 44.788700
#          Iterations: 4
#          Function evaluations: 817
# 第： 3 层   第 76 个参数
# Optimization terminated successfully.
#          Current function value: 29.721100
#          Iterations: 7
#          Function evaluations: 1549
# 第： 3 层   第 77 个参数
# Optimization terminated successfully.
#          Current function value: 32.315200
#          Iterations: 9
#          Function evaluations: 1981
# 第： 3 层   第 78 个参数
# Optimization terminated successfully.
#          Current function value: 120.050300
#          Iterations: 6
#          Function evaluations: 1212
# 第： 3 层   第 79 个参数
# Optimization terminated successfully.
#          Current function value: 52.872700
#          Iterations: 5
#          Function evaluations: 938
# 第： 3 层   第 80 个参数
# Optimization terminated successfully.
#          Current function value: 28.389500
#          Iterations: 5
#          Function evaluations: 1119
# 第： 3 层   第 81 个参数
# Optimization terminated successfully.
#          Current function value: 26.834400
#          Iterations: 4
#          Function evaluations: 843
# 第： 3 层   第 82 个参数
# Optimization terminated successfully.
#          Current function value: 27.743600
#          Iterations: 6
#          Function evaluations: 1210
# 第： 3 层   第 83 个参数
# Optimization terminated successfully.
#          Current function value: 31.120200
#          Iterations: 7
#          Function evaluations: 1521
# 第： 3 层   第 84 个参数
# Optimization terminated successfully.
#          Current function value: 30.627800
#          Iterations: 4
#          Function evaluations: 807
# 第： 3 层   第 85 个参数
# Optimization terminated successfully.
#          Current function value: 26.959900
#          Iterations: 8
#          Function evaluations: 1529
# 第： 3 层   第 86 个参数
# Optimization terminated successfully.
#          Current function value: 45.234100
#          Iterations: 5
#          Function evaluations: 1037
# 第： 3 层   第 87 个参数
# Optimization terminated successfully.
#          Current function value: 30.209400
#          Iterations: 11
#          Function evaluations: 2467
# 第： 3 层   第 88 个参数
# Optimization terminated successfully.
#          Current function value: 29.317100
#          Iterations: 7
#          Function evaluations: 1543
# 第： 3 层   第 89 个参数
# Optimization terminated successfully.
#          Current function value: 54.370800
#          Iterations: 4
#          Function evaluations: 805
# 第： 3 层   第 90 个参数
# Optimization terminated successfully.
#          Current function value: 55.763500
#          Iterations: 9
#          Function evaluations: 1917
# 第： 3 层   第 91 个参数
# Optimization terminated successfully.
#          Current function value: 32.200500
#          Iterations: 7
#          Function evaluations: 1554
# 第： 3 层   第 92 个参数
# Optimization terminated successfully.
#          Current function value: 30.903200
#          Iterations: 10
#          Function evaluations: 2169
# 第： 3 层   第 93 个参数
# Optimization terminated successfully.
#          Current function value: 44.470400
#          Iterations: 12
#          Function evaluations: 2571
# 第： 3 层   第 94 个参数
# Optimization terminated successfully.
#          Current function value: 31.896400
#          Iterations: 5
#          Function evaluations: 1093
# 第： 3 层   第 95 个参数
# Optimization terminated successfully.
#          Current function value: 29.831900
#          Iterations: 6
#          Function evaluations: 1398
# 第： 3 层   第 96 个参数
# Optimization terminated successfully.
#          Current function value: 30.977200
#          Iterations: 3
#          Function evaluations: 697
# 第： 3 层   第 97 个参数
# Optimization terminated successfully.
#          Current function value: 55.592500
#          Iterations: 5
#          Function evaluations: 1095
# 第： 3 层   第 98 个参数
# Optimization terminated successfully.
#          Current function value: 48.879300
#          Iterations: 6
#          Function evaluations: 1294
# 第： 3 层   第 99 个参数
# Optimization terminated successfully.
#          Current function value: 56.371400
#          Iterations: 5
#          Function evaluations: 1053
# 优化时间： 22071.071287870407
# Optimal parameters: [10.17296833  0.34304711  3.32271678  1.67234127  5.02210505  3.34669371]
# Optimal value: 19.6001
# Final expectation value: 19.6001
# Final measurement counts: {'00111': 7399, '10111': 1656, '00110': 312, '00101': 169, '01111': 88, '10011': 87, '10110': 57, '11101': 43, '00011': 38, '11111': 37, '01001': 25, '01100': 12, '01110': 12, '01101': 10, '11001': 9, '00001': 8, '00100': 7, '01011': 6, '10010': 6, '10100': 4, '11110': 3, '10001': 3, '11100': 3, '10101': 2, '10000': 1, '00010': 1, '01000': 1, '11011': 1}

# %%
# from qiskit.visualization import plot_histogram
# 
# # 输出结果
# print("优化时间：", endTime - startTime)
# print("Optimal parameters:", final_result.x)
# print("Optimal value:", final_result.fun)
# # 使用最优参数运行量子电路并输出测量结果
# final_expectation, final_counts = cost_function(final_result.x)
# sorted_dict = {item[0][::-1]: item[1] for item in sorted(final_counts.items(), key=lambda item: item[1], reverse=True)}
# print("Final expectation value:", final_expectation)
# print("Final measurement counts:", sorted_dict)
# plot_histogram(sorted_dict)
# Out:
# 优化时间： 1053.3414280414581
# Optimal parameters: [11.51242214  3.42492016  1.57472522  3.34568431  3.06119681  7.87903805]
# Optimal value: 129.4413
# Final expectation value: 129.4413
# Final measurement counts: {'00110': 2766, '10111': 2220, '00111': 1138, '00100': 918, '10010': 384, '01101': 373, '01100': 319, '00101': 277, '10011': 268, '00011': 243, '11001': 155, '11100': 150, '10100': 144, '11101': 119, '01110': 108, '00001': 103, '10001': 57, '10000': 44, '01111': 37, '11111': 28, '00000': 27, '01001': 26, '11011': 25, '11000': 23, '01000': 15, '10110': 11, '11110': 8, '00010': 5, '01011': 3, '11010': 3, '01010': 2, '10101': 1}

# %%
expectation = 0
bitstring = "00011"
z_h = np.array([int(bit) for bit in bitstring[(n * N):]])
s_ik = np.array([int(bit) for bit in bitstring[:(n * N)]]).reshape(n, N)
E1 = np.sum([2 ** h * z for h, z in enumerate(z_h)])
E2 = 0
for j in range(len(bw)):
    for i in range(n):
        constant = 1
        for k in range(N):
            constant = constant * (1 - (s_ik[i, k] - bw[j, k]) ** 2)
        E2 += constant
E2 = K1 * E2
E3 = 0
for j in range(m):
    constant1 = 0
    # print("机器：", j)
    for i in range(n):
        constant2 = 1
        for k in range(N):
            constant2 = constant2 * (1 - (s_ik[i, k] - b[j, k]) ** 2)
        # print("constant2:", constant2)
        # print("p[i,j]:", p[i,j])
        constant1 += p[i, j] * constant2
    # print("constant1:", constant1)
    constant3 = 0
    for h in range(l):
        constant3 += 2 ** h * z_h[h]
    # print("constant3:", constant3)
    constant = max(0, constant1 - constant3)
    E3 += (constant) ** 2

    # alpha_s = np.max([0, np.sum(x_ij * p) - np.sum([2 ** h * z for h, z in enumerate(z_h)])])

E = E1 + K1 * E2 + P * E3
print(E1)
print(E2)
print(E3)
# print(e1)
# print(e2)
# Out:
# 1
# 0
# 4
